# %%
import os, sys, random
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader

from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import euclidean_distances

# %%
def random_seed(seed=1234):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

random_seed(1234)

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)
# Out:
# Device: cpu

# %%
from google.colab import drive
drive.mount('/content/drive')

# 경로 설정
ospj = os.path.join
path_workspace = '/content/drive/MyDrive/'
sys.path.append(ospj(path_workspace, 'Collected_dataset'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define training data paths
dict_path_tr_clean = {
    #'20m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_static.csv'),
     '20m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn1.csv'),
    # '20m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn2.csv'),
    #'50m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_static.csv'),
     '50m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn1.csv'),
    # '50m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn2.csv'),
    #'70m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_static.csv'),
     '70m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn1.csv'),
    # '70m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn2.csv'),
}


dict_path_te_clean = {
    #'35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat.csv'),
     '35m_dyn1': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn1.csv'),
    # '35m_dyn2': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn2.csv'),
}



# dict_path_tr_clean = {
#     '20m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_static.csv'),
#     '20m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn1.csv'),
#     '20m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn2.csv'),
#     '50m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_static.csv'),
#     '50m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn1.csv'),
#     '50m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn2.csv'),
#     '70m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_static.csv'),
#     '70m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn1.csv'),
#     '70m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn2.csv'),
# }


# dict_path_te_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat.csv'),
#     '35m_dyn1': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn1.csv'),
#     '35m_dyn2': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn2.csv'),
# }






# dict_path_tr_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/35m_stat_train.csv'),
# }
# dict_path_te_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat_test.csv'),
# }

# %%
selected_columns = [
    'lat','lon','alt','alt_ellipsoid',
    'vel_m_s','vel_n_m_s','vel_e_m_s','vel_d_m_s',
    'cog_rad','timestamp'
]

# %%
dict_df_tr_clean, dict_df_te_clean = {}, {}
for key, p in dict_path_tr_clean.items():
    dict_df_tr_clean[key] = pd.read_csv(p, usecols=selected_columns)
    print(f'{key} ✅ Training data loaded')

for key, p in dict_path_te_clean.items():
    dict_df_te_clean[key] = pd.read_csv(p, usecols=selected_columns)
    print(f'{key} ✅ Test data loaded')
# Out:
# 20m_dyn1 ✅ Training data loaded
# 50m_dyn1 ✅ Training data loaded
# 70m_dyn1 ✅ Training data loaded
# 35m_dyn1 ✅ Test data loaded

# %%
def convert_timestamp_to_seconds(t):
    try:
        m, s = t.split(':')
        return int(m)*60 + float(s)
    except Exception as e:
        return np.nan

def split_by_time_gap(df, time_col='timestamp', threshold=1.0):
    d = df.copy()
    d[time_col] = d[time_col].apply(convert_timestamp_to_seconds)
    d = d.dropna(subset=[time_col]).reset_index(drop=True)
    diffs = d[time_col].diff().abs().fillna(0.0)
    idx = diffs[diffs >= threshold].index.tolist()
    idx = [0] + idx + [len(d)]
    return [ d.iloc[idx[i]:idx[i+1]].reset_index(drop=True) for i in range(len(idx)-1) ]

dict_split_tr_clean = {k: split_by_time_gap(df, threshold=1.0) for k, df in dict_df_tr_clean.items()}
dict_split_te_clean = {k: split_by_time_gap(df, threshold=1.0) for k, df in dict_df_te_clean.items()}

# %%
# Train/Valid 분리 (원본 로직: 마지막 세그먼트만 검증)
dict_split_train_only, dict_split_valid_only = {}, {}
for k, segs in dict_split_tr_clean.items():
    if len(segs) > 1:
        dict_split_train_only[k] = segs[:-1]
        dict_split_valid_only[k] = [segs[-1]]
    else:
        dict_split_train_only[k] = []
        dict_split_valid_only[k] = segs

# %%
def print_segment_counts(dict_split_train_only, dict_split_valid_only, dict_split_te_clean):
    print("\n📦 세그먼트 개수 요약")
    total_train, total_valid, total_test = 0, 0, 0

    print("\n[TRAIN & VALID]")
    for k in dict_split_train_only.keys():
        n_train = len(dict_split_train_only[k])
        n_valid = len(dict_split_valid_only[k])
        total_train += n_train
        total_valid += n_valid
        print(f"{k} → Train seg: {n_train}, Valid seg: {n_valid}")

    print("\n[TEST]")
    for k in dict_split_te_clean.keys():
        n_test = len(dict_split_te_clean[k])
        total_test += n_test
        print(f"{k} → Test seg: {n_test}")

    print("\n📊 전체 합계")
    print(f"Train seg total: {total_train}")
    print(f"Valid seg total: {total_valid}")
    print(f"Test seg total : {total_test}")

# %%
print_segment_counts(dict_split_train_only, dict_split_valid_only, dict_split_te_clean)
# Out:
# 📦 세그먼트 개수 요약
#
# [TRAIN & VALID]
# 20m_dyn1 → Train seg: 3, Valid seg: 1
# 50m_dyn1 → Train seg: 3, Valid seg: 1
# 70m_dyn1 → Train seg: 4, Valid seg: 1
#
# [TEST]
# 35m_dyn1 → Test seg: 4
#
# 📊 전체 합계
# Train seg total: 10
# Valid seg total: 3
# Test seg total : 4

# %%
# ======================================
# 4) 파생 피처 + 윈도잉 (원본 로직 유지)
# ======================================
def add_delta_coordinates(dict_split):
    for segs in dict_split.values():
        for df in segs:
            df['D_lat'] = [0.0] + (df['lat'].diff().fillna(0).tolist())[1:]
            df['D_lon'] = [0.0] + (df['lon'].diff().fillna(0).tolist())[1:]
            df['D_alt'] = [0.0] + (df['alt'].diff().fillna(0).tolist())[1:]

def add_euc_distance(dict_split):
    for segs in dict_split.values():
        for df in segs:
            coords = df[['lat','lon','alt']].to_numpy()
            distances = [0.0]
            for i in range(1, len(coords)):
                distances.append(euclidean_distances([coords[i-1]],[coords[i]])[0][0])
            df['d_pos'] = distances

def add_time_gap(dict_split):
    for segs in dict_split.values():
        for df in segs:
            df['time_gap'] = [0.0] + (df['timestamp'].diff().fillna(0).tolist())[1:]

for d in [dict_split_train_only, dict_split_valid_only, dict_split_te_clean]:
    add_delta_coordinates(d); add_euc_distance(d); add_time_gap(d)

# %%
import numpy as np

# Define window size
window_size = 5 # 기본 5개
# Real 5개를 가지고 6번째 예측
#2,3,4,5,6 을보고 7을 예측

# Define input features and target features
input_features =  ['vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'vel_d_m_s', 'cog_rad', 'D_lat', 'D_lon', 'D_alt', 'd_pos','time_gap']
# 'vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'vel_d_m_s', 'cog_rad', 'D_lat', 'D_lon', 'D_alt', 'd_pos','time_gap'

target_features = ['D_alt']  # target to predict

# %%
def create_sequence_label_tensors(dict_split, window_size):
    X_all, y_all = [], []
    for segs in dict_split.values():
        for df in segs:
            if len(df) <= window_size: continue
            data   = df[input_features].to_numpy()
            labels = df[target_features].to_numpy()
            for i in range(len(df) - window_size):
                X_all.append(data[i : i + window_size])
                y_all.append(labels[i + window_size])
    return np.array(X_all), np.array(y_all)

X_train, y_train = create_sequence_label_tensors(dict_split_train_only, window_size)
X_valid, y_valid = create_sequence_label_tensors(dict_split_valid_only, window_size)
X_test,  y_test  = create_sequence_label_tensors(dict_split_te_clean,  window_size)

print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_valid: {X_valid.shape}, y_valid: {y_valid.shape}")
print(f"X_test : {X_test.shape},  y_test : {y_test.shape}")
# Out:
# X_train: (4394, 5, 10), y_train: (4394, 1)
# X_valid: (1347, 5, 10), y_valid: (1347, 1)
# X_test : (2100, 5, 10),  y_test : (2100, 1)

# %%
# ======================================
# 5) DataLoader (AE / 지도학습)
# ======================================
def make_loader_ae(X, batch_size=64, shuffle=True):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    return DataLoader(TensorDataset(X_tensor, X_tensor), batch_size=batch_size, shuffle=shuffle)

def make_loader_sup(X, y, batch_size=64, shuffle=True):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)
    return DataLoader(TensorDataset(X_tensor, y_tensor), batch_size=batch_size, shuffle=shuffle)

train_loader_ae = make_loader_ae(X_train, batch_size=64, shuffle=True)
valid_loader_ae = make_loader_ae(X_valid, batch_size=64, shuffle=False)
train_loader_sup = make_loader_sup(X_train, y_train, batch_size=64, shuffle=True)
valid_loader_sup = make_loader_sup(X_valid, y_valid, batch_size=64, shuffle=False)
test_loader_sup  = make_loader_sup(X_test,  y_test,  batch_size=64, shuffle=False)

input_dim = X_train.shape[-1]
seq_len   = X_train.shape[1]

# %%
import torch.nn as nn

class LSTMAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_layers=2, dropout=0.2, seq_len=5):
        super().__init__()
        self.seq_len = seq_len
        self.input_dim = input_dim
        self.encoder = nn.LSTM(
            input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
            batch_first=True, dropout=dropout if num_layers>1 else 0.0
        )
        self.decoder = nn.LSTM(
            input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
            batch_first=True, dropout=dropout if num_layers>1 else 0.0
        )
        self.proj = nn.Linear(hidden_dim, input_dim)

    def forward(self, x):
        _, (h, c) = self.encoder(x)
        B = x.size(0)
        dec_in = torch.zeros(B, self.seq_len, self.input_dim, device=x.device)
        dec_out, _ = self.decoder(dec_in, (h, c))
        return self.proj(dec_out)

def train_ae_with_early_stop(
    input_dim, seq_len, train_loader, valid_loader,
    n_epochs=1000, lr=1e-3, hidden_dim=128, num_layers=2, dropout=0.2,
    patience=40, device=device
):
    model = LSTMAutoencoder(input_dim, hidden_dim, num_layers, dropout, seq_len).to(device)
    opt = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
    crit = nn.MSELoss()

    best_mse = float('inf')
    best_state = None
    best_epoch = -1
    no_imp = 0

    for ep in range(1, n_epochs+1):
        # Train
        model.train(); tr=[]
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            xhat = model(xb)
            loss = crit(xhat, yb)
            loss.backward()
            opt.step()
            tr.append(loss.item())
        tr_mse = float(np.mean(tr)) if tr else np.nan

        # Valid
        model.eval(); va=[]
        with torch.no_grad():
            for xb, yb in valid_loader:
                xb, yb = xb.to(device), yb.to(device)
                va.append(crit(model(xb), yb).item())
        va_mse = float(np.mean(va)) if va else np.nan

        if (ep % 5 == 0) or (va_mse < best_mse):
            print(f"[AE] Epoch {ep}/{n_epochs} | Train MSE {tr_mse:.6f} | Valid MSE {va_mse:.6f} | Best {best_mse:.6f} (ep {best_epoch})")

        if va_mse < best_mse:
            best_mse = va_mse
            best_state = {k:v.cpu() for k,v in model.state_dict().items()}
            best_epoch = ep
            no_imp = 0
            print("[AE] 🎯 New Best Valid MSE!")
        else:
            no_imp += 1
            if no_imp >= patience:
                print(f"[AE] ⏹️ Early stopping at epoch {ep}")
                break

    if best_state is not None:
        model.load_state_dict(best_state)
    print(f"[AE] ✅ Finished. Best Valid MSE: {best_mse:.6f} at epoch {best_epoch}")
    return model, best_mse, best_epoch

# %%
lstm_hidden_dim = 128
lstm_layers     = 2
dropout         = 0.2
ae_model, best_mse, best_ep = train_ae_with_early_stop(
    input_dim=input_dim, seq_len=seq_len,
    train_loader=train_loader_ae, valid_loader=valid_loader_ae,
    n_epochs=1000, lr=0.00001,
    hidden_dim=lstm_hidden_dim, num_layers=lstm_layers, dropout=dropout,
    patience=200, device=device
)
# Out:
# [AE] Epoch 1/1000 | Train MSE 1450.617098 | Valid MSE 1456.285933 | Best inf (ep -1)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 2/1000 | Train MSE 1452.719031 | Valid MSE 1455.262130 | Best 1456.285933 (ep 1)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 3/1000 | Train MSE 1449.276606 | Valid MSE 1454.001024 | Best 1455.262130 (ep 2)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 4/1000 | Train MSE 1448.518338 | Valid MSE 1452.265248 | Best 1454.001024 (ep 3)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 5/1000 | Train MSE 1445.094222 | Valid MSE 1449.597061 | Best 1452.265248 (ep 4)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 6/1000 | Train MSE 1444.251240 | Valid MSE 1444.970332 | Best 1449.597061 (ep 5)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 7/1000 | Train MSE 1437.353503 | Valid MSE 1436.367258 | Best 1444.970332 (ep 6)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 8/1000 | Train MSE 1424.294595 | Valid MSE 1422.271829 | Best 1436.367258 (ep 7)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 9/1000 | Train MSE 1407.122344 | Valid MSE 1407.785260 | Best 1422.271829 (ep 8)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 10/1000 | Train MSE 1396.572114 | Valid MSE 1397.034238 | Best 1407.785260 (ep 9)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 11/1000 | Train MSE 1385.439910 | Valid MSE 1389.130359 | Best 1397.034238 (ep 10)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 12/1000 | Train MSE 1381.721370 | Valid MSE 1382.827483 | Best 1389.130359 (ep 11)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 13/1000 | Train MSE 1373.788633 | Valid MSE 1377.585807 | Best 1382.827483 (ep 12)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 14/1000 | Train MSE 1365.990383 | Valid MSE 1373.096837 | Best 1377.585807 (ep 13)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 15/1000 | Train MSE 1363.078166 | Valid MSE 1369.134442 | Best 1373.096837 (ep 14)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 16/1000 | Train MSE 1361.819980 | Valid MSE 1365.614748 | Best 1369.134442 (ep 15)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 17/1000 | Train MSE 1354.799314 | Valid MSE 1362.416290 | Best 1365.614748 (ep 16)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 18/1000 | Train MSE 1351.596942 | Valid MSE 1359.483772 | Best 1362.416290 (ep 17)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 19/1000 | Train MSE 1351.140454 | Valid MSE 1356.762178 | Best 1359.483772 (ep 18)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 20/1000 | Train MSE 1346.937500 | Valid MSE 1354.191933 | Best 1356.762178 (ep 19)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 21/1000 | Train MSE 1349.364129 | Valid MSE 1351.766988 | Best 1354.191933 (ep 20)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 22/1000 | Train MSE 1340.332937 | Valid MSE 1349.435336 | Best 1351.766988 (ep 21)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 23/1000 | Train MSE 1339.341105 | Valid MSE 1347.196285 | Best 1349.435336 (ep 22)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 24/1000 | Train MSE 1336.390123 | Valid MSE 1345.029596 | Best 1347.196285 (ep 23)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 25/1000 | Train MSE 1336.176228 | Valid MSE 1342.882072 | Best 1345.029596 (ep 24)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 26/1000 | Train MSE 1335.909669 | Valid MSE 1340.772644 | Best 1342.882072 (ep 25)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 27/1000 | Train MSE 1328.955341 | Valid MSE 1338.719531 | Best 1340.772644 (ep 26)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 28/1000 | Train MSE 1328.845147 | Valid MSE 1336.752076 | Best 1338.719531 (ep 27)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 29/1000 | Train MSE 1328.160865 | Valid MSE 1334.841582 | Best 1336.752076 (ep 28)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 30/1000 | Train MSE 1325.606929 | Valid MSE 1332.975941 | Best 1334.841582 (ep 29)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 31/1000 | Train MSE 1322.564388 | Valid MSE 1331.196934 | Best 1332.975941 (ep 30)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 32/1000 | Train MSE 1320.405935 | Valid MSE 1329.462666 | Best 1331.196934 (ep 31)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 33/1000 | Train MSE 1320.105655 | Valid MSE 1327.782717 | Best 1329.462666 (ep 32)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 34/1000 | Train MSE 1317.278207 | Valid MSE 1326.132317 | Best 1327.782717 (ep 33)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 35/1000 | Train MSE 1316.766358 | Valid MSE 1324.562563 | Best 1326.132317 (ep 34)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 36/1000 | Train MSE 1313.613411 | Valid MSE 1323.036463 | Best 1324.562563 (ep 35)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 37/1000 | Train MSE 1311.464692 | Valid MSE 1321.540615 | Best 1323.036463 (ep 36)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 38/1000 | Train MSE 1310.298253 | Valid MSE 1320.081530 | Best 1321.540615 (ep 37)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 39/1000 | Train MSE 1310.411120 | Valid MSE 1318.653868 | Best 1320.081530 (ep 38)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 40/1000 | Train MSE 1308.702877 | Valid MSE 1317.239902 | Best 1318.653868 (ep 39)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 41/1000 | Train MSE 1309.833096 | Valid MSE 1315.844116 | Best 1317.239902 (ep 40)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 42/1000 | Train MSE 1307.315238 | Valid MSE 1314.475067 | Best 1315.844116 (ep 41)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 43/1000 | Train MSE 1305.954130 | Valid MSE 1313.121382 | Best 1314.475067 (ep 42)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 44/1000 | Train MSE 1302.792015 | Valid MSE 1311.780929 | Best 1313.121382 (ep 43)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 45/1000 | Train MSE 1305.033918 | Valid MSE 1310.458076 | Best 1311.780929 (ep 44)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 46/1000 | Train MSE 1300.653164 | Valid MSE 1309.132176 | Best 1310.458076 (ep 45)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 47/1000 | Train MSE 1299.115105 | Valid MSE 1307.815040 | Best 1309.132176 (ep 46)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 48/1000 | Train MSE 1296.300674 | Valid MSE 1306.503982 | Best 1307.815040 (ep 47)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 49/1000 | Train MSE 1296.001354 | Valid MSE 1305.197852 | Best 1306.503982 (ep 48)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 50/1000 | Train MSE 1292.915046 | Valid MSE 1303.898244 | Best 1305.197852 (ep 49)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 51/1000 | Train MSE 1292.409870 | Valid MSE 1302.603406 | Best 1303.898244 (ep 50)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 52/1000 | Train MSE 1292.106342 | Valid MSE 1301.309508 | Best 1302.603406 (ep 51)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 53/1000 | Train MSE 1291.203496 | Valid MSE 1300.059940 | Best 1301.309508 (ep 52)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 54/1000 | Train MSE 1292.442430 | Valid MSE 1298.824474 | Best 1300.059940 (ep 53)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 55/1000 | Train MSE 1286.290332 | Valid MSE 1297.589494 | Best 1298.824474 (ep 54)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 56/1000 | Train MSE 1284.673926 | Valid MSE 1296.367580 | Best 1297.589494 (ep 55)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 57/1000 | Train MSE 1285.599472 | Valid MSE 1295.150794 | Best 1296.367580 (ep 56)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 58/1000 | Train MSE 1285.654500 | Valid MSE 1293.957582 | Best 1295.150794 (ep 57)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 59/1000 | Train MSE 1281.200891 | Valid MSE 1292.757009 | Best 1293.957582 (ep 58)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 60/1000 | Train MSE 1280.614253 | Valid MSE 1291.564244 | Best 1292.757009 (ep 59)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 61/1000 | Train MSE 1281.864745 | Valid MSE 1290.363860 | Best 1291.564244 (ep 60)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 62/1000 | Train MSE 1279.650858 | Valid MSE 1289.144400 | Best 1290.363860 (ep 61)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 63/1000 | Train MSE 1278.124264 | Valid MSE 1287.949725 | Best 1289.144400 (ep 62)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 64/1000 | Train MSE 1279.373545 | Valid MSE 1286.778633 | Best 1287.949725 (ep 63)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 65/1000 | Train MSE 1274.829275 | Valid MSE 1285.585327 | Best 1286.778633 (ep 64)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 66/1000 | Train MSE 1273.760098 | Valid MSE 1284.416922 | Best 1285.585327 (ep 65)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 67/1000 | Train MSE 1274.986445 | Valid MSE 1283.239839 | Best 1284.416922 (ep 66)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 68/1000 | Train MSE 1273.193335 | Valid MSE 1282.078905 | Best 1283.239839 (ep 67)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 69/1000 | Train MSE 1268.462047 | Valid MSE 1280.911945 | Best 1282.078905 (ep 68)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 70/1000 | Train MSE 1267.754758 | Valid MSE 1279.751330 | Best 1280.911945 (ep 69)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 71/1000 | Train MSE 1269.738318 | Valid MSE 1278.593422 | Best 1279.751330 (ep 70)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 72/1000 | Train MSE 1266.992994 | Valid MSE 1277.428999 | Best 1278.593422 (ep 71)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 73/1000 | Train MSE 1276.135346 | Valid MSE 1276.286542 | Best 1277.428999 (ep 72)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 74/1000 | Train MSE 1266.513134 | Valid MSE 1275.122914 | Best 1276.286542 (ep 73)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 75/1000 | Train MSE 1267.569595 | Valid MSE 1273.970528 | Best 1275.122914 (ep 74)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 76/1000 | Train MSE 1262.942082 | Valid MSE 1272.800165 | Best 1273.970528 (ep 75)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 77/1000 | Train MSE 1260.099779 | Valid MSE 1271.627716 | Best 1272.800165 (ep 76)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 78/1000 | Train MSE 1262.757613 | Valid MSE 1270.478855 | Best 1271.627716 (ep 77)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 79/1000 | Train MSE 1258.249015 | Valid MSE 1269.332658 | Best 1270.478855 (ep 78)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 80/1000 | Train MSE 1256.454018 | Valid MSE 1268.189973 | Best 1269.332658 (ep 79)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 81/1000 | Train MSE 1255.875502 | Valid MSE 1267.051893 | Best 1268.189973 (ep 80)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 82/1000 | Train MSE 1256.241156 | Valid MSE 1265.909251 | Best 1267.051893 (ep 81)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 83/1000 | Train MSE 1253.851763 | Valid MSE 1264.780185 | Best 1265.909251 (ep 82)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 84/1000 | Train MSE 1254.143494 | Valid MSE 1263.639549 | Best 1264.780185 (ep 83)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 85/1000 | Train MSE 1253.906458 | Valid MSE 1262.493996 | Best 1263.639549 (ep 84)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 86/1000 | Train MSE 1251.843521 | Valid MSE 1261.363138 | Best 1262.493996 (ep 85)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 87/1000 | Train MSE 1252.555607 | Valid MSE 1260.235722 | Best 1261.363138 (ep 86)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 88/1000 | Train MSE 1251.950800 | Valid MSE 1259.102154 | Best 1260.235722 (ep 87)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 89/1000 | Train MSE 1247.995009 | Valid MSE 1257.982296 | Best 1259.102154 (ep 88)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 90/1000 | Train MSE 1246.792265 | Valid MSE 1256.871310 | Best 1257.982296 (ep 89)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 91/1000 | Train MSE 1247.471858 | Valid MSE 1255.753417 | Best 1256.871310 (ep 90)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 92/1000 | Train MSE 1244.182406 | Valid MSE 1254.641372 | Best 1255.753417 (ep 91)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 93/1000 | Train MSE 1241.525657 | Valid MSE 1253.505145 | Best 1254.641372 (ep 92)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 94/1000 | Train MSE 1243.541797 | Valid MSE 1252.354199 | Best 1253.505145 (ep 93)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 95/1000 | Train MSE 1241.098566 | Valid MSE 1251.251924 | Best 1252.354199 (ep 94)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 96/1000 | Train MSE 1238.923914 | Valid MSE 1250.131073 | Best 1251.251924 (ep 95)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 97/1000 | Train MSE 1238.101560 | Valid MSE 1249.029397 | Best 1250.131073 (ep 96)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 98/1000 | Train MSE 1236.725909 | Valid MSE 1247.937924 | Best 1249.029397 (ep 97)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 99/1000 | Train MSE 1233.212610 | Valid MSE 1246.832606 | Best 1247.937924 (ep 98)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 100/1000 | Train MSE 1235.407430 | Valid MSE 1245.730486 | Best 1246.832606 (ep 99)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 101/1000 | Train MSE 1232.955236 | Valid MSE 1244.640157 | Best 1245.730486 (ep 100)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 102/1000 | Train MSE 1231.761826 | Valid MSE 1243.548042 | Best 1244.640157 (ep 101)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 103/1000 | Train MSE 1231.816841 | Valid MSE 1242.456402 | Best 1243.548042 (ep 102)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 104/1000 | Train MSE 1229.914207 | Valid MSE 1241.374093 | Best 1242.456402 (ep 103)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 105/1000 | Train MSE 1229.266991 | Valid MSE 1240.284193 | Best 1241.374093 (ep 104)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 106/1000 | Train MSE 1228.617997 | Valid MSE 1239.203354 | Best 1240.284193 (ep 105)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 107/1000 | Train MSE 1227.022957 | Valid MSE 1238.119853 | Best 1239.203354 (ep 106)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 108/1000 | Train MSE 1224.561258 | Valid MSE 1237.034315 | Best 1238.119853 (ep 107)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 109/1000 | Train MSE 1224.493441 | Valid MSE 1235.949038 | Best 1237.034315 (ep 108)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 110/1000 | Train MSE 1224.119836 | Valid MSE 1234.860188 | Best 1235.949038 (ep 109)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 111/1000 | Train MSE 1222.091311 | Valid MSE 1233.791307 | Best 1234.860188 (ep 110)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 112/1000 | Train MSE 1222.383090 | Valid MSE 1232.716429 | Best 1233.791307 (ep 111)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 113/1000 | Train MSE 1219.755407 | Valid MSE 1231.646265 | Best 1232.716429 (ep 112)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 114/1000 | Train MSE 1219.833217 | Valid MSE 1230.549380 | Best 1231.646265 (ep 113)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 115/1000 | Train MSE 1218.703032 | Valid MSE 1229.474162 | Best 1230.549380 (ep 114)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 116/1000 | Train MSE 1217.893412 | Valid MSE 1228.386188 | Best 1229.474162 (ep 115)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 117/1000 | Train MSE 1216.316612 | Valid MSE 1227.325028 | Best 1228.386188 (ep 116)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 118/1000 | Train MSE 1220.018725 | Valid MSE 1226.261437 | Best 1227.325028 (ep 117)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 119/1000 | Train MSE 1215.928583 | Valid MSE 1225.193915 | Best 1226.261437 (ep 118)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 120/1000 | Train MSE 1215.286938 | Valid MSE 1224.130300 | Best 1225.193915 (ep 119)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 121/1000 | Train MSE 1211.910356 | Valid MSE 1223.075050 | Best 1224.130300 (ep 120)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 122/1000 | Train MSE 1210.410130 | Valid MSE 1222.021182 | Best 1223.075050 (ep 121)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 123/1000 | Train MSE 1211.039770 | Valid MSE 1220.967273 | Best 1222.021182 (ep 122)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 124/1000 | Train MSE 1207.516420 | Valid MSE 1219.913566 | Best 1220.967273 (ep 123)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 125/1000 | Train MSE 1206.704408 | Valid MSE 1218.861342 | Best 1219.913566 (ep 124)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 126/1000 | Train MSE 1206.057393 | Valid MSE 1217.818494 | Best 1218.861342 (ep 125)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 127/1000 | Train MSE 1203.321137 | Valid MSE 1216.764253 | Best 1217.818494 (ep 126)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 128/1000 | Train MSE 1206.489210 | Valid MSE 1215.725055 | Best 1216.764253 (ep 127)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 129/1000 | Train MSE 1203.498289 | Valid MSE 1214.675153 | Best 1215.725055 (ep 128)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 130/1000 | Train MSE 1200.646261 | Valid MSE 1213.632309 | Best 1214.675153 (ep 129)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 131/1000 | Train MSE 1200.193136 | Valid MSE 1212.599606 | Best 1213.632309 (ep 130)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 132/1000 | Train MSE 1199.957178 | Valid MSE 1211.553078 | Best 1212.599606 (ep 131)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 133/1000 | Train MSE 1197.902685 | Valid MSE 1210.528676 | Best 1211.553078 (ep 132)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 134/1000 | Train MSE 1196.058942 | Valid MSE 1209.492159 | Best 1210.528676 (ep 133)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 135/1000 | Train MSE 1195.297235 | Valid MSE 1208.453339 | Best 1209.492159 (ep 134)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 136/1000 | Train MSE 1196.444566 | Valid MSE 1207.425255 | Best 1208.453339 (ep 135)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 137/1000 | Train MSE 1193.718326 | Valid MSE 1206.389359 | Best 1207.425255 (ep 136)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 138/1000 | Train MSE 1193.583711 | Valid MSE 1205.359464 | Best 1206.389359 (ep 137)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 139/1000 | Train MSE 1191.348921 | Valid MSE 1204.334338 | Best 1205.359464 (ep 138)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 140/1000 | Train MSE 1190.732566 | Valid MSE 1203.304775 | Best 1204.334338 (ep 139)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 141/1000 | Train MSE 1188.544649 | Valid MSE 1202.279935 | Best 1203.304775 (ep 140)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 142/1000 | Train MSE 1190.486442 | Valid MSE 1201.261712 | Best 1202.279935 (ep 141)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 143/1000 | Train MSE 1189.482369 | Valid MSE 1200.237619 | Best 1201.261712 (ep 142)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 144/1000 | Train MSE 1189.085609 | Valid MSE 1199.210184 | Best 1200.237619 (ep 143)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 145/1000 | Train MSE 1184.717258 | Valid MSE 1198.173802 | Best 1199.210184 (ep 144)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 146/1000 | Train MSE 1186.466914 | Valid MSE 1197.160299 | Best 1198.173802 (ep 145)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 147/1000 | Train MSE 1185.877352 | Valid MSE 1196.149302 | Best 1197.160299 (ep 146)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 148/1000 | Train MSE 1185.063050 | Valid MSE 1195.131355 | Best 1196.149302 (ep 147)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 149/1000 | Train MSE 1181.044581 | Valid MSE 1194.113504 | Best 1195.131355 (ep 148)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 150/1000 | Train MSE 1181.262652 | Valid MSE 1193.094872 | Best 1194.113504 (ep 149)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 151/1000 | Train MSE 1180.245844 | Valid MSE 1192.081756 | Best 1193.094872 (ep 150)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 152/1000 | Train MSE 1180.408236 | Valid MSE 1191.064527 | Best 1192.081756 (ep 151)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 153/1000 | Train MSE 1177.770724 | Valid MSE 1190.050538 | Best 1191.064527 (ep 152)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 154/1000 | Train MSE 1178.778357 | Valid MSE 1189.044016 | Best 1190.050538 (ep 153)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 155/1000 | Train MSE 1177.053923 | Valid MSE 1188.029142 | Best 1189.044016 (ep 154)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 156/1000 | Train MSE 1175.032943 | Valid MSE 1187.013005 | Best 1188.029142 (ep 155)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 157/1000 | Train MSE 1174.057664 | Valid MSE 1186.011392 | Best 1187.013005 (ep 156)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 158/1000 | Train MSE 1172.194038 | Valid MSE 1184.999868 | Best 1186.011392 (ep 157)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 159/1000 | Train MSE 1170.363263 | Valid MSE 1183.990567 | Best 1184.999868 (ep 158)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 160/1000 | Train MSE 1171.393755 | Valid MSE 1182.986898 | Best 1183.990567 (ep 159)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 161/1000 | Train MSE 1168.457635 | Valid MSE 1181.985107 | Best 1182.986898 (ep 160)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 162/1000 | Train MSE 1167.344274 | Valid MSE 1180.988516 | Best 1181.985107 (ep 161)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 163/1000 | Train MSE 1166.410583 | Valid MSE 1179.980750 | Best 1180.988516 (ep 162)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 164/1000 | Train MSE 1167.544350 | Valid MSE 1178.985380 | Best 1179.980750 (ep 163)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 165/1000 | Train MSE 1164.838559 | Valid MSE 1177.984323 | Best 1178.985380 (ep 164)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 166/1000 | Train MSE 1165.054439 | Valid MSE 1176.990522 | Best 1177.984323 (ep 165)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 167/1000 | Train MSE 1166.896036 | Valid MSE 1175.992779 | Best 1176.990522 (ep 166)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 168/1000 | Train MSE 1161.252143 | Valid MSE 1174.987434 | Best 1175.992779 (ep 167)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 169/1000 | Train MSE 1160.085487 | Valid MSE 1173.996124 | Best 1174.987434 (ep 168)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 170/1000 | Train MSE 1160.653759 | Valid MSE 1172.998696 | Best 1173.996124 (ep 169)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 171/1000 | Train MSE 1159.874222 | Valid MSE 1172.009752 | Best 1172.998696 (ep 170)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 172/1000 | Train MSE 1159.706524 | Valid MSE 1171.009358 | Best 1172.009752 (ep 171)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 173/1000 | Train MSE 1160.719467 | Valid MSE 1170.016499 | Best 1171.009358 (ep 172)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 174/1000 | Train MSE 1154.964513 | Valid MSE 1169.024623 | Best 1170.016499 (ep 173)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 175/1000 | Train MSE 1158.808562 | Valid MSE 1168.031751 | Best 1169.024623 (ep 174)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 176/1000 | Train MSE 1154.370501 | Valid MSE 1167.046409 | Best 1168.031751 (ep 175)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 177/1000 | Train MSE 1152.761196 | Valid MSE 1166.059837 | Best 1167.046409 (ep 176)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 178/1000 | Train MSE 1153.592979 | Valid MSE 1165.070630 | Best 1166.059837 (ep 177)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 179/1000 | Train MSE 1153.660448 | Valid MSE 1164.088653 | Best 1165.070630 (ep 178)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 180/1000 | Train MSE 1150.589635 | Valid MSE 1163.099840 | Best 1164.088653 (ep 179)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 181/1000 | Train MSE 1148.784778 | Valid MSE 1162.124949 | Best 1163.099840 (ep 180)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 182/1000 | Train MSE 1148.582106 | Valid MSE 1161.145770 | Best 1162.124949 (ep 181)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 183/1000 | Train MSE 1147.207497 | Valid MSE 1160.153720 | Best 1161.145770 (ep 182)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 184/1000 | Train MSE 1145.693142 | Valid MSE 1159.189892 | Best 1160.153720 (ep 183)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 185/1000 | Train MSE 1144.481095 | Valid MSE 1158.203097 | Best 1159.189892 (ep 184)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 186/1000 | Train MSE 1142.881604 | Valid MSE 1157.232353 | Best 1158.203097 (ep 185)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 187/1000 | Train MSE 1142.861662 | Valid MSE 1156.258427 | Best 1157.232353 (ep 186)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 188/1000 | Train MSE 1143.022602 | Valid MSE 1155.284084 | Best 1156.258427 (ep 187)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 189/1000 | Train MSE 1139.814071 | Valid MSE 1154.310956 | Best 1155.284084 (ep 188)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 190/1000 | Train MSE 1140.354960 | Valid MSE 1153.348934 | Best 1154.310956 (ep 189)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 191/1000 | Train MSE 1140.918358 | Valid MSE 1152.376309 | Best 1153.348934 (ep 190)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 192/1000 | Train MSE 1139.347682 | Valid MSE 1151.410970 | Best 1152.376309 (ep 191)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 193/1000 | Train MSE 1137.896700 | Valid MSE 1150.440889 | Best 1151.410970 (ep 192)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 194/1000 | Train MSE 1138.563376 | Valid MSE 1149.468075 | Best 1150.440889 (ep 193)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 195/1000 | Train MSE 1141.157692 | Valid MSE 1148.503029 | Best 1149.468075 (ep 194)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 196/1000 | Train MSE 1135.122858 | Valid MSE 1147.534048 | Best 1148.503029 (ep 195)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 197/1000 | Train MSE 1132.663862 | Valid MSE 1146.565982 | Best 1147.534048 (ep 196)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 198/1000 | Train MSE 1133.437695 | Valid MSE 1145.613972 | Best 1146.565982 (ep 197)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 199/1000 | Train MSE 1136.240274 | Valid MSE 1144.654013 | Best 1145.613972 (ep 198)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 200/1000 | Train MSE 1131.953129 | Valid MSE 1143.691378 | Best 1144.654013 (ep 199)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 201/1000 | Train MSE 1129.244816 | Valid MSE 1142.736865 | Best 1143.691378 (ep 200)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 202/1000 | Train MSE 1128.095601 | Valid MSE 1141.782922 | Best 1142.736865 (ep 201)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 203/1000 | Train MSE 1126.973175 | Valid MSE 1140.822403 | Best 1141.782922 (ep 202)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 204/1000 | Train MSE 1126.742440 | Valid MSE 1139.870562 | Best 1140.822403 (ep 203)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 205/1000 | Train MSE 1127.391388 | Valid MSE 1138.920692 | Best 1139.870562 (ep 204)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 206/1000 | Train MSE 1124.598309 | Valid MSE 1137.961566 | Best 1138.920692 (ep 205)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 207/1000 | Train MSE 1128.176913 | Valid MSE 1137.014200 | Best 1137.961566 (ep 206)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 208/1000 | Train MSE 1121.641760 | Valid MSE 1136.058306 | Best 1137.014200 (ep 207)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 209/1000 | Train MSE 1120.213784 | Valid MSE 1135.109378 | Best 1136.058306 (ep 208)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 210/1000 | Train MSE 1121.926599 | Valid MSE 1134.172111 | Best 1135.109378 (ep 209)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 211/1000 | Train MSE 1120.021018 | Valid MSE 1133.220560 | Best 1134.172111 (ep 210)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 212/1000 | Train MSE 1120.757721 | Valid MSE 1132.270019 | Best 1133.220560 (ep 211)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 213/1000 | Train MSE 1116.552458 | Valid MSE 1131.324160 | Best 1132.270019 (ep 212)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 214/1000 | Train MSE 1115.346374 | Valid MSE 1130.385635 | Best 1131.324160 (ep 213)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 215/1000 | Train MSE 1115.447335 | Valid MSE 1129.437799 | Best 1130.385635 (ep 214)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 216/1000 | Train MSE 1113.862046 | Valid MSE 1128.501732 | Best 1129.437799 (ep 215)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 217/1000 | Train MSE 1114.308743 | Valid MSE 1127.560690 | Best 1128.501732 (ep 216)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 218/1000 | Train MSE 1112.030562 | Valid MSE 1126.618510 | Best 1127.560690 (ep 217)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 219/1000 | Train MSE 1111.198159 | Valid MSE 1125.687915 | Best 1126.618510 (ep 218)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 220/1000 | Train MSE 1111.355759 | Valid MSE 1124.755735 | Best 1125.687915 (ep 219)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 221/1000 | Train MSE 1108.648476 | Valid MSE 1123.813820 | Best 1124.755735 (ep 220)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 222/1000 | Train MSE 1111.820183 | Valid MSE 1122.884193 | Best 1123.813820 (ep 221)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 223/1000 | Train MSE 1108.386424 | Valid MSE 1121.943770 | Best 1122.884193 (ep 222)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 224/1000 | Train MSE 1106.151124 | Valid MSE 1121.008248 | Best 1121.943770 (ep 223)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 225/1000 | Train MSE 1109.941937 | Valid MSE 1120.080228 | Best 1121.008248 (ep 224)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 226/1000 | Train MSE 1106.481741 | Valid MSE 1119.145090 | Best 1120.080228 (ep 225)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 227/1000 | Train MSE 1106.017078 | Valid MSE 1118.214883 | Best 1119.145090 (ep 226)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 228/1000 | Train MSE 1103.982402 | Valid MSE 1117.280332 | Best 1118.214883 (ep 227)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 229/1000 | Train MSE 1101.544854 | Valid MSE 1116.351444 | Best 1117.280332 (ep 228)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 230/1000 | Train MSE 1101.237954 | Valid MSE 1115.427918 | Best 1116.351444 (ep 229)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 231/1000 | Train MSE 1100.559225 | Valid MSE 1114.501772 | Best 1115.427918 (ep 230)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 232/1000 | Train MSE 1100.591816 | Valid MSE 1113.582902 | Best 1114.501772 (ep 231)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 233/1000 | Train MSE 1098.507029 | Valid MSE 1112.652049 | Best 1113.582902 (ep 232)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 234/1000 | Train MSE 1097.294825 | Valid MSE 1111.724267 | Best 1112.652049 (ep 233)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 235/1000 | Train MSE 1096.477113 | Valid MSE 1110.802422 | Best 1111.724267 (ep 234)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 236/1000 | Train MSE 1096.141485 | Valid MSE 1109.883111 | Best 1110.802422 (ep 235)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 237/1000 | Train MSE 1095.430082 | Valid MSE 1108.965545 | Best 1109.883111 (ep 236)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 238/1000 | Train MSE 1093.732085 | Valid MSE 1108.040175 | Best 1108.965545 (ep 237)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 239/1000 | Train MSE 1093.324052 | Valid MSE 1107.122099 | Best 1108.040175 (ep 238)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 240/1000 | Train MSE 1091.995114 | Valid MSE 1106.200722 | Best 1107.122099 (ep 239)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 241/1000 | Train MSE 1091.792106 | Valid MSE 1105.282364 | Best 1106.200722 (ep 240)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 242/1000 | Train MSE 1091.098995 | Valid MSE 1104.372219 | Best 1105.282364 (ep 241)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 243/1000 | Train MSE 1087.966308 | Valid MSE 1103.454987 | Best 1104.372219 (ep 242)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 244/1000 | Train MSE 1089.786382 | Valid MSE 1102.548778 | Best 1103.454987 (ep 243)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 245/1000 | Train MSE 1087.099312 | Valid MSE 1101.631490 | Best 1102.548778 (ep 244)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 246/1000 | Train MSE 1088.600109 | Valid MSE 1100.724138 | Best 1101.631490 (ep 245)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 247/1000 | Train MSE 1083.641565 | Valid MSE 1099.803104 | Best 1100.724138 (ep 246)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 248/1000 | Train MSE 1087.233178 | Valid MSE 1098.903527 | Best 1099.803104 (ep 247)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 249/1000 | Train MSE 1083.181021 | Valid MSE 1097.987054 | Best 1098.903527 (ep 248)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 250/1000 | Train MSE 1081.765280 | Valid MSE 1097.075590 | Best 1097.987054 (ep 249)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 251/1000 | Train MSE 1081.371439 | Valid MSE 1096.174347 | Best 1097.075590 (ep 250)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 252/1000 | Train MSE 1081.733406 | Valid MSE 1095.271609 | Best 1096.174347 (ep 251)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 253/1000 | Train MSE 1085.432091 | Valid MSE 1094.364613 | Best 1095.271609 (ep 252)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 254/1000 | Train MSE 1079.223354 | Valid MSE 1093.463044 | Best 1094.364613 (ep 253)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 255/1000 | Train MSE 1078.350934 | Valid MSE 1092.557052 | Best 1093.463044 (ep 254)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 256/1000 | Train MSE 1079.948177 | Valid MSE 1091.656770 | Best 1092.557052 (ep 255)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 257/1000 | Train MSE 1077.377331 | Valid MSE 1090.751894 | Best 1091.656770 (ep 256)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 258/1000 | Train MSE 1075.772708 | Valid MSE 1089.860153 | Best 1090.751894 (ep 257)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 259/1000 | Train MSE 1073.845547 | Valid MSE 1088.946280 | Best 1089.860153 (ep 258)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 260/1000 | Train MSE 1072.868367 | Valid MSE 1088.051297 | Best 1088.946280 (ep 259)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 261/1000 | Train MSE 1071.477273 | Valid MSE 1087.153576 | Best 1088.051297 (ep 260)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 262/1000 | Train MSE 1070.747927 | Valid MSE 1086.263123 | Best 1087.153576 (ep 261)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 263/1000 | Train MSE 1072.103375 | Valid MSE 1085.367878 | Best 1086.263123 (ep 262)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 264/1000 | Train MSE 1068.303103 | Valid MSE 1084.470502 | Best 1085.367878 (ep 263)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 265/1000 | Train MSE 1070.121579 | Valid MSE 1083.584324 | Best 1084.470502 (ep 264)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 266/1000 | Train MSE 1067.526474 | Valid MSE 1082.690193 | Best 1083.584324 (ep 265)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 267/1000 | Train MSE 1065.676658 | Valid MSE 1081.795387 | Best 1082.690193 (ep 266)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 268/1000 | Train MSE 1065.123672 | Valid MSE 1080.900908 | Best 1081.795387 (ep 267)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 269/1000 | Train MSE 1068.287986 | Valid MSE 1080.018854 | Best 1080.900908 (ep 268)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 270/1000 | Train MSE 1070.746034 | Valid MSE 1079.132560 | Best 1080.018854 (ep 269)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 271/1000 | Train MSE 1062.088751 | Valid MSE 1078.240326 | Best 1079.132560 (ep 270)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 272/1000 | Train MSE 1062.613326 | Valid MSE 1077.354461 | Best 1078.240326 (ep 271)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 273/1000 | Train MSE 1065.613157 | Valid MSE 1076.467115 | Best 1077.354461 (ep 272)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 274/1000 | Train MSE 1058.333038 | Valid MSE 1075.579399 | Best 1076.467115 (ep 273)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 275/1000 | Train MSE 1058.304476 | Valid MSE 1074.707613 | Best 1075.579399 (ep 274)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 276/1000 | Train MSE 1056.209168 | Valid MSE 1073.813531 | Best 1074.707613 (ep 275)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 277/1000 | Train MSE 1056.637201 | Valid MSE 1072.940724 | Best 1073.813531 (ep 276)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 278/1000 | Train MSE 1056.771236 | Valid MSE 1072.060164 | Best 1072.940724 (ep 277)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 279/1000 | Train MSE 1057.851710 | Valid MSE 1071.180772 | Best 1072.060164 (ep 278)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 280/1000 | Train MSE 1054.192726 | Valid MSE 1070.298118 | Best 1071.180772 (ep 279)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 281/1000 | Train MSE 1057.444483 | Valid MSE 1069.420942 | Best 1070.298118 (ep 280)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 282/1000 | Train MSE 1051.645708 | Valid MSE 1068.543267 | Best 1069.420942 (ep 281)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 283/1000 | Train MSE 1056.668402 | Valid MSE 1067.670854 | Best 1068.543267 (ep 282)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 284/1000 | Train MSE 1050.464749 | Valid MSE 1066.798682 | Best 1067.670854 (ep 283)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 285/1000 | Train MSE 1051.675664 | Valid MSE 1065.925228 | Best 1066.798682 (ep 284)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 286/1000 | Train MSE 1049.732946 | Valid MSE 1065.051999 | Best 1065.925228 (ep 285)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 287/1000 | Train MSE 1047.835485 | Valid MSE 1064.180337 | Best 1065.051999 (ep 286)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 288/1000 | Train MSE 1052.107011 | Valid MSE 1063.301857 | Best 1064.180337 (ep 287)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 289/1000 | Train MSE 1047.747115 | Valid MSE 1062.435736 | Best 1063.301857 (ep 288)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 290/1000 | Train MSE 1046.349590 | Valid MSE 1061.558980 | Best 1062.435736 (ep 289)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 291/1000 | Train MSE 1044.314443 | Valid MSE 1060.695898 | Best 1061.558980 (ep 290)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 292/1000 | Train MSE 1050.197509 | Valid MSE 1059.831222 | Best 1060.695898 (ep 291)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 293/1000 | Train MSE 1047.478639 | Valid MSE 1058.959296 | Best 1059.831222 (ep 292)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 294/1000 | Train MSE 1042.140834 | Valid MSE 1058.085503 | Best 1058.959296 (ep 293)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 295/1000 | Train MSE 1041.936630 | Valid MSE 1057.218585 | Best 1058.085503 (ep 294)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 296/1000 | Train MSE 1040.265063 | Valid MSE 1056.357865 | Best 1057.218585 (ep 295)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 297/1000 | Train MSE 1043.324182 | Valid MSE 1055.493322 | Best 1056.357865 (ep 296)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 298/1000 | Train MSE 1038.909735 | Valid MSE 1054.626999 | Best 1055.493322 (ep 297)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 299/1000 | Train MSE 1038.579739 | Valid MSE 1053.769769 | Best 1054.626999 (ep 298)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 300/1000 | Train MSE 1037.771421 | Valid MSE 1052.907799 | Best 1053.769769 (ep 299)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 301/1000 | Train MSE 1035.862020 | Valid MSE 1052.044039 | Best 1052.907799 (ep 300)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 302/1000 | Train MSE 1037.547805 | Valid MSE 1051.180972 | Best 1052.044039 (ep 301)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 303/1000 | Train MSE 1036.500732 | Valid MSE 1050.324883 | Best 1051.180972 (ep 302)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 304/1000 | Train MSE 1033.248180 | Valid MSE 1049.463667 | Best 1050.324883 (ep 303)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 305/1000 | Train MSE 1033.736418 | Valid MSE 1048.609428 | Best 1049.463667 (ep 304)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 306/1000 | Train MSE 1033.015245 | Valid MSE 1047.750912 | Best 1048.609428 (ep 305)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 307/1000 | Train MSE 1033.608406 | Valid MSE 1046.898847 | Best 1047.750912 (ep 306)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 308/1000 | Train MSE 1032.972143 | Valid MSE 1046.042082 | Best 1046.898847 (ep 307)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 309/1000 | Train MSE 1027.793255 | Valid MSE 1045.178409 | Best 1046.042082 (ep 308)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 310/1000 | Train MSE 1028.549397 | Valid MSE 1044.334774 | Best 1045.178409 (ep 309)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 311/1000 | Train MSE 1027.182961 | Valid MSE 1043.478687 | Best 1044.334774 (ep 310)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 312/1000 | Train MSE 1028.086163 | Valid MSE 1042.623468 | Best 1043.478687 (ep 311)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 313/1000 | Train MSE 1024.648389 | Valid MSE 1041.775605 | Best 1042.623468 (ep 312)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 314/1000 | Train MSE 1024.198601 | Valid MSE 1040.926459 | Best 1041.775605 (ep 313)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 315/1000 | Train MSE 1023.275337 | Valid MSE 1040.078614 | Best 1040.926459 (ep 314)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 316/1000 | Train MSE 1026.937779 | Valid MSE 1039.224744 | Best 1040.078614 (ep 315)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 317/1000 | Train MSE 1020.459505 | Valid MSE 1038.372411 | Best 1039.224744 (ep 316)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 318/1000 | Train MSE 1019.621328 | Valid MSE 1037.526251 | Best 1038.372411 (ep 317)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 319/1000 | Train MSE 1025.178482 | Valid MSE 1036.688549 | Best 1037.526251 (ep 318)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 320/1000 | Train MSE 1018.009469 | Valid MSE 1035.833134 | Best 1036.688549 (ep 319)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 321/1000 | Train MSE 1018.549982 | Valid MSE 1034.989043 | Best 1035.833134 (ep 320)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 322/1000 | Train MSE 1018.452180 | Valid MSE 1034.153661 | Best 1034.989043 (ep 321)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 323/1000 | Train MSE 1015.684508 | Valid MSE 1033.304813 | Best 1034.153661 (ep 322)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 324/1000 | Train MSE 1014.710262 | Valid MSE 1032.464528 | Best 1033.304813 (ep 323)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 325/1000 | Train MSE 1016.595406 | Valid MSE 1031.628494 | Best 1032.464528 (ep 324)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 326/1000 | Train MSE 1015.740976 | Valid MSE 1030.789425 | Best 1031.628494 (ep 325)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 327/1000 | Train MSE 1015.335738 | Valid MSE 1029.943330 | Best 1030.789425 (ep 326)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 328/1000 | Train MSE 1013.337512 | Valid MSE 1029.105933 | Best 1029.943330 (ep 327)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 329/1000 | Train MSE 1011.264656 | Valid MSE 1028.262852 | Best 1029.105933 (ep 328)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 330/1000 | Train MSE 1010.758058 | Valid MSE 1027.423297 | Best 1028.262852 (ep 329)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 331/1000 | Train MSE 1010.783875 | Valid MSE 1026.585044 | Best 1027.423297 (ep 330)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 332/1000 | Train MSE 1008.997073 | Valid MSE 1025.745614 | Best 1026.585044 (ep 331)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 333/1000 | Train MSE 1008.201605 | Valid MSE 1024.921970 | Best 1025.745614 (ep 332)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 334/1000 | Train MSE 1006.731829 | Valid MSE 1024.075791 | Best 1024.921970 (ep 333)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 335/1000 | Train MSE 1007.140148 | Valid MSE 1023.247513 | Best 1024.075791 (ep 334)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 336/1000 | Train MSE 1008.090194 | Valid MSE 1022.410424 | Best 1023.247513 (ep 335)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 337/1000 | Train MSE 1005.497336 | Valid MSE 1021.569545 | Best 1022.410424 (ep 336)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 338/1000 | Train MSE 1003.647580 | Valid MSE 1020.748082 | Best 1021.569545 (ep 337)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 339/1000 | Train MSE 1003.561124 | Valid MSE 1019.906965 | Best 1020.748082 (ep 338)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 340/1000 | Train MSE 1001.254156 | Valid MSE 1019.072548 | Best 1019.906965 (ep 339)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 341/1000 | Train MSE 1003.016705 | Valid MSE 1018.247723 | Best 1019.072548 (ep 340)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 342/1000 | Train MSE 1002.237172 | Valid MSE 1017.421781 | Best 1018.247723 (ep 341)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 343/1000 | Train MSE 1001.087744 | Valid MSE 1016.588784 | Best 1017.421781 (ep 342)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 344/1000 | Train MSE 1001.813304 | Valid MSE 1015.763176 | Best 1016.588784 (ep 343)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 345/1000 | Train MSE 998.397017 | Valid MSE 1014.930780 | Best 1015.763176 (ep 344)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 346/1000 | Train MSE 996.317221 | Valid MSE 1014.100058 | Best 1014.930780 (ep 345)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 347/1000 | Train MSE 998.914051 | Valid MSE 1013.274295 | Best 1014.100058 (ep 346)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 348/1000 | Train MSE 995.110704 | Valid MSE 1012.458353 | Best 1013.274295 (ep 347)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 349/1000 | Train MSE 994.787208 | Valid MSE 1011.633842 | Best 1012.458353 (ep 348)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 350/1000 | Train MSE 994.179988 | Valid MSE 1010.807093 | Best 1011.633842 (ep 349)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 351/1000 | Train MSE 993.746827 | Valid MSE 1009.972595 | Best 1010.807093 (ep 350)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 352/1000 | Train MSE 991.961944 | Valid MSE 1009.154551 | Best 1009.972595 (ep 351)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 353/1000 | Train MSE 990.006986 | Valid MSE 1008.337888 | Best 1009.154551 (ep 352)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 354/1000 | Train MSE 990.112437 | Valid MSE 1007.519538 | Best 1008.337888 (ep 353)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 355/1000 | Train MSE 992.541077 | Valid MSE 1006.693793 | Best 1007.519538 (ep 354)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 356/1000 | Train MSE 988.453042 | Valid MSE 1005.877102 | Best 1006.693793 (ep 355)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 357/1000 | Train MSE 989.949921 | Valid MSE 1005.062580 | Best 1005.877102 (ep 356)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 358/1000 | Train MSE 987.791960 | Valid MSE 1004.235836 | Best 1005.062580 (ep 357)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 359/1000 | Train MSE 987.893365 | Valid MSE 1003.417523 | Best 1004.235836 (ep 358)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 360/1000 | Train MSE 987.244015 | Valid MSE 1002.604630 | Best 1003.417523 (ep 359)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 361/1000 | Train MSE 984.167171 | Valid MSE 1001.784573 | Best 1002.604630 (ep 360)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 362/1000 | Train MSE 982.685619 | Valid MSE 1000.973518 | Best 1001.784573 (ep 361)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 363/1000 | Train MSE 984.505749 | Valid MSE 1000.161536 | Best 1000.973518 (ep 362)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 364/1000 | Train MSE 983.823923 | Valid MSE 999.345044 | Best 1000.161536 (ep 363)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 365/1000 | Train MSE 982.090536 | Valid MSE 998.520536 | Best 999.345044 (ep 364)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 366/1000 | Train MSE 979.624440 | Valid MSE 997.710009 | Best 998.520536 (ep 365)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 367/1000 | Train MSE 981.389880 | Valid MSE 996.899989 | Best 997.710009 (ep 366)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 368/1000 | Train MSE 977.491296 | Valid MSE 996.085370 | Best 996.899989 (ep 367)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 369/1000 | Train MSE 978.312426 | Valid MSE 995.277668 | Best 996.085370 (ep 368)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 370/1000 | Train MSE 975.848121 | Valid MSE 994.464451 | Best 995.277668 (ep 369)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 371/1000 | Train MSE 975.276582 | Valid MSE 993.662458 | Best 994.464451 (ep 370)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 372/1000 | Train MSE 973.796584 | Valid MSE 992.855545 | Best 993.662458 (ep 371)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 373/1000 | Train MSE 974.682548 | Valid MSE 992.046938 | Best 992.855545 (ep 372)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 374/1000 | Train MSE 972.533347 | Valid MSE 991.236605 | Best 992.046938 (ep 373)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 375/1000 | Train MSE 973.343792 | Valid MSE 990.439270 | Best 991.236605 (ep 374)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 376/1000 | Train MSE 972.700005 | Valid MSE 989.627516 | Best 990.439270 (ep 375)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 377/1000 | Train MSE 972.683454 | Valid MSE 988.821066 | Best 989.627516 (ep 376)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 378/1000 | Train MSE 971.410251 | Valid MSE 988.024822 | Best 988.821066 (ep 377)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 379/1000 | Train MSE 969.704182 | Valid MSE 987.212583 | Best 988.024822 (ep 378)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 380/1000 | Train MSE 971.147161 | Valid MSE 986.405819 | Best 987.212583 (ep 379)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 381/1000 | Train MSE 967.712514 | Valid MSE 985.607219 | Best 986.405819 (ep 380)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 382/1000 | Train MSE 968.061173 | Valid MSE 984.802489 | Best 985.607219 (ep 381)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 383/1000 | Train MSE 966.411389 | Valid MSE 984.003460 | Best 984.802489 (ep 382)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 384/1000 | Train MSE 964.519604 | Valid MSE 983.203371 | Best 984.003460 (ep 383)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 385/1000 | Train MSE 967.332304 | Valid MSE 982.401737 | Best 983.203371 (ep 384)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 386/1000 | Train MSE 962.840899 | Valid MSE 981.603230 | Best 982.401737 (ep 385)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 387/1000 | Train MSE 962.358168 | Valid MSE 980.808067 | Best 981.603230 (ep 386)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 388/1000 | Train MSE 961.323820 | Valid MSE 980.005017 | Best 980.808067 (ep 387)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 389/1000 | Train MSE 962.347530 | Valid MSE 979.208002 | Best 980.005017 (ep 388)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 390/1000 | Train MSE 960.099058 | Valid MSE 978.417875 | Best 979.208002 (ep 389)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 391/1000 | Train MSE 958.762382 | Valid MSE 977.612193 | Best 978.417875 (ep 390)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 392/1000 | Train MSE 958.148044 | Valid MSE 976.826579 | Best 977.612193 (ep 391)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 393/1000 | Train MSE 958.669748 | Valid MSE 976.029450 | Best 976.826579 (ep 392)
# ...
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 869/1000 | Train MSE 640.173235 | Valid MSE 663.957547 | Best 664.486555 (ep 868)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 870/1000 | Train MSE 641.900093 | Valid MSE 663.403929 | Best 663.957547 (ep 869)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 871/1000 | Train MSE 636.966291 | Valid MSE 662.874173 | Best 663.403929 (ep 870)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 872/1000 | Train MSE 636.933999 | Valid MSE 662.324914 | Best 662.874173 (ep 871)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 873/1000 | Train MSE 636.433476 | Valid MSE 661.791571 | Best 662.324914 (ep 872)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 874/1000 | Train MSE 635.974915 | Valid MSE 661.268350 | Best 661.791571 (ep 873)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 875/1000 | Train MSE 638.101726 | Valid MSE 660.727088 | Best 661.268350 (ep 874)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 876/1000 | Train MSE 635.071052 | Valid MSE 660.203072 | Best 660.727088 (ep 875)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 877/1000 | Train MSE 633.623569 | Valid MSE 659.646071 | Best 660.203072 (ep 876)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 878/1000 | Train MSE 633.921876 | Valid MSE 659.129163 | Best 659.646071 (ep 877)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 879/1000 | Train MSE 633.293419 | Valid MSE 658.610983 | Best 659.129163 (ep 878)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 880/1000 | Train MSE 634.654710 | Valid MSE 658.077505 | Best 658.610983 (ep 879)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 881/1000 | Train MSE 632.879207 | Valid MSE 657.538053 | Best 658.077505 (ep 880)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 882/1000 | Train MSE 633.400440 | Valid MSE 657.021660 | Best 657.538053 (ep 881)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 883/1000 | Train MSE 631.308781 | Valid MSE 656.495561 | Best 657.021660 (ep 882)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 884/1000 | Train MSE 631.526732 | Valid MSE 655.942747 | Best 656.495561 (ep 883)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 885/1000 | Train MSE 629.984412 | Valid MSE 655.411176 | Best 655.942747 (ep 884)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 886/1000 | Train MSE 628.519874 | Valid MSE 654.873588 | Best 655.411176 (ep 885)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 887/1000 | Train MSE 630.838534 | Valid MSE 654.372344 | Best 654.873588 (ep 886)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 888/1000 | Train MSE 628.391530 | Valid MSE 653.839390 | Best 654.372344 (ep 887)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 889/1000 | Train MSE 628.035115 | Valid MSE 653.302896 | Best 653.839390 (ep 888)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 890/1000 | Train MSE 630.985857 | Valid MSE 652.761676 | Best 653.302896 (ep 889)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 891/1000 | Train MSE 628.829539 | Valid MSE 652.256497 | Best 652.761676 (ep 890)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 892/1000 | Train MSE 626.513337 | Valid MSE 651.721579 | Best 652.256497 (ep 891)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 893/1000 | Train MSE 626.646921 | Valid MSE 651.195796 | Best 651.721579 (ep 892)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 894/1000 | Train MSE 624.344183 | Valid MSE 650.673633 | Best 651.195796 (ep 893)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 895/1000 | Train MSE 627.383085 | Valid MSE 650.147438 | Best 650.673633 (ep 894)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 896/1000 | Train MSE 623.332987 | Valid MSE 649.631325 | Best 650.147438 (ep 895)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 897/1000 | Train MSE 622.890411 | Valid MSE 649.093869 | Best 649.631325 (ep 896)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 898/1000 | Train MSE 625.682831 | Valid MSE 648.569826 | Best 649.093869 (ep 897)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 899/1000 | Train MSE 622.122855 | Valid MSE 648.035428 | Best 648.569826 (ep 898)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 900/1000 | Train MSE 622.626808 | Valid MSE 647.501430 | Best 648.035428 (ep 899)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 901/1000 | Train MSE 622.417483 | Valid MSE 646.992183 | Best 647.501430 (ep 900)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 902/1000 | Train MSE 622.397751 | Valid MSE 646.486918 | Best 646.992183 (ep 901)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 903/1000 | Train MSE 619.670856 | Valid MSE 645.954993 | Best 646.486918 (ep 902)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 904/1000 | Train MSE 620.546381 | Valid MSE 645.444689 | Best 645.954993 (ep 903)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 905/1000 | Train MSE 618.991923 | Valid MSE 644.907272 | Best 645.444689 (ep 904)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 906/1000 | Train MSE 618.799667 | Valid MSE 644.384844 | Best 644.907272 (ep 905)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 907/1000 | Train MSE 620.886392 | Valid MSE 643.871504 | Best 644.384844 (ep 906)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 908/1000 | Train MSE 617.025287 | Valid MSE 643.340314 | Best 643.871504 (ep 907)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 909/1000 | Train MSE 617.001378 | Valid MSE 642.813712 | Best 643.340314 (ep 908)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 910/1000 | Train MSE 615.967696 | Valid MSE 642.299749 | Best 642.813712 (ep 909)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 911/1000 | Train MSE 617.183716 | Valid MSE 641.769546 | Best 642.299749 (ep 910)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 912/1000 | Train MSE 616.092968 | Valid MSE 641.260559 | Best 641.769546 (ep 911)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 913/1000 | Train MSE 615.064657 | Valid MSE 640.731572 | Best 641.260559 (ep 912)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 914/1000 | Train MSE 615.567016 | Valid MSE 640.217129 | Best 640.731572 (ep 913)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 915/1000 | Train MSE 614.020536 | Valid MSE 639.718300 | Best 640.217129 (ep 914)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 916/1000 | Train MSE 613.295479 | Valid MSE 639.200260 | Best 639.718300 (ep 915)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 917/1000 | Train MSE 615.066017 | Valid MSE 638.645614 | Best 639.200260 (ep 916)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 918/1000 | Train MSE 612.933196 | Valid MSE 638.133228 | Best 638.645614 (ep 917)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 919/1000 | Train MSE 610.912231 | Valid MSE 637.630044 | Best 638.133228 (ep 918)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 920/1000 | Train MSE 611.247113 | Valid MSE 637.116297 | Best 637.630044 (ep 919)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 921/1000 | Train MSE 614.033512 | Valid MSE 636.617474 | Best 637.116297 (ep 920)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 922/1000 | Train MSE 609.580389 | Valid MSE 636.081099 | Best 636.617474 (ep 921)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 923/1000 | Train MSE 611.188348 | Valid MSE 635.566732 | Best 636.081099 (ep 922)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 924/1000 | Train MSE 610.434455 | Valid MSE 635.066178 | Best 635.566732 (ep 923)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 925/1000 | Train MSE 608.640413 | Valid MSE 634.558909 | Best 635.066178 (ep 924)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 926/1000 | Train MSE 607.972430 | Valid MSE 634.053861 | Best 634.558909 (ep 925)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 927/1000 | Train MSE 610.013870 | Valid MSE 633.520409 | Best 634.053861 (ep 926)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 928/1000 | Train MSE 606.874067 | Valid MSE 633.014203 | Best 633.520409 (ep 927)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 929/1000 | Train MSE 606.571421 | Valid MSE 632.487074 | Best 633.014203 (ep 928)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 930/1000 | Train MSE 606.708813 | Valid MSE 631.969379 | Best 632.487074 (ep 929)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 931/1000 | Train MSE 606.334213 | Valid MSE 631.474855 | Best 631.969379 (ep 930)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 932/1000 | Train MSE 605.450855 | Valid MSE 630.969271 | Best 631.474855 (ep 931)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 933/1000 | Train MSE 605.105600 | Valid MSE 630.453211 | Best 630.969271 (ep 932)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 934/1000 | Train MSE 603.567788 | Valid MSE 629.932828 | Best 630.453211 (ep 933)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 935/1000 | Train MSE 604.049751 | Valid MSE 629.411009 | Best 629.932828 (ep 934)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 936/1000 | Train MSE 603.862103 | Valid MSE 628.935816 | Best 629.411009 (ep 935)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 937/1000 | Train MSE 604.483946 | Valid MSE 628.428881 | Best 628.935816 (ep 936)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 938/1000 | Train MSE 601.866793 | Valid MSE 627.901232 | Best 628.428881 (ep 937)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 939/1000 | Train MSE 602.001426 | Valid MSE 627.404596 | Best 627.901232 (ep 938)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 940/1000 | Train MSE 603.163802 | Valid MSE 626.872920 | Best 627.404596 (ep 939)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 941/1000 | Train MSE 601.675710 | Valid MSE 626.369959 | Best 626.872920 (ep 940)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 942/1000 | Train MSE 599.990209 | Valid MSE 625.855641 | Best 626.369959 (ep 941)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 943/1000 | Train MSE 599.751911 | Valid MSE 625.345024 | Best 625.855641 (ep 942)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 944/1000 | Train MSE 601.185944 | Valid MSE 624.824518 | Best 625.345024 (ep 943)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 945/1000 | Train MSE 598.592026 | Valid MSE 624.333769 | Best 624.824518 (ep 944)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 946/1000 | Train MSE 598.273977 | Valid MSE 623.824329 | Best 624.333769 (ep 945)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 947/1000 | Train MSE 600.471745 | Valid MSE 623.343139 | Best 623.824329 (ep 946)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 948/1000 | Train MSE 597.851901 | Valid MSE 622.841495 | Best 623.343139 (ep 947)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 949/1000 | Train MSE 598.373050 | Valid MSE 622.342190 | Best 622.841495 (ep 948)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 950/1000 | Train MSE 596.017546 | Valid MSE 621.802269 | Best 622.342190 (ep 949)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 951/1000 | Train MSE 596.015247 | Valid MSE 621.349476 | Best 621.802269 (ep 950)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 952/1000 | Train MSE 594.857247 | Valid MSE 620.797027 | Best 621.349476 (ep 951)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 953/1000 | Train MSE 594.351050 | Valid MSE 620.309622 | Best 620.797027 (ep 952)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 954/1000 | Train MSE 594.000930 | Valid MSE 619.813295 | Best 620.309622 (ep 953)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 955/1000 | Train MSE 592.464279 | Valid MSE 619.310457 | Best 619.813295 (ep 954)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 956/1000 | Train MSE 592.515714 | Valid MSE 618.807338 | Best 619.310457 (ep 955)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 957/1000 | Train MSE 592.817841 | Valid MSE 618.285818 | Best 618.807338 (ep 956)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 958/1000 | Train MSE 592.871742 | Valid MSE 617.802784 | Best 618.285818 (ep 957)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 959/1000 | Train MSE 591.793428 | Valid MSE 617.302526 | Best 617.802784 (ep 958)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 960/1000 | Train MSE 592.325320 | Valid MSE 616.800037 | Best 617.302526 (ep 959)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 961/1000 | Train MSE 591.784403 | Valid MSE 616.295860 | Best 616.800037 (ep 960)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 962/1000 | Train MSE 588.997469 | Valid MSE 615.796469 | Best 616.295860 (ep 961)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 963/1000 | Train MSE 588.123129 | Valid MSE 615.287946 | Best 615.796469 (ep 962)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 964/1000 | Train MSE 590.131763 | Valid MSE 614.815125 | Best 615.287946 (ep 963)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 965/1000 | Train MSE 587.599548 | Valid MSE 614.300953 | Best 614.815125 (ep 964)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 966/1000 | Train MSE 588.700921 | Valid MSE 613.805573 | Best 614.300953 (ep 965)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 967/1000 | Train MSE 587.746678 | Valid MSE 613.306467 | Best 613.805573 (ep 966)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 968/1000 | Train MSE 586.826873 | Valid MSE 612.809427 | Best 613.306467 (ep 967)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 969/1000 | Train MSE 588.601026 | Valid MSE 612.317791 | Best 612.809427 (ep 968)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 970/1000 | Train MSE 585.680532 | Valid MSE 611.806720 | Best 612.317791 (ep 969)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 971/1000 | Train MSE 585.449899 | Valid MSE 611.301545 | Best 611.806720 (ep 970)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 972/1000 | Train MSE 584.729766 | Valid MSE 610.829776 | Best 611.301545 (ep 971)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 973/1000 | Train MSE 584.969273 | Valid MSE 610.321205 | Best 610.829776 (ep 972)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 974/1000 | Train MSE 584.411253 | Valid MSE 609.854749 | Best 610.321205 (ep 973)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 975/1000 | Train MSE 583.270206 | Valid MSE 609.343621 | Best 609.854749 (ep 974)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 976/1000 | Train MSE 582.595910 | Valid MSE 608.816698 | Best 609.343621 (ep 975)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 977/1000 | Train MSE 583.858106 | Valid MSE 608.349543 | Best 608.816698 (ep 976)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 978/1000 | Train MSE 581.927345 | Valid MSE 607.854812 | Best 608.349543 (ep 977)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 979/1000 | Train MSE 580.634702 | Valid MSE 607.368490 | Best 607.854812 (ep 978)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 980/1000 | Train MSE 580.795518 | Valid MSE 606.870736 | Best 607.368490 (ep 979)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 981/1000 | Train MSE 580.642647 | Valid MSE 606.377801 | Best 606.870736 (ep 980)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 982/1000 | Train MSE 582.333226 | Valid MSE 605.897371 | Best 606.377801 (ep 981)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 983/1000 | Train MSE 582.125149 | Valid MSE 605.407757 | Best 605.897371 (ep 982)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 984/1000 | Train MSE 579.850394 | Valid MSE 604.904586 | Best 605.407757 (ep 983)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 985/1000 | Train MSE 578.554872 | Valid MSE 604.413055 | Best 604.904586 (ep 984)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 986/1000 | Train MSE 578.193326 | Valid MSE 603.932670 | Best 604.413055 (ep 985)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 987/1000 | Train MSE 579.245914 | Valid MSE 603.427142 | Best 603.932670 (ep 986)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 988/1000 | Train MSE 576.296524 | Valid MSE 602.930760 | Best 603.427142 (ep 987)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 989/1000 | Train MSE 577.253316 | Valid MSE 602.458088 | Best 602.930760 (ep 988)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 990/1000 | Train MSE 577.119672 | Valid MSE 601.971165 | Best 602.458088 (ep 989)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 991/1000 | Train MSE 575.971113 | Valid MSE 601.475208 | Best 601.971165 (ep 990)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 992/1000 | Train MSE 574.544837 | Valid MSE 600.988639 | Best 601.475208 (ep 991)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 993/1000 | Train MSE 576.707999 | Valid MSE 600.499037 | Best 600.988639 (ep 992)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 994/1000 | Train MSE 574.257364 | Valid MSE 600.013780 | Best 600.499037 (ep 993)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 995/1000 | Train MSE 574.324798 | Valid MSE 599.514068 | Best 600.013780 (ep 994)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 996/1000 | Train MSE 573.540213 | Valid MSE 599.045209 | Best 599.514068 (ep 995)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 997/1000 | Train MSE 572.085420 | Valid MSE 598.544960 | Best 599.045209 (ep 996)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 998/1000 | Train MSE 573.012106 | Valid MSE 598.066577 | Best 598.544960 (ep 997)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 999/1000 | Train MSE 571.558658 | Valid MSE 597.583098 | Best 598.066577 (ep 998)
# [AE] 🎯 New Best Valid MSE!
# [AE] Epoch 1000/1000 | Train MSE 573.888713 | Valid MSE 597.094012 | Best 597.583098 (ep 999)
# [AE] 🎯 New Best Valid MSE!
# [AE] ✅ Finished. Best Valid MSE: 597.094012 at epoch 1000

# %%
# ======================================
# 7) AE 인코더 재사용 LSTM+MLP 예측 모델
# ======================================
class AEEncoderRegressor(nn.Module):
    def __init__(self, ae_model, head_lstm_hidden=128, head_lstm_layers=1,
                 mlp_layers=2, output_dim=2, dropout=0.2, freeze_encoder=False):
        super().__init__()
        # AE encoder와 동일 사양의 LSTM 생성 후 state_dict 복사
        self.encoder = nn.LSTM(
            input_size=ae_model.encoder.input_size,
            hidden_size=ae_model.encoder.hidden_size,
            num_layers=ae_model.encoder.num_layers,
            batch_first=True,
            dropout=dropout if ae_model.encoder.num_layers>1 else 0.0
        )
        self.encoder.load_state_dict(ae_model.encoder.state_dict())
        if freeze_encoder:
            for p in self.encoder.parameters(): p.requires_grad=False

        enc_outdim = ae_model.encoder.hidden_size
        self.head_lstm = nn.LSTM(
            input_size=enc_outdim, hidden_size=head_lstm_hidden,
            num_layers=head_lstm_layers, batch_first=True,
            dropout=dropout if head_lstm_layers>1 else 0.0
        )

        mlp = []
        in_dim = head_lstm_hidden
        for _ in range(mlp_layers):
            out_dim = max(in_dim//2, 8)
            mlp += [nn.Linear(in_dim, out_dim), nn.ReLU()]
            in_dim = out_dim
        mlp += [nn.Linear(in_dim, output_dim)]
        self.mlp = nn.Sequential(*mlp)

    def forward(self, x):
        enc_out,_  = self.encoder(x)      # (B, T, H_enc)
        head_out,_ = self.head_lstm(enc_out) # (B, T, H_head)
        last = head_out[:, -1, :]         # (B, H_head)
        return self.mlp(last)             # (B, 2)

# %%
reg_model = AEEncoderRegressor(
    ae_model=ae_model,
    head_lstm_hidden=128,
    head_lstm_layers=2,
    mlp_layers=3, # 3,4,5 등등
    output_dim=1,
    dropout=dropout,
    freeze_encoder=False  # 필요 시 True로 바꾸면 인코더 동결
)
#mse lr 을보니까 range 가 구간이있는데 몰려있는곳,autoincoder는 구간이 짧은네 분표되어있어 전반적으로는 auto인코더가 좋다고 그걸 summary 스탯으로 엑셀로 loss 받아놓기.
# test 파일로.

# %%
# ======================================
# 8) 원하는 로그 포맷의 트레이너 + 학습 실행
# ======================================
import numpy as np

def compute_all_metrics(preds, targets):
    pn = preds.detach().cpu().numpy()
    tn = targets.detach().cpu().numpy()
    mse  = float(np.mean((pn - tn)**2))
    rmse = float(np.sqrt(mse))
    mae  = float(np.mean(np.abs(pn - tn)))
    return {"MSE": mse, "RMSE": rmse, "MAE": mae}

def train_with_valid_early_stop(
    model,                    # 이미 생성된 모델 인스턴스 (reg_model)
    train_loader, valid_loader,
    n_epochs=300, lr=1e-3, weight_decay=1e-5,
    patience=30, log_every=5, device=device
):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.MSELoss()

    train_mse_curve, valid_mse_curve = [], []
    best_mse = float('inf')
    best_state = None
    best_epoch = 0
    no_improve = 0

    for epoch in range(n_epochs):
        # === Train ===
        model.train()
        all_preds, all_targets = [], []
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            preds = model(X_batch)
            loss = criterion(preds, y_batch)
            loss.backward()
            optimizer.step()
            all_preds.append(preds.detach().cpu())
            all_targets.append(y_batch.detach().cpu())
        train_mse = compute_all_metrics(torch.cat(all_preds), torch.cat(all_targets))['MSE']
        train_mse_curve.append(train_mse)

        # === Valid ===
        model.eval()
        val_preds, val_targets = [], []
        with torch.no_grad():
            for X_batch, y_batch in valid_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                preds = model(X_batch)
                val_preds.append(preds.detach().cpu())
                val_targets.append(y_batch.detach().cpu())
        valid_mse = compute_all_metrics(torch.cat(val_preds), torch.cat(val_targets))['MSE']
        valid_mse_curve.append(valid_mse)

        # 로그 (요청한 포맷 그대로)
        if (epoch + 1) % log_every == 0 or valid_mse < best_mse:
            print(f"Epoch {epoch+1}/{n_epochs} - "
                  f"Train MSE: {train_mse:.6f} | Valid MSE: {valid_mse:.6f} | "
                  f"Best Valid MSE: {best_mse:.6f} (Epoch {best_epoch+1})")

        # Early stopping
        if valid_mse < best_mse:
            best_mse = valid_mse
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            best_epoch = epoch
            no_improve = 0
            print("🎯 New Best Valid MSE!")
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"⏹️ Early stopping triggered at epoch {epoch+1}")
                break

    if best_state is not None:
        model.load_state_dict(best_state)
    print(f"✅ Finished. Best Valid MSE: {best_mse:.6f} at Epoch {best_epoch+1}")

    return model, train_mse_curve, valid_mse_curve, best_mse, best_epoch

# %%
reg_model, tr_curve, va_curve, best_mse, best_ep = train_with_valid_early_stop(
    model=reg_model,
    train_loader=train_loader_sup,
    valid_loader=valid_loader_sup,
    n_epochs=1000, lr=0.0001, weight_decay=0.2,
    patience=200, log_every=5, device=device
)
# Out:
# Epoch 1/1000 - Train MSE: 4066.363281 | Valid MSE: 4834.953125 | Best Valid MSE: inf (Epoch 1)
# 🎯 New Best Valid MSE!
# Epoch 2/1000 - Train MSE: 4065.218018 | Valid MSE: 4833.454102 | Best Valid MSE: 4834.953125 (Epoch 1)
# 🎯 New Best Valid MSE!
# Epoch 3/1000 - Train MSE: 4063.898438 | Valid MSE: 4831.610352 | Best Valid MSE: 4833.454102 (Epoch 2)
# 🎯 New Best Valid MSE!
# Epoch 4/1000 - Train MSE: 4057.259033 | Valid MSE: 4810.404297 | Best Valid MSE: 4831.610352 (Epoch 3)
# 🎯 New Best Valid MSE!
# Epoch 5/1000 - Train MSE: 4013.882568 | Valid MSE: 4729.944336 | Best Valid MSE: 4810.404297 (Epoch 4)
# 🎯 New Best Valid MSE!
# Epoch 6/1000 - Train MSE: 3918.526123 | Valid MSE: 4596.415039 | Best Valid MSE: 4729.944336 (Epoch 5)
# 🎯 New Best Valid MSE!
# Epoch 7/1000 - Train MSE: 3770.656982 | Valid MSE: 4398.795898 | Best Valid MSE: 4596.415039 (Epoch 6)
# 🎯 New Best Valid MSE!
# Epoch 8/1000 - Train MSE: 3567.967041 | Valid MSE: 4119.932617 | Best Valid MSE: 4398.795898 (Epoch 7)
# 🎯 New Best Valid MSE!
# Epoch 9/1000 - Train MSE: 3298.222656 | Valid MSE: 3783.622070 | Best Valid MSE: 4119.932617 (Epoch 8)
# 🎯 New Best Valid MSE!
# Epoch 10/1000 - Train MSE: 3003.591309 | Valid MSE: 3362.139893 | Best Valid MSE: 3783.622070 (Epoch 9)
# 🎯 New Best Valid MSE!
# Epoch 11/1000 - Train MSE: 2699.726562 | Valid MSE: 2958.841064 | Best Valid MSE: 3362.139893 (Epoch 10)
# 🎯 New Best Valid MSE!
# Epoch 12/1000 - Train MSE: 2421.691162 | Valid MSE: 2578.177246 | Best Valid MSE: 2958.841064 (Epoch 11)
# 🎯 New Best Valid MSE!
# Epoch 13/1000 - Train MSE: 2187.244385 | Valid MSE: 2278.927002 | Best Valid MSE: 2578.177246 (Epoch 12)
# 🎯 New Best Valid MSE!
# Epoch 14/1000 - Train MSE: 2022.361816 | Valid MSE: 2056.122559 | Best Valid MSE: 2278.927002 (Epoch 13)
# 🎯 New Best Valid MSE!
# Epoch 15/1000 - Train MSE: 1937.226196 | Valid MSE: 1935.215820 | Best Valid MSE: 2056.122559 (Epoch 14)
# 🎯 New Best Valid MSE!
# Epoch 16/1000 - Train MSE: 1882.605835 | Valid MSE: 1825.825195 | Best Valid MSE: 1935.215820 (Epoch 15)
# 🎯 New Best Valid MSE!
# Epoch 17/1000 - Train MSE: 1829.162231 | Valid MSE: 1774.823120 | Best Valid MSE: 1825.825195 (Epoch 16)
# 🎯 New Best Valid MSE!
# Epoch 18/1000 - Train MSE: 1788.876831 | Valid MSE: 1736.852783 | Best Valid MSE: 1774.823120 (Epoch 17)
# 🎯 New Best Valid MSE!
# Epoch 19/1000 - Train MSE: 1768.331543 | Valid MSE: 1683.979614 | Best Valid MSE: 1736.852783 (Epoch 18)
# 🎯 New Best Valid MSE!
# Epoch 20/1000 - Train MSE: 1734.794800 | Valid MSE: 1655.453613 | Best Valid MSE: 1683.979614 (Epoch 19)
# 🎯 New Best Valid MSE!
# Epoch 21/1000 - Train MSE: 1716.473145 | Valid MSE: 1630.755249 | Best Valid MSE: 1655.453613 (Epoch 20)
# 🎯 New Best Valid MSE!
# Epoch 22/1000 - Train MSE: 1698.821289 | Valid MSE: 1609.870850 | Best Valid MSE: 1630.755249 (Epoch 21)
# 🎯 New Best Valid MSE!
# Epoch 23/1000 - Train MSE: 1685.079468 | Valid MSE: 1599.503540 | Best Valid MSE: 1609.870850 (Epoch 22)
# 🎯 New Best Valid MSE!
# Epoch 24/1000 - Train MSE: 1658.080200 | Valid MSE: 1582.804932 | Best Valid MSE: 1599.503540 (Epoch 23)
# 🎯 New Best Valid MSE!
# Epoch 25/1000 - Train MSE: 1628.036987 | Valid MSE: 1565.517090 | Best Valid MSE: 1582.804932 (Epoch 24)
# 🎯 New Best Valid MSE!
# Epoch 27/1000 - Train MSE: 1606.723267 | Valid MSE: 1565.416992 | Best Valid MSE: 1565.517090 (Epoch 25)
# 🎯 New Best Valid MSE!
# Epoch 29/1000 - Train MSE: 1569.254028 | Valid MSE: 1545.495605 | Best Valid MSE: 1565.416992 (Epoch 27)
# 🎯 New Best Valid MSE!
# Epoch 30/1000 - Train MSE: 1562.676147 | Valid MSE: 1552.894775 | Best Valid MSE: 1545.495605 (Epoch 29)
# Epoch 31/1000 - Train MSE: 1556.401978 | Valid MSE: 1531.180664 | Best Valid MSE: 1545.495605 (Epoch 29)
# 🎯 New Best Valid MSE!
# Epoch 35/1000 - Train MSE: 1483.141479 | Valid MSE: 1561.813110 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 40/1000 - Train MSE: 1412.447998 | Valid MSE: 1576.365845 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 45/1000 - Train MSE: 1354.357056 | Valid MSE: 1660.001099 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 50/1000 - Train MSE: 1308.244873 | Valid MSE: 1589.939697 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 55/1000 - Train MSE: 1261.102173 | Valid MSE: 1637.454712 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 60/1000 - Train MSE: 1214.326294 | Valid MSE: 1617.674805 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 65/1000 - Train MSE: 1183.869995 | Valid MSE: 1748.202637 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 70/1000 - Train MSE: 1168.356689 | Valid MSE: 1702.806641 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 75/1000 - Train MSE: 1113.245972 | Valid MSE: 1775.296997 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 80/1000 - Train MSE: 1109.587402 | Valid MSE: 1837.916870 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 85/1000 - Train MSE: 1115.162231 | Valid MSE: 1732.234741 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 90/1000 - Train MSE: 1045.017944 | Valid MSE: 1795.739624 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 95/1000 - Train MSE: 1019.323853 | Valid MSE: 1878.448730 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 100/1000 - Train MSE: 1017.770569 | Valid MSE: 1810.354248 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 105/1000 - Train MSE: 995.574646 | Valid MSE: 1869.242065 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 110/1000 - Train MSE: 1010.748840 | Valid MSE: 1847.756104 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 115/1000 - Train MSE: 969.351868 | Valid MSE: 1843.143677 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 120/1000 - Train MSE: 917.179443 | Valid MSE: 1911.616211 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 125/1000 - Train MSE: 911.527405 | Valid MSE: 1898.898804 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 130/1000 - Train MSE: 902.127930 | Valid MSE: 1980.307739 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 135/1000 - Train MSE: 883.633240 | Valid MSE: 1968.712280 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 140/1000 - Train MSE: 877.208496 | Valid MSE: 1973.891113 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 145/1000 - Train MSE: 842.997070 | Valid MSE: 2038.242188 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 150/1000 - Train MSE: 837.264465 | Valid MSE: 2055.047607 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 155/1000 - Train MSE: 799.979248 | Valid MSE: 2059.406738 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 160/1000 - Train MSE: 802.814148 | Valid MSE: 2004.953735 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 165/1000 - Train MSE: 793.863892 | Valid MSE: 2005.646484 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 170/1000 - Train MSE: 769.864502 | Valid MSE: 1983.249634 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 175/1000 - Train MSE: 780.785645 | Valid MSE: 1973.627319 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 180/1000 - Train MSE: 747.546387 | Valid MSE: 2086.939941 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 185/1000 - Train MSE: 755.504517 | Valid MSE: 2040.576660 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 190/1000 - Train MSE: 729.917847 | Valid MSE: 2027.295044 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 195/1000 - Train MSE: 720.457581 | Valid MSE: 1980.476074 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 200/1000 - Train MSE: 720.136414 | Valid MSE: 1991.109131 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 205/1000 - Train MSE: 748.239197 | Valid MSE: 2085.050537 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 210/1000 - Train MSE: 721.501587 | Valid MSE: 2031.836060 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 215/1000 - Train MSE: 681.621948 | Valid MSE: 2074.948975 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 220/1000 - Train MSE: 687.325134 | Valid MSE: 2016.084229 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 225/1000 - Train MSE: 661.849731 | Valid MSE: 2029.587646 | Best Valid MSE: 1531.180664 (Epoch 31)
# Epoch 230/1000 - Train MSE: 669.862793 | Valid MSE: 1982.696045 | Best Valid MSE: 1531.180664 (Epoch 31)
# ⏹️ Early stopping triggered at epoch 231
# ✅ Finished. Best Valid MSE: 1531.180664 at Epoch 31

# %%
# # ======================================
# # 9) 테스트 평가 + 10개 출력 & 저장
# # ======================================
# reg_model.eval()
# preds, trues = [], []
# with torch.no_grad():
#     for xb, yb in test_loader_sup:
#         xb = xb.to(device)
#         preds.append(reg_model(xb).cpu().numpy())
#         trues.append(yb.numpy())
# preds = np.vstack(preds)
# trues = np.vstack(trues)

# mse = mean_squared_error(trues, preds)
# rmse = float(np.sqrt(mse))
# print(f"[TEST] MSE={mse:.8f} | RMSE={rmse:.8f}")

# # 앞 10개 비교
# n_show = min(10, preds.shape[0])
# df_show = pd.DataFrame({
#     "true_D_lat": trues[:n_show, 0],
#     "pred_D_lat": preds[:n_show, 0],
#     "true_D_lon": trues[:n_show, 1],
#     "pred_D_lon": preds[:n_show, 1],
# })
# print("\n🔎 First 10 predictions vs truth (Δlat, Δlon):")
# print(df_show.round(8))

# # 전체 저장
# save_csv = "/content/drive/MyDrive/test_next_delta_latlon_pred_from_AEencoder.csv"
# pd.DataFrame({
#     "true_D_lat": trues[:, 0], "pred_D_lat": preds[:, 0],
#     "true_D_lon": trues[:, 1], "pred_D_lon": preds[:, 1]
# }).to_csv(save_csv, index=False)
# print(f"✅ Saved: {save_csv}")

# %% [markdown]
# D_alt 만

# %%
# ======================================
# 9) 테스트 평가 + 10개 출력 (D_alt 전용) — CSV 저장 제거/정리
# ======================================
reg_model.eval()
preds_list, trues_list = [], []
with torch.no_grad():
    for xb, yb in test_loader_sup:
        xb = xb.to(device)
        preds_list.append(reg_model(xb).squeeze(-1).cpu())  # (B,)
        trues_list.append(yb.squeeze(-1).cpu())             # (B,)

# 하나로 합치고 numpy로 변환
preds = torch.cat(preds_list).numpy()
trues = torch.cat(trues_list).numpy()

# 메트릭
errors = preds - trues
mse  = float(np.mean(errors**2))
rmse = float(np.sqrt(mse))
mae  = float(np.mean(np.abs(errors)))
print(f"[TEST] (D_alt) MSE={mse:.8f} | RMSE={rmse:.8f} | MAE={mae:.8f}")

# 앞 10개 비교 출력
n_show = min(10, preds.shape[0])
print("\n🔎 First 10 predictions vs truth (Δlat):")
print(pd.DataFrame({
    "true_D_alt": trues[:n_show],
    "pred_D_alt": preds[:n_show],
    "error":      errors[:n_show],
}).round(8))

# ===== Summary Statistics for D_alt =====
df_res = pd.DataFrame({
    "true_D_alt":   trues,
    "pred_D_alt":   preds,
    "error":        errors,
    "abs_error":    np.abs(errors),
    "squared_error": errors**2
})
print("\n📊 Summary Statistics (D_alt):")
print(df_res.describe().round(6))
# Out:
# [TEST] (D_alt) MSE=871.67822266 | RMSE=29.52419724 | MAE=21.26348495
#
# 🔎 First 10 predictions vs truth (Δlat):
#    true_D_alt  pred_D_alt      error
# 0        -1.0   -0.383590   0.616410
# 1        -6.0    5.119737  11.119737
# 2         6.0   -6.399152 -12.399152
# 3        -9.0    0.846358   9.846358
# 4         6.0   -3.583112  -9.583112
# 5       -17.0   -5.804514  11.195485
# 6       -18.0   -8.954138   9.045862
# 7        18.0   -9.298636 -27.298637
# 8        19.0  -10.851712 -29.851711
# 9         9.0   -4.488590 -13.488590
#
# 📊 Summary Statistics (D_alt):
#         true_D_alt   pred_D_alt        error    abs_error  squared_error
# count  2100.000000  2100.000000  2100.000000  2100.000000    2100.000000
# mean    -12.487619   -14.291746    -1.804127    21.263485     871.678223
# std      49.802773    42.274906    29.476046    20.487627    2066.529053
# min    -279.000000  -199.489044  -167.627151     0.002168       0.000005
# 25%     -20.000000   -13.683705   -17.311725     7.141557      51.001839
# 50%      -3.000000    -1.590775    -1.350500    15.862713     251.625702
# 75%      13.000000     3.817694    13.905050    28.585442     817.127625
# max     160.000000   128.622604   157.848312   167.627151   28098.861328
