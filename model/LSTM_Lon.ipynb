# %%
import sys
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import euclidean_distances
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
import torch
from torch.utils.data import TensorDataset, DataLoader
from google.colab import drive

# %%
def random_seed(seed=1234):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

random_seed(1234)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Add dataset directory to path
import sys
sys.path.append('/content/drive/MyDrive/Collected_dataset')

# OS and path setup
import os
ospj = os.path.join
path_workspace = '/content/drive/MyDrive/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define training data paths
dict_path_tr_clean = {
    #'20m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_static.csv'),
     '20m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn1.csv'),
    # '20m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn2.csv'),
    #'50m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_static.csv'),
     '50m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn1.csv'),
    # '50m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn2.csv'),
    #'70m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_static.csv'),
     '70m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn1.csv'),
    # '70m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn2.csv'),
}


dict_path_te_clean = {
    # '35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat.csv'),
     '35m_dyn1': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn1.csv'),
    # '35m_dyn2': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn2.csv'),
}



# dict_path_tr_clean = {
#     '20m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_static.csv'),
#     '20m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn1.csv'),
#     '20m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/20m_dyn2.csv'),
#     '50m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_static.csv'),
#     '50m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn1.csv'),
#     '50m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/50m_dyn2.csv'),
#     '70m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_static.csv'),
#     '70m_dyn1': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn1.csv'),
#     '70m_dyn2': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/70m_dyn2.csv'),
# }


# dict_path_te_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat.csv'),
#     '35m_dyn1': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn1.csv'),
#     '35m_dyn2': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_dyn2.csv'),
# }






# dict_path_tr_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Training & Validation/clean/35m_stat_train.csv'),
# }
# dict_path_te_clean = {
#     '35m_stat': ospj(path_workspace, r'Collected_dataset/Testing/clean/35m_stat_test.csv'),
# }

# 우선
# 20 ,50 ,70 stat 만 file , 1 개씩 valid 35 stat test 로 파일 구성
# training 하고 test 는 다를수있어도 valid 랑 test 는 유사한지 확인
# baseline 모델 이랑 lstm 구현 epoch 은 100 만 수요일 4시반 목요일대신

# %%
import pandas as pd

# Select specific columns
selected_columns = ['lat', 'lon', 'alt', 'alt_ellipsoid','vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'vel_d_m_s', 'cog_rad', 'timestamp']

# Initialize dictionaries
dict_df_tr_clean = {}
dict_df_te_clean = {}

# Load training CSVs
for key, csv_path in dict_path_tr_clean.items():
    try:
        df = pd.read_csv(csv_path, usecols=selected_columns)
        dict_df_tr_clean[key] = df
        print(f"{key} ✅ Training data loaded")
    except Exception as e:
        print(f"{key} ❌ Training load error: {e}")

# Load testing CSVs
for key, csv_path in dict_path_te_clean.items():
    try:
        df = pd.read_csv(csv_path, usecols=selected_columns)
        dict_df_te_clean[key] = df
        print(f"{key} ✅ Test data loaded")
    except Exception as e:
        print(f"{key} ❌ Test load error: {e}")
# Out:
# 20m_dyn1 ✅ Training data loaded
# 50m_dyn1 ✅ Training data loaded
# 70m_dyn1 ✅ Training data loaded
# 35m_dyn1 ✅ Test data loaded

# %%
def convert_timestamp_to_seconds(t):
    try:
        minutes, sec_fraction = t.split(":")
        return int(minutes) * 60 + float(sec_fraction)
    except Exception as e:
        print(f"Error converting timestamp: {t} -> {e}")
        return None

# %%
def split_by_time_gap(df, time_col='timestamp', threshold=1.0):
    df = df.copy()
    df[time_col] = df[time_col].apply(convert_timestamp_to_seconds)
    df = df.dropna(subset=[time_col]).reset_index(drop=True)

    print("\n🧪 Converted timestamp (head):")
    print(df[time_col].iloc[:5].tolist())

    diffs = df[time_col].diff().fillna(0).abs()
    split_indices = diffs[diffs >= threshold].index.tolist()

    split_indices = [0] + split_indices + [len(df)]
    splits = [
        df.iloc[split_indices[i]:split_indices[i + 1]].reset_index(drop=True)
        for i in range(len(split_indices) - 1)
    ]
    return splits

# %%
# Apply segment split to training and testing data
dict_split_tr_clean = {}
dict_split_te_clean = {}

for key, df in dict_df_tr_clean.items():
    split_dfs = split_by_time_gap(df, time_col='timestamp', threshold=1.0)
    dict_split_tr_clean[key] = split_dfs
    print(f"{key} ✅ Segmented - {len(split_dfs)} segments")

for key, df in dict_df_te_clean.items():
    split_dfs = split_by_time_gap(df, time_col='timestamp', threshold=1.0)
    dict_split_te_clean[key] = split_dfs
    print(f"{key} ✅ Segmented - {len(split_dfs)} segments")
# Out:
# 🧪 Converted timestamp (head):
# [270.4, 270.6, 270.8, 271.0, 271.2]
# 20m_dyn1 ✅ Segmented - 4 segments
#
# 🧪 Converted timestamp (head):
# [256.0, 256.2, 256.4, 256.6, 256.8]
# 50m_dyn1 ✅ Segmented - 4 segments
#
# 🧪 Converted timestamp (head):
# [330.6, 330.8, 331.0, 331.2, 331.4]
# 70m_dyn1 ✅ Segmented - 5 segments
#
# 🧪 Converted timestamp (head):
# [226.7, 226.9, 227.1, 227.3, 227.5]
# 35m_dyn1 ✅ Segmented - 4 segments

# %%
dict_split_train_only = {}
dict_split_valid_only = {}

for key, segments in dict_split_tr_clean.items():
    if len(segments) > 1:
        dict_split_train_only[key] = segments[:-1]
        dict_split_valid_only[key] = [segments[-1]]
    else:
        dict_split_train_only[key] = []
        dict_split_valid_only[key] = segments

# 확인
for k in dict_split_tr_clean.keys():
    print(f"{k} → Train seg: {len(dict_split_train_only[k])}, Valid seg: {len(dict_split_valid_only[k])}")
# Out:
# 20m_dyn1 → Train seg: 3, Valid seg: 1
# 50m_dyn1 → Train seg: 3, Valid seg: 1
# 70m_dyn1 → Train seg: 4, Valid seg: 1

# %%
def count_total_points(dict_original, dict_split):
    for key in dict_original:
        original_count = len(dict_original[key])
        split_count = sum(len(df) for df in dict_split[key])
        status = "✅ 일치" if original_count == split_count else "❌ 불일치"
        print(f"{key}: 원본 = {original_count} / 분할 합계 = {split_count} → {status}")

# %%
# =====================================
# 3. 원본 vs Segment 개수 비교
# =====================================
print("\n🔎 학습 데이터 확인 (원본 vs 전체 segment)")
count_total_points(dict_df_tr_clean, dict_split_tr_clean)

print("\n🔎 테스트 데이터 확인 (원본 vs 전체 segment)")
count_total_points(dict_df_te_clean, dict_split_te_clean)
# Out:
# 🔎 학습 데이터 확인 (원본 vs 전체 segment)
# 20m_dyn1: 원본 = 1826 / 분할 합계 = 1826 → ✅ 일치
# 50m_dyn1: 원본 = 1980 / 분할 합계 = 1980 → ✅ 일치
# 70m_dyn1: 원본 = 2000 / 분할 합계 = 2000 → ✅ 일치
#
# 🔎 테스트 데이터 확인 (원본 vs 전체 segment)
# 35m_dyn1: 원본 = 2120 / 분할 합계 = 2120 → ✅ 일치

# %%
# =====================================
# 4. Train / Valid 포인트 수 요약
# =====================================
train_points = sum(len(df) for dfs in dict_split_train_only.values() for df in dfs)
valid_points = sum(len(df) for dfs in dict_split_valid_only.values() for df in dfs)
test_points  = sum(len(df) for dfs in dict_split_te_clean.values()   for df in dfs)

print("\n📊 데이터 포인트 개수 요약")
print(f"Train total points: {train_points}")
print(f"Valid total points: {valid_points}")
print(f"Test total points:  {test_points}")
# Out:
# 📊 데이터 포인트 개수 요약
# Train total points: 4444
# Valid total points: 1362
# Test total points:  2120

# %%
def add_delta_coordinates(dict_split):
    for key, split_list in dict_split.items():
        for df in split_list:
            df['D_lat'] = [0.0] + (df['lat'].diff().fillna(0).tolist())[1:]
            df['D_lon'] = [0.0] + (df['lon'].diff().fillna(0).tolist())[1:]
            df['D_alt'] = [0.0] + (df['alt'].diff().fillna(0).tolist())[1:]

# %%
from sklearn.metrics import euclidean_distances

def calculate_euc_distance(df):
    coordinates = df[['lat', 'lon', 'alt']].to_numpy()
    distances = [0.0]
    for i in range(1, len(coordinates)):
        dist = euclidean_distances([coordinates[i - 1]], [coordinates[i]])[0][0]
        distances.append(dist)
    return distances

def add_euc_distance(dict_split):
    for key, split_list in dict_split.items():
        for df in split_list:
            distances = calculate_euc_distance(df)
            df['d_pos'] = distances

# %%
def add_time_gap(dict_split):
    for key, split_list in dict_split.items():
        for df in split_list:
            time_gap = [0.0] + (df['timestamp'].diff().fillna(0).tolist())[1:]
            df['time_gap'] = time_gap

# %%
# Apply feature creation to both training and test sets
add_delta_coordinates(dict_split_train_only)
add_delta_coordinates(dict_split_valid_only)
add_delta_coordinates(dict_split_te_clean)

add_euc_distance(dict_split_train_only)
add_euc_distance(dict_split_valid_only)
add_euc_distance(dict_split_te_clean)

add_time_gap(dict_split_train_only)
add_time_gap(dict_split_valid_only)
add_time_gap(dict_split_te_clean)

# %%
# =====================================
# 세트별 segment 개수 더블 체크
# =====================================
print("\n📦 Segment 개수 확인")
print(f"Train set: {sum(len(segments) for segments in dict_split_train_only.values())} segments total")
print(f"Valid set: {sum(len(segments) for segments in dict_split_valid_only.values())} segments total")
print(f"Test set:  {sum(len(segments) for segments in dict_split_te_clean.values())} segments total")

# key별 segment 개수 확인 (원하면 주석 해제)
for k in dict_split_train_only.keys():
    print(f"{k} → Train seg: {len(dict_split_train_only[k])}, Valid seg: {len(dict_split_valid_only[k])}")
# Out:
# 📦 Segment 개수 확인
# Train set: 10 segments total
# Valid set: 3 segments total
# Test set:  4 segments total
# 20m_dyn1 → Train seg: 3, Valid seg: 1
# 50m_dyn1 → Train seg: 3, Valid seg: 1
# 70m_dyn1 → Train seg: 4, Valid seg: 1

# %%
# # Extract rows where time_gap < 0
# neg_time_gap_rows = dict_split_tr_clean['20m_stat'][0][dict_split_tr_clean['20m_stat'][0]['time_gap'] < 0]

# # Display them
# print("❗ Rows with time_gap < 0:")
# print(neg_time_gap_rows)

# %%
import numpy as np

# Define window size
window_size = 5 # 기본 5개
# Real 5개를 가지고 6번째 예측
#2,3,4,5,6 을보고 7을 예측

# Define input features and target features
input_features =  ['vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'cog_rad', 'D_lat', 'D_lon', 'd_pos','time_gap']
# 'vel_m_s', 'vel_n_m_s', 'vel_e_m_s', 'vel_d_m_s', 'cog_rad', 'D_lat', 'D_lon', 'D_alt', 'd_pos','time_gap'

target_features = ['D_lon']  # target to predict

# %%
def create_sequence_label_tensors(dict_split, window_size):
    X_all, y_all = [], []
    for df_list in dict_split.values():
        for df in df_list:
            if len(df) <= window_size:
                continue
            data = df[input_features].to_numpy()
            labels = df[target_features].to_numpy()
            for i in range(len(df) - window_size):
                window = data[i : i + window_size]
                label = labels[i + window_size]
                X_all.append(window)
                y_all.append(label)
    X_tensor = np.array(X_all)
    y_tensor = np.array(y_all)
    return X_tensor, y_tensor

# %%
# Apply sequence generation
X_train, y_train = create_sequence_label_tensors(dict_split_train_only, window_size)
X_valid, y_valid = create_sequence_label_tensors(dict_split_valid_only, window_size)
X_test,  y_test  = create_sequence_label_tensors(dict_split_te_clean,  window_size)

# %%
# Check resulting shapes
print(f"✅ Train sequences shape: {X_train.shape}")
print(f"✅ Train labels shape:    {y_train.shape}")

print(f"✅ Valid sequences shape: {X_valid.shape}")
print(f"✅ Valid labels shape:    {y_valid.shape}")

print(f"✅ Test sequences shape:  {X_test.shape}")
print(f"✅ Test labels shape:     {y_test.shape}")
# Out:
# ✅ Train sequences shape: (4394, 5, 8)
# ✅ Train labels shape:    (4394, 1)
# ✅ Valid sequences shape: (1347, 5, 8)
# ✅ Valid labels shape:    (1347, 1)
# ✅ Test sequences shape:  (2100, 5, 8)
# ✅ Test labels shape:     (2100, 1)

# %%
def count_expected_windows(dict_split, window_size):
    expected_total = 0
    for df_list in dict_split.values():
        for df in df_list:
            expected_total += max(0, len(df) - window_size)
    return expected_total

# ✅ 세트별 기대 윈도우 개수
expected_train = count_expected_windows(dict_split_train_only, window_size)
expected_valid = count_expected_windows(dict_split_valid_only, window_size)
expected_test  = count_expected_windows(dict_split_te_clean,  window_size)

# ✅ 실제 생성된 윈도우 개수 (앞서 만든 넘파이 배열 기준)
actual_train = X_train.shape[0]
actual_valid = X_valid.shape[0]
actual_test  = X_test.shape[0]

# ✅ 매칭 여부 출력
print(f"✅ Train: expected = {expected_train}, actual = {actual_train} → {'✔️ Match' if expected_train == actual_train else '❌ Mismatch'}")
print(f"✅ Valid: expected = {expected_valid}, actual = {actual_valid} → {'✔️ Match' if expected_valid == actual_valid else '❌ Mismatch'}")
print(f"✅ Test:  expected = {expected_test},  actual = {actual_test}  → {'✔️ Match' if expected_test  == actual_test  else '❌ Mismatch'}")
# Out:
# ✅ Train: expected = 4394, actual = 4394 → ✔️ Match
# ✅ Valid: expected = 1347, actual = 1347 → ✔️ Match
# ✅ Test:  expected = 2100,  actual = 2100  → ✔️ Match

# %%
def create_sequence_label_tensors(dict_split, window_size):
    X_all, y_all = [], []
    for df_list in dict_split.values():
        for df in df_list:
            if len(df) <= window_size:
                continue
            data = df[input_features].to_numpy()
            labels = df[target_features].to_numpy()
            for i in range(len(df) - window_size):
                window = data[i : i + window_size]
                label = labels[i + window_size]
                X_all.append(window)
                y_all.append(label)
    X_tensor = np.array(X_all)
    y_tensor = np.array(y_all)
    return X_tensor, y_tensor

# %%
X_train, y_train = create_sequence_label_tensors(dict_split_train_only, window_size)
X_valid, y_valid = create_sequence_label_tensors(dict_split_valid_only, window_size)
X_test,  y_test  = create_sequence_label_tensors(dict_split_te_clean,  window_size)

# %%
print(f"✅ Train sequences shape: {X_train.shape}")
print(f"✅ Train labels shape:    {y_train.shape}")
print(f"✅ Valid sequences shape: {X_valid.shape}")
print(f"✅ Valid labels shape:    {y_valid.shape}")
print(f"✅ Test sequences shape:  {X_test.shape}")
print(f"✅ Test labels shape:     {y_test.shape}")
# Out:
# ✅ Train sequences shape: (4394, 5, 8)
# ✅ Train labels shape:    (4394, 1)
# ✅ Valid sequences shape: (1347, 5, 8)
# ✅ Valid labels shape:    (1347, 1)
# ✅ Test sequences shape:  (2100, 5, 8)
# ✅ Test labels shape:     (2100, 1)

# %%
def make_loader(X, y, batch_size=64, shuffle=True):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)
    dataset = TensorDataset(X_tensor, y_tensor)

    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# %%
# Train loader
train_loader = make_loader(X_train, y_train, batch_size=64, shuffle=True)

# Valid loader
X_val_tensor = torch.tensor(X_valid, dtype=torch.float32)
y_val_tensor = torch.tensor(y_valid, dtype=torch.float32)
valid_dataset = TensorDataset(X_val_tensor, y_val_tensor)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

# Test loader
X_te_tensor = torch.tensor(X_test, dtype=torch.float32)
y_te_tensor = torch.tensor(y_test, dtype=torch.float32)
test_dataset = TensorDataset(X_te_tensor, y_te_tensor)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
import numpy as np
import torch
from sklearn.metrics import mean_squared_error

def compute_all_metrics(preds, targets):
    # 텐서를 numpy로 변환 (GPU/grad 대응)
    if isinstance(preds, torch.Tensor):
        preds = preds.detach().cpu().numpy()
    if isinstance(targets, torch.Tensor):
        targets = targets.detach().cpu().numpy()

    # sklearn 기본 MSE (전체 좌표 포함 평균)
    mse = mean_squared_error(targets, preds)

    return {
        'MSE': mse
    }

# %%
def show_delta_predictions(preds, targets, n=10):
    if isinstance(preds, torch.Tensor):
        preds = preds.detach().cpu().numpy()
    if isinstance(targets, torch.Tensor):
        targets = targets.detach().cpu().numpy()
    df = pd.DataFrame({
#        'D_lat_pred': preds[:n, 0],
#        'D_lat_true': targets[:n, 0],
        'D_lon_pred': preds[:n, 0],
        'D_lon_true': targets[:n, 0],
#        'D_alt_pred': preds[:n, 2],
#        'D_alt_true': targets[:n, 2],
    })
    return df.round(4)

# %%
import torch
import torch.nn as nn

class LSTMRegressor(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, lstm_layers, mlp_layers, output_dim=2, dropout=0.2):
        super(LSTMRegressor, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim,
                            hidden_size=lstm_hidden_dim,
                            num_layers=lstm_layers,
                            batch_first=True,
                            dropout=dropout)
        mlp = []
        in_dim = lstm_hidden_dim
        for _ in range(mlp_layers):
            out_dim = max(in_dim // 2, 8)
            mlp.append(nn.Linear(in_dim, out_dim))
            mlp.append(nn.ReLU())
            in_dim = out_dim
        mlp.append(nn.Linear(in_dim, output_dim))
        self.mlp = nn.Sequential(*mlp)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)        # (batch, seq_len, hidden)
        last_hidden = lstm_out[:, -1, :]  # 마지막 time step의 hidden
        return self.mlp(last_hidden)

# %%
import torch
import torch.nn as nn

def train_model_with_valid_early_stop(
    input_dim,
    output_dim,
    train_loader,
    valid_loader,
    n_epochs=300,
    lr=0.001,
    lstm_hidden_dim=128,
    lstm_layers=2,
    mlp_layers=4,
    patience=30,
    device='cuda' if torch.cuda.is_available() else 'cpu'
):
    model = LSTMRegressor(
        input_dim=input_dim,
        lstm_hidden_dim=lstm_hidden_dim,
        lstm_layers=lstm_layers,
        mlp_layers=mlp_layers,
        output_dim=output_dim
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
    criterion = nn.MSELoss()

    train_mse_curve, valid_mse_curve = [], []
    best_mse = float('inf')
    best_state = None
    best_epoch = 0
    no_improve = 0

    for epoch in range(n_epochs):
        # === Train ===
        model.train()
        all_preds, all_targets = [], []
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            preds = model(X_batch)
            loss = criterion(preds, y_batch)
            loss.backward()
            optimizer.step()
            all_preds.append(preds.detach().cpu())
            all_targets.append(y_batch.detach().cpu())

        train_mse = compute_all_metrics(torch.cat(all_preds), torch.cat(all_targets))['MSE']
        train_mse_curve.append(train_mse)

        # === Validation ===
        model.eval()
        val_preds, val_targets = [], []
        with torch.no_grad():
            for X_batch, y_batch in valid_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                preds = model(X_batch)
                val_preds.append(preds.detach().cpu())
                val_targets.append(y_batch.detach().cpu())
        valid_mse = compute_all_metrics(torch.cat(val_preds), torch.cat(val_targets))['MSE']
        valid_mse_curve.append(valid_mse)

        # 로그 출력
        if (epoch + 1) % 5 == 0 or valid_mse < best_mse:
            print(f"Epoch {epoch+1}/{n_epochs} - "
                  f"Train MSE: {train_mse:.6f} | Valid MSE: {valid_mse:.6f} | "
                  f"Best Valid MSE: {best_mse:.6f} (Epoch {best_epoch+1})")

        # Early stopping (valid 기준)
        if valid_mse < best_mse:
            best_mse = valid_mse
            best_state = model.state_dict()
            best_epoch = epoch
            no_improve = 0
            print("🎯 New Best Valid MSE!")
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"⏹️ Early stopping triggered at epoch {epoch+1}")
                break

    # 최적 가중치 로드 (best_state가 None이 아닌 경우에만)
    if best_state is not None:
        model.load_state_dict(best_state)
    print(f"✅ Finished. Best Valid MSE: {best_mse:.6f} at Epoch {best_epoch+1}")

    return model, train_mse_curve, valid_mse_curve, best_mse, best_epoch

# %%
import torch
import numpy as np

def evaluate_on_test_set_direct(
    model,
    test_loader,
    device=None,
    show_samples=10
):
    """
    이미 학습된 모델(model)을 그대로 사용해 test_loader를 평가합니다.
    - 모델 저장/재로딩 없이 바로 평가
    - compute_all_metrics를 사용해 지표(MSE 등) 계산
    """
    # 모델이 올라가 있는 디바이스 자동 감지
    if device is None:
        device = next(model.parameters()).device

    model.eval()
    all_preds, all_targets = [], []

    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch = X_batch.to(device)
            preds = model(X_batch).cpu()  # CPU로 모으기
            y_batch = y_batch.cpu()
            all_preds.append(preds)
            all_targets.append(y_batch)

    all_preds = torch.cat(all_preds, dim=0)
    all_targets = torch.cat(all_targets, dim=0)

    # 지표 계산
    test_metrics = compute_all_metrics(all_preds, all_targets)

    # 로그 출력
    print("\n🎯 Test Set Evaluation (direct)")
    for k, v in test_metrics.items():
        print(f"{k}: {v:.6f}")

    # 예측 vs 실제 샘플 표시
    print("\n🔍 Sample Predictions vs Targets:")
    preds_np = all_preds.numpy()
    targets_np = all_targets.numpy()
    for i in range(min(show_samples, len(preds_np))):
        print(f"[{i}] pred: {preds_np[i]},  true: {targets_np[i]}")

    return test_metrics, all_preds, all_targets

# %%
# 하이퍼파라미터
lstm_hidden_dim = 128
lstm_layers = 2
mlp_layers = 3
best_params = [lstm_hidden_dim, lstm_layers, mlp_layers]  # (재현/로그용)

# %%
model, tr_curve, va_curve, best_mse, best_ep = train_model_with_valid_early_stop(
    input_dim=len(input_features),          # 8
    output_dim=len(target_features),        # 2 (D_lat, D_lon)
    train_loader=train_loader,
    valid_loader=valid_loader,
    n_epochs=1000,
    lr=0.000001,
    lstm_hidden_dim=lstm_hidden_dim,
    lstm_layers=lstm_layers,
    mlp_layers=mlp_layers,
    patience=200
)
# Out:
# Epoch 1/1000 - Train MSE: 2015.927124 | Valid MSE: 1777.517090 | Best Valid MSE: inf (Epoch 1)
# 🎯 New Best Valid MSE!
# Epoch 2/1000 - Train MSE: 2015.892822 | Valid MSE: 1777.485352 | Best Valid MSE: 1777.517090 (Epoch 1)
# 🎯 New Best Valid MSE!
# Epoch 3/1000 - Train MSE: 2015.863037 | Valid MSE: 1777.453613 | Best Valid MSE: 1777.485352 (Epoch 2)
# 🎯 New Best Valid MSE!
# Epoch 4/1000 - Train MSE: 2015.831543 | Valid MSE: 1777.422974 | Best Valid MSE: 1777.453613 (Epoch 3)
# 🎯 New Best Valid MSE!
# Epoch 5/1000 - Train MSE: 2015.797241 | Valid MSE: 1777.392578 | Best Valid MSE: 1777.422974 (Epoch 4)
# 🎯 New Best Valid MSE!
# Epoch 6/1000 - Train MSE: 2015.767822 | Valid MSE: 1777.361938 | Best Valid MSE: 1777.392578 (Epoch 5)
# 🎯 New Best Valid MSE!
# Epoch 7/1000 - Train MSE: 2015.736450 | Valid MSE: 1777.331665 | Best Valid MSE: 1777.361938 (Epoch 6)
# 🎯 New Best Valid MSE!
# Epoch 8/1000 - Train MSE: 2015.704590 | Valid MSE: 1777.301025 | Best Valid MSE: 1777.331665 (Epoch 7)
# 🎯 New Best Valid MSE!
# Epoch 9/1000 - Train MSE: 2015.673218 | Valid MSE: 1777.270630 | Best Valid MSE: 1777.301025 (Epoch 8)
# 🎯 New Best Valid MSE!
# Epoch 10/1000 - Train MSE: 2015.639038 | Valid MSE: 1777.239990 | Best Valid MSE: 1777.270630 (Epoch 9)
# 🎯 New Best Valid MSE!
# Epoch 11/1000 - Train MSE: 2015.608154 | Valid MSE: 1777.208374 | Best Valid MSE: 1777.239990 (Epoch 10)
# 🎯 New Best Valid MSE!
# Epoch 12/1000 - Train MSE: 2015.571411 | Valid MSE: 1777.175171 | Best Valid MSE: 1777.208374 (Epoch 11)
# 🎯 New Best Valid MSE!
# Epoch 13/1000 - Train MSE: 2015.540771 | Valid MSE: 1777.141479 | Best Valid MSE: 1777.175171 (Epoch 12)
# 🎯 New Best Valid MSE!
# Epoch 14/1000 - Train MSE: 2015.504517 | Valid MSE: 1777.106323 | Best Valid MSE: 1777.141479 (Epoch 13)
# 🎯 New Best Valid MSE!
# Epoch 15/1000 - Train MSE: 2015.466064 | Valid MSE: 1777.070190 | Best Valid MSE: 1777.106323 (Epoch 14)
# 🎯 New Best Valid MSE!
# Epoch 16/1000 - Train MSE: 2015.430542 | Valid MSE: 1777.033447 | Best Valid MSE: 1777.070190 (Epoch 15)
# 🎯 New Best Valid MSE!
# Epoch 17/1000 - Train MSE: 2015.390503 | Valid MSE: 1776.995361 | Best Valid MSE: 1777.033447 (Epoch 16)
# 🎯 New Best Valid MSE!
# Epoch 18/1000 - Train MSE: 2015.354126 | Valid MSE: 1776.957153 | Best Valid MSE: 1776.995361 (Epoch 17)
# 🎯 New Best Valid MSE!
# Epoch 19/1000 - Train MSE: 2015.312012 | Valid MSE: 1776.918335 | Best Valid MSE: 1776.957153 (Epoch 18)
# 🎯 New Best Valid MSE!
# Epoch 20/1000 - Train MSE: 2015.270386 | Valid MSE: 1776.878296 | Best Valid MSE: 1776.918335 (Epoch 19)
# 🎯 New Best Valid MSE!
# Epoch 21/1000 - Train MSE: 2015.227295 | Valid MSE: 1776.838501 | Best Valid MSE: 1776.878296 (Epoch 20)
# 🎯 New Best Valid MSE!
# Epoch 22/1000 - Train MSE: 2015.185425 | Valid MSE: 1776.798096 | Best Valid MSE: 1776.838501 (Epoch 21)
# 🎯 New Best Valid MSE!
# Epoch 23/1000 - Train MSE: 2015.144775 | Valid MSE: 1776.757202 | Best Valid MSE: 1776.798096 (Epoch 22)
# 🎯 New Best Valid MSE!
# Epoch 24/1000 - Train MSE: 2015.104004 | Valid MSE: 1776.716553 | Best Valid MSE: 1776.757202 (Epoch 23)
# 🎯 New Best Valid MSE!
# Epoch 25/1000 - Train MSE: 2015.061035 | Valid MSE: 1776.675781 | Best Valid MSE: 1776.716553 (Epoch 24)
# 🎯 New Best Valid MSE!
# Epoch 26/1000 - Train MSE: 2015.015015 | Valid MSE: 1776.634155 | Best Valid MSE: 1776.675781 (Epoch 25)
# 🎯 New Best Valid MSE!
# Epoch 27/1000 - Train MSE: 2014.970581 | Valid MSE: 1776.592041 | Best Valid MSE: 1776.634155 (Epoch 26)
# 🎯 New Best Valid MSE!
# Epoch 28/1000 - Train MSE: 2014.927124 | Valid MSE: 1776.549927 | Best Valid MSE: 1776.592041 (Epoch 27)
# 🎯 New Best Valid MSE!
# Epoch 29/1000 - Train MSE: 2014.878418 | Valid MSE: 1776.506836 | Best Valid MSE: 1776.549927 (Epoch 28)
# 🎯 New Best Valid MSE!
# Epoch 30/1000 - Train MSE: 2014.837524 | Valid MSE: 1776.463013 | Best Valid MSE: 1776.506836 (Epoch 29)
# 🎯 New Best Valid MSE!
# Epoch 31/1000 - Train MSE: 2014.782715 | Valid MSE: 1776.418335 | Best Valid MSE: 1776.463013 (Epoch 30)
# 🎯 New Best Valid MSE!
# Epoch 32/1000 - Train MSE: 2014.735596 | Valid MSE: 1776.372437 | Best Valid MSE: 1776.418335 (Epoch 31)
# 🎯 New Best Valid MSE!
# Epoch 33/1000 - Train MSE: 2014.683228 | Valid MSE: 1776.324219 | Best Valid MSE: 1776.372437 (Epoch 32)
# 🎯 New Best Valid MSE!
# Epoch 34/1000 - Train MSE: 2014.632690 | Valid MSE: 1776.273438 | Best Valid MSE: 1776.324219 (Epoch 33)
# 🎯 New Best Valid MSE!
# Epoch 35/1000 - Train MSE: 2014.581055 | Valid MSE: 1776.219971 | Best Valid MSE: 1776.273438 (Epoch 34)
# 🎯 New Best Valid MSE!
# Epoch 36/1000 - Train MSE: 2014.527710 | Valid MSE: 1776.165894 | Best Valid MSE: 1776.219971 (Epoch 35)
# 🎯 New Best Valid MSE!
# Epoch 37/1000 - Train MSE: 2014.465210 | Valid MSE: 1776.111328 | Best Valid MSE: 1776.165894 (Epoch 36)
# 🎯 New Best Valid MSE!
# Epoch 38/1000 - Train MSE: 2014.411743 | Valid MSE: 1776.057129 | Best Valid MSE: 1776.111328 (Epoch 37)
# 🎯 New Best Valid MSE!
# Epoch 39/1000 - Train MSE: 2014.353027 | Valid MSE: 1776.004028 | Best Valid MSE: 1776.057129 (Epoch 38)
# 🎯 New Best Valid MSE!
# Epoch 40/1000 - Train MSE: 2014.293579 | Valid MSE: 1775.951782 | Best Valid MSE: 1776.004028 (Epoch 39)
# 🎯 New Best Valid MSE!
# Epoch 41/1000 - Train MSE: 2014.240356 | Valid MSE: 1775.899902 | Best Valid MSE: 1775.951782 (Epoch 40)
# 🎯 New Best Valid MSE!
# Epoch 42/1000 - Train MSE: 2014.183472 | Valid MSE: 1775.847656 | Best Valid MSE: 1775.899902 (Epoch 41)
# 🎯 New Best Valid MSE!
# Epoch 43/1000 - Train MSE: 2014.127441 | Valid MSE: 1775.795288 | Best Valid MSE: 1775.847656 (Epoch 42)
# 🎯 New Best Valid MSE!
# Epoch 44/1000 - Train MSE: 2014.072876 | Valid MSE: 1775.739746 | Best Valid MSE: 1775.795288 (Epoch 43)
# 🎯 New Best Valid MSE!
# Epoch 45/1000 - Train MSE: 2014.013184 | Valid MSE: 1775.681641 | Best Valid MSE: 1775.739746 (Epoch 44)
# 🎯 New Best Valid MSE!
# Epoch 46/1000 - Train MSE: 2013.950562 | Valid MSE: 1775.620117 | Best Valid MSE: 1775.681641 (Epoch 45)
# 🎯 New Best Valid MSE!
# Epoch 47/1000 - Train MSE: 2013.884888 | Valid MSE: 1775.557129 | Best Valid MSE: 1775.620117 (Epoch 46)
# 🎯 New Best Valid MSE!
# Epoch 48/1000 - Train MSE: 2013.818359 | Valid MSE: 1775.494385 | Best Valid MSE: 1775.557129 (Epoch 47)
# 🎯 New Best Valid MSE!
# Epoch 49/1000 - Train MSE: 2013.757812 | Valid MSE: 1775.432617 | Best Valid MSE: 1775.494385 (Epoch 48)
# 🎯 New Best Valid MSE!
# Epoch 50/1000 - Train MSE: 2013.687256 | Valid MSE: 1775.370850 | Best Valid MSE: 1775.432617 (Epoch 49)
# 🎯 New Best Valid MSE!
# Epoch 51/1000 - Train MSE: 2013.621338 | Valid MSE: 1775.307007 | Best Valid MSE: 1775.370850 (Epoch 50)
# 🎯 New Best Valid MSE!
# Epoch 52/1000 - Train MSE: 2013.553467 | Valid MSE: 1775.244019 | Best Valid MSE: 1775.307007 (Epoch 51)
# 🎯 New Best Valid MSE!
# Epoch 53/1000 - Train MSE: 2013.480225 | Valid MSE: 1775.179077 | Best Valid MSE: 1775.244019 (Epoch 52)
# 🎯 New Best Valid MSE!
# Epoch 54/1000 - Train MSE: 2013.410156 | Valid MSE: 1775.113159 | Best Valid MSE: 1775.179077 (Epoch 53)
# 🎯 New Best Valid MSE!
# Epoch 55/1000 - Train MSE: 2013.345703 | Valid MSE: 1775.046997 | Best Valid MSE: 1775.113159 (Epoch 54)
# 🎯 New Best Valid MSE!
# Epoch 56/1000 - Train MSE: 2013.274902 | Valid MSE: 1774.979370 | Best Valid MSE: 1775.046997 (Epoch 55)
# 🎯 New Best Valid MSE!
# Epoch 57/1000 - Train MSE: 2013.201416 | Valid MSE: 1774.911499 | Best Valid MSE: 1774.979370 (Epoch 56)
# 🎯 New Best Valid MSE!
# Epoch 58/1000 - Train MSE: 2013.130859 | Valid MSE: 1774.842285 | Best Valid MSE: 1774.911499 (Epoch 57)
# 🎯 New Best Valid MSE!
# Epoch 59/1000 - Train MSE: 2013.055298 | Valid MSE: 1774.773926 | Best Valid MSE: 1774.842285 (Epoch 58)
# 🎯 New Best Valid MSE!
# Epoch 60/1000 - Train MSE: 2012.979980 | Valid MSE: 1774.704468 | Best Valid MSE: 1774.773926 (Epoch 59)
# 🎯 New Best Valid MSE!
# Epoch 61/1000 - Train MSE: 2012.911011 | Valid MSE: 1774.634033 | Best Valid MSE: 1774.704468 (Epoch 60)
# 🎯 New Best Valid MSE!
# Epoch 62/1000 - Train MSE: 2012.835693 | Valid MSE: 1774.563110 | Best Valid MSE: 1774.634033 (Epoch 61)
# 🎯 New Best Valid MSE!
# Epoch 63/1000 - Train MSE: 2012.756958 | Valid MSE: 1774.491699 | Best Valid MSE: 1774.563110 (Epoch 62)
# 🎯 New Best Valid MSE!
# Epoch 64/1000 - Train MSE: 2012.684082 | Valid MSE: 1774.419067 | Best Valid MSE: 1774.491699 (Epoch 63)
# 🎯 New Best Valid MSE!
# Epoch 65/1000 - Train MSE: 2012.601074 | Valid MSE: 1774.348755 | Best Valid MSE: 1774.419067 (Epoch 64)
# 🎯 New Best Valid MSE!
# Epoch 66/1000 - Train MSE: 2012.530762 | Valid MSE: 1774.278809 | Best Valid MSE: 1774.348755 (Epoch 65)
# 🎯 New Best Valid MSE!
# Epoch 67/1000 - Train MSE: 2012.457642 | Valid MSE: 1774.211060 | Best Valid MSE: 1774.278809 (Epoch 66)
# 🎯 New Best Valid MSE!
# Epoch 68/1000 - Train MSE: 2012.385498 | Valid MSE: 1774.141235 | Best Valid MSE: 1774.211060 (Epoch 67)
# 🎯 New Best Valid MSE!
# Epoch 69/1000 - Train MSE: 2012.301758 | Valid MSE: 1774.071777 | Best Valid MSE: 1774.141235 (Epoch 68)
# 🎯 New Best Valid MSE!
# Epoch 70/1000 - Train MSE: 2012.229370 | Valid MSE: 1774.001465 | Best Valid MSE: 1774.071777 (Epoch 69)
# 🎯 New Best Valid MSE!
# Epoch 71/1000 - Train MSE: 2012.161987 | Valid MSE: 1773.930420 | Best Valid MSE: 1774.001465 (Epoch 70)
# 🎯 New Best Valid MSE!
# Epoch 72/1000 - Train MSE: 2012.085571 | Valid MSE: 1773.858032 | Best Valid MSE: 1773.930420 (Epoch 71)
# 🎯 New Best Valid MSE!
# Epoch 73/1000 - Train MSE: 2012.004150 | Valid MSE: 1773.783813 | Best Valid MSE: 1773.858032 (Epoch 72)
# 🎯 New Best Valid MSE!
# Epoch 74/1000 - Train MSE: 2011.927124 | Valid MSE: 1773.708008 | Best Valid MSE: 1773.783813 (Epoch 73)
# 🎯 New Best Valid MSE!
# Epoch 75/1000 - Train MSE: 2011.843384 | Valid MSE: 1773.630493 | Best Valid MSE: 1773.708008 (Epoch 74)
# 🎯 New Best Valid MSE!
# Epoch 76/1000 - Train MSE: 2011.758789 | Valid MSE: 1773.552490 | Best Valid MSE: 1773.630493 (Epoch 75)
# 🎯 New Best Valid MSE!
# Epoch 77/1000 - Train MSE: 2011.673706 | Valid MSE: 1773.471924 | Best Valid MSE: 1773.552490 (Epoch 76)
# 🎯 New Best Valid MSE!
# Epoch 78/1000 - Train MSE: 2011.593140 | Valid MSE: 1773.389038 | Best Valid MSE: 1773.471924 (Epoch 77)
# 🎯 New Best Valid MSE!
# Epoch 79/1000 - Train MSE: 2011.494751 | Valid MSE: 1773.303101 | Best Valid MSE: 1773.389038 (Epoch 78)
# 🎯 New Best Valid MSE!
# Epoch 80/1000 - Train MSE: 2011.409180 | Valid MSE: 1773.216064 | Best Valid MSE: 1773.303101 (Epoch 79)
# 🎯 New Best Valid MSE!
# Epoch 81/1000 - Train MSE: 2011.319702 | Valid MSE: 1773.126587 | Best Valid MSE: 1773.216064 (Epoch 80)
# 🎯 New Best Valid MSE!
# Epoch 82/1000 - Train MSE: 2011.221680 | Valid MSE: 1773.035645 | Best Valid MSE: 1773.126587 (Epoch 81)
# 🎯 New Best Valid MSE!
# Epoch 83/1000 - Train MSE: 2011.129761 | Valid MSE: 1772.941895 | Best Valid MSE: 1773.035645 (Epoch 82)
# 🎯 New Best Valid MSE!
# Epoch 84/1000 - Train MSE: 2011.023193 | Valid MSE: 1772.845947 | Best Valid MSE: 1772.941895 (Epoch 83)
# 🎯 New Best Valid MSE!
# Epoch 85/1000 - Train MSE: 2010.930420 | Valid MSE: 1772.748291 | Best Valid MSE: 1772.845947 (Epoch 84)
# 🎯 New Best Valid MSE!
# Epoch 86/1000 - Train MSE: 2010.825195 | Valid MSE: 1772.648804 | Best Valid MSE: 1772.748291 (Epoch 85)
# 🎯 New Best Valid MSE!
# Epoch 87/1000 - Train MSE: 2010.718750 | Valid MSE: 1772.546997 | Best Valid MSE: 1772.648804 (Epoch 86)
# 🎯 New Best Valid MSE!
# Epoch 88/1000 - Train MSE: 2010.616943 | Valid MSE: 1772.443237 | Best Valid MSE: 1772.546997 (Epoch 87)
# 🎯 New Best Valid MSE!
# Epoch 89/1000 - Train MSE: 2010.502075 | Valid MSE: 1772.340210 | Best Valid MSE: 1772.443237 (Epoch 88)
# 🎯 New Best Valid MSE!
# Epoch 90/1000 - Train MSE: 2010.390503 | Valid MSE: 1772.243896 | Best Valid MSE: 1772.340210 (Epoch 89)
# 🎯 New Best Valid MSE!
# Epoch 91/1000 - Train MSE: 2010.286743 | Valid MSE: 1772.149536 | Best Valid MSE: 1772.243896 (Epoch 90)
# 🎯 New Best Valid MSE!
# Epoch 92/1000 - Train MSE: 2010.190674 | Valid MSE: 1772.057007 | Best Valid MSE: 1772.149536 (Epoch 91)
# 🎯 New Best Valid MSE!
# Epoch 93/1000 - Train MSE: 2010.086670 | Valid MSE: 1771.961426 | Best Valid MSE: 1772.057007 (Epoch 92)
# 🎯 New Best Valid MSE!
# Epoch 94/1000 - Train MSE: 2009.985840 | Valid MSE: 1771.867432 | Best Valid MSE: 1771.961426 (Epoch 93)
# 🎯 New Best Valid MSE!
# Epoch 95/1000 - Train MSE: 2009.883423 | Valid MSE: 1771.775024 | Best Valid MSE: 1771.867432 (Epoch 94)
# 🎯 New Best Valid MSE!
# Epoch 96/1000 - Train MSE: 2009.779663 | Valid MSE: 1771.682617 | Best Valid MSE: 1771.775024 (Epoch 95)
# 🎯 New Best Valid MSE!
# Epoch 97/1000 - Train MSE: 2009.687256 | Valid MSE: 1771.592651 | Best Valid MSE: 1771.682617 (Epoch 96)
# 🎯 New Best Valid MSE!
# Epoch 98/1000 - Train MSE: 2009.583252 | Valid MSE: 1771.502930 | Best Valid MSE: 1771.592651 (Epoch 97)
# 🎯 New Best Valid MSE!
# Epoch 99/1000 - Train MSE: 2009.490479 | Valid MSE: 1771.414673 | Best Valid MSE: 1771.502930 (Epoch 98)
# 🎯 New Best Valid MSE!
# Epoch 100/1000 - Train MSE: 2009.388916 | Valid MSE: 1771.325684 | Best Valid MSE: 1771.414673 (Epoch 99)
# 🎯 New Best Valid MSE!
# Epoch 101/1000 - Train MSE: 2009.286743 | Valid MSE: 1771.235474 | Best Valid MSE: 1771.325684 (Epoch 100)
# 🎯 New Best Valid MSE!
# Epoch 102/1000 - Train MSE: 2009.191162 | Valid MSE: 1771.142578 | Best Valid MSE: 1771.235474 (Epoch 101)
# 🎯 New Best Valid MSE!
# Epoch 103/1000 - Train MSE: 2009.092896 | Valid MSE: 1771.049194 | Best Valid MSE: 1771.142578 (Epoch 102)
# 🎯 New Best Valid MSE!
# Epoch 104/1000 - Train MSE: 2008.999512 | Valid MSE: 1770.955322 | Best Valid MSE: 1771.049194 (Epoch 103)
# 🎯 New Best Valid MSE!
# Epoch 105/1000 - Train MSE: 2008.896240 | Valid MSE: 1770.858765 | Best Valid MSE: 1770.955322 (Epoch 104)
# 🎯 New Best Valid MSE!
# Epoch 106/1000 - Train MSE: 2008.787842 | Valid MSE: 1770.763916 | Best Valid MSE: 1770.858765 (Epoch 105)
# 🎯 New Best Valid MSE!
# Epoch 107/1000 - Train MSE: 2008.685913 | Valid MSE: 1770.666260 | Best Valid MSE: 1770.763916 (Epoch 106)
# 🎯 New Best Valid MSE!
# Epoch 108/1000 - Train MSE: 2008.591431 | Valid MSE: 1770.568726 | Best Valid MSE: 1770.666260 (Epoch 107)
# 🎯 New Best Valid MSE!
# Epoch 109/1000 - Train MSE: 2008.476074 | Valid MSE: 1770.470337 | Best Valid MSE: 1770.568726 (Epoch 108)
# 🎯 New Best Valid MSE!
# Epoch 110/1000 - Train MSE: 2008.379639 | Valid MSE: 1770.372070 | Best Valid MSE: 1770.470337 (Epoch 109)
# 🎯 New Best Valid MSE!
# Epoch 111/1000 - Train MSE: 2008.274048 | Valid MSE: 1770.276489 | Best Valid MSE: 1770.372070 (Epoch 110)
# 🎯 New Best Valid MSE!
# Epoch 112/1000 - Train MSE: 2008.161865 | Valid MSE: 1770.179688 | Best Valid MSE: 1770.276489 (Epoch 111)
# 🎯 New Best Valid MSE!
# Epoch 113/1000 - Train MSE: 2008.061035 | Valid MSE: 1770.080688 | Best Valid MSE: 1770.179688 (Epoch 112)
# 🎯 New Best Valid MSE!
# Epoch 114/1000 - Train MSE: 2007.953125 | Valid MSE: 1769.976562 | Best Valid MSE: 1770.080688 (Epoch 113)
# 🎯 New Best Valid MSE!
# Epoch 115/1000 - Train MSE: 2007.840210 | Valid MSE: 1769.873047 | Best Valid MSE: 1769.976562 (Epoch 114)
# 🎯 New Best Valid MSE!
# Epoch 116/1000 - Train MSE: 2007.725952 | Valid MSE: 1769.766357 | Best Valid MSE: 1769.873047 (Epoch 115)
# 🎯 New Best Valid MSE!
# Epoch 117/1000 - Train MSE: 2007.617188 | Valid MSE: 1769.659302 | Best Valid MSE: 1769.766357 (Epoch 116)
# 🎯 New Best Valid MSE!
# Epoch 118/1000 - Train MSE: 2007.506348 | Valid MSE: 1769.550537 | Best Valid MSE: 1769.659302 (Epoch 117)
# 🎯 New Best Valid MSE!
# Epoch 119/1000 - Train MSE: 2007.385010 | Valid MSE: 1769.439697 | Best Valid MSE: 1769.550537 (Epoch 118)
# 🎯 New Best Valid MSE!
# Epoch 120/1000 - Train MSE: 2007.264893 | Valid MSE: 1769.327637 | Best Valid MSE: 1769.439697 (Epoch 119)
# 🎯 New Best Valid MSE!
# Epoch 121/1000 - Train MSE: 2007.139282 | Valid MSE: 1769.213989 | Best Valid MSE: 1769.327637 (Epoch 120)
# 🎯 New Best Valid MSE!
# Epoch 122/1000 - Train MSE: 2007.027710 | Valid MSE: 1769.098877 | Best Valid MSE: 1769.213989 (Epoch 121)
# 🎯 New Best Valid MSE!
# Epoch 123/1000 - Train MSE: 2006.895752 | Valid MSE: 1768.983643 | Best Valid MSE: 1769.098877 (Epoch 122)
# 🎯 New Best Valid MSE!
# Epoch 124/1000 - Train MSE: 2006.783081 | Valid MSE: 1768.864014 | Best Valid MSE: 1768.983643 (Epoch 123)
# 🎯 New Best Valid MSE!
# Epoch 125/1000 - Train MSE: 2006.645630 | Valid MSE: 1768.744629 | Best Valid MSE: 1768.864014 (Epoch 124)
# 🎯 New Best Valid MSE!
# Epoch 126/1000 - Train MSE: 2006.524780 | Valid MSE: 1768.621338 | Best Valid MSE: 1768.744629 (Epoch 125)
# 🎯 New Best Valid MSE!
# Epoch 127/1000 - Train MSE: 2006.387817 | Valid MSE: 1768.497437 | Best Valid MSE: 1768.621338 (Epoch 126)
# 🎯 New Best Valid MSE!
# Epoch 128/1000 - Train MSE: 2006.255371 | Valid MSE: 1768.372070 | Best Valid MSE: 1768.497437 (Epoch 127)
# 🎯 New Best Valid MSE!
# Epoch 129/1000 - Train MSE: 2006.118774 | Valid MSE: 1768.243286 | Best Valid MSE: 1768.372070 (Epoch 128)
# 🎯 New Best Valid MSE!
# Epoch 130/1000 - Train MSE: 2005.984009 | Valid MSE: 1768.113159 | Best Valid MSE: 1768.243286 (Epoch 129)
# 🎯 New Best Valid MSE!
# Epoch 131/1000 - Train MSE: 2005.836182 | Valid MSE: 1767.979248 | Best Valid MSE: 1768.113159 (Epoch 130)
# 🎯 New Best Valid MSE!
# Epoch 132/1000 - Train MSE: 2005.702148 | Valid MSE: 1767.842773 | Best Valid MSE: 1767.979248 (Epoch 131)
# 🎯 New Best Valid MSE!
# Epoch 133/1000 - Train MSE: 2005.553223 | Valid MSE: 1767.705322 | Best Valid MSE: 1767.842773 (Epoch 132)
# 🎯 New Best Valid MSE!
# Epoch 134/1000 - Train MSE: 2005.408081 | Valid MSE: 1767.567749 | Best Valid MSE: 1767.705322 (Epoch 133)
# 🎯 New Best Valid MSE!
# Epoch 135/1000 - Train MSE: 2005.263306 | Valid MSE: 1767.424316 | Best Valid MSE: 1767.567749 (Epoch 134)
# 🎯 New Best Valid MSE!
# Epoch 136/1000 - Train MSE: 2005.108765 | Valid MSE: 1767.279907 | Best Valid MSE: 1767.424316 (Epoch 135)
# 🎯 New Best Valid MSE!
# Epoch 137/1000 - Train MSE: 2004.946777 | Valid MSE: 1767.134766 | Best Valid MSE: 1767.279907 (Epoch 136)
# 🎯 New Best Valid MSE!
# Epoch 138/1000 - Train MSE: 2004.802002 | Valid MSE: 1766.988647 | Best Valid MSE: 1767.134766 (Epoch 137)
# 🎯 New Best Valid MSE!
# Epoch 139/1000 - Train MSE: 2004.636963 | Valid MSE: 1766.838501 | Best Valid MSE: 1766.988647 (Epoch 138)
# 🎯 New Best Valid MSE!
# Epoch 140/1000 - Train MSE: 2004.477905 | Valid MSE: 1766.688599 | Best Valid MSE: 1766.838501 (Epoch 139)
# 🎯 New Best Valid MSE!
# Epoch 141/1000 - Train MSE: 2004.317749 | Valid MSE: 1766.533813 | Best Valid MSE: 1766.688599 (Epoch 140)
# 🎯 New Best Valid MSE!
# Epoch 142/1000 - Train MSE: 2004.161621 | Valid MSE: 1766.378296 | Best Valid MSE: 1766.533813 (Epoch 141)
# 🎯 New Best Valid MSE!
# Epoch 143/1000 - Train MSE: 2003.989502 | Valid MSE: 1766.222900 | Best Valid MSE: 1766.378296 (Epoch 142)
# 🎯 New Best Valid MSE!
# Epoch 144/1000 - Train MSE: 2003.820679 | Valid MSE: 1766.063843 | Best Valid MSE: 1766.222900 (Epoch 143)
# 🎯 New Best Valid MSE!
# Epoch 145/1000 - Train MSE: 2003.656860 | Valid MSE: 1765.902588 | Best Valid MSE: 1766.063843 (Epoch 144)
# 🎯 New Best Valid MSE!
# Epoch 146/1000 - Train MSE: 2003.469238 | Valid MSE: 1765.738892 | Best Valid MSE: 1765.902588 (Epoch 145)
# 🎯 New Best Valid MSE!
# Epoch 147/1000 - Train MSE: 2003.309082 | Valid MSE: 1765.574585 | Best Valid MSE: 1765.738892 (Epoch 146)
# 🎯 New Best Valid MSE!
# Epoch 148/1000 - Train MSE: 2003.125122 | Valid MSE: 1765.406860 | Best Valid MSE: 1765.574585 (Epoch 147)
# 🎯 New Best Valid MSE!
# Epoch 149/1000 - Train MSE: 2002.940796 | Valid MSE: 1765.237183 | Best Valid MSE: 1765.406860 (Epoch 148)
# 🎯 New Best Valid MSE!
# Epoch 150/1000 - Train MSE: 2002.764893 | Valid MSE: 1765.066406 | Best Valid MSE: 1765.237183 (Epoch 149)
# 🎯 New Best Valid MSE!
# Epoch 151/1000 - Train MSE: 2002.566650 | Valid MSE: 1764.892700 | Best Valid MSE: 1765.066406 (Epoch 150)
# 🎯 New Best Valid MSE!
# Epoch 152/1000 - Train MSE: 2002.392334 | Valid MSE: 1764.718628 | Best Valid MSE: 1764.892700 (Epoch 151)
# 🎯 New Best Valid MSE!
# Epoch 153/1000 - Train MSE: 2002.213867 | Valid MSE: 1764.544189 | Best Valid MSE: 1764.718628 (Epoch 152)
# 🎯 New Best Valid MSE!
# Epoch 154/1000 - Train MSE: 2002.022705 | Valid MSE: 1764.364014 | Best Valid MSE: 1764.544189 (Epoch 153)
# 🎯 New Best Valid MSE!
# Epoch 155/1000 - Train MSE: 2001.813354 | Valid MSE: 1764.183594 | Best Valid MSE: 1764.364014 (Epoch 154)
# 🎯 New Best Valid MSE!
# Epoch 156/1000 - Train MSE: 2001.623779 | Valid MSE: 1764.001099 | Best Valid MSE: 1764.183594 (Epoch 155)
# 🎯 New Best Valid MSE!
# Epoch 157/1000 - Train MSE: 2001.438721 | Valid MSE: 1763.817383 | Best Valid MSE: 1764.001099 (Epoch 156)
# 🎯 New Best Valid MSE!
# Epoch 158/1000 - Train MSE: 2001.245361 | Valid MSE: 1763.631592 | Best Valid MSE: 1763.817383 (Epoch 157)
# 🎯 New Best Valid MSE!
# Epoch 159/1000 - Train MSE: 2001.050049 | Valid MSE: 1763.442505 | Best Valid MSE: 1763.631592 (Epoch 158)
# 🎯 New Best Valid MSE!
# Epoch 160/1000 - Train MSE: 2000.830200 | Valid MSE: 1763.253174 | Best Valid MSE: 1763.442505 (Epoch 159)
# 🎯 New Best Valid MSE!
# Epoch 161/1000 - Train MSE: 2000.632202 | Valid MSE: 1763.062012 | Best Valid MSE: 1763.253174 (Epoch 160)
# 🎯 New Best Valid MSE!
# Epoch 162/1000 - Train MSE: 2000.428589 | Valid MSE: 1762.869019 | Best Valid MSE: 1763.062012 (Epoch 161)
# 🎯 New Best Valid MSE!
# Epoch 163/1000 - Train MSE: 2000.222168 | Valid MSE: 1762.674316 | Best Valid MSE: 1762.869019 (Epoch 162)
# 🎯 New Best Valid MSE!
# Epoch 164/1000 - Train MSE: 2000.018677 | Valid MSE: 1762.478149 | Best Valid MSE: 1762.674316 (Epoch 163)
# 🎯 New Best Valid MSE!
# Epoch 165/1000 - Train MSE: 1999.805176 | Valid MSE: 1762.279541 | Best Valid MSE: 1762.478149 (Epoch 164)
# 🎯 New Best Valid MSE!
# Epoch 166/1000 - Train MSE: 1999.586060 | Valid MSE: 1762.079590 | Best Valid MSE: 1762.279541 (Epoch 165)
# 🎯 New Best Valid MSE!
# Epoch 167/1000 - Train MSE: 1999.370972 | Valid MSE: 1761.877563 | Best Valid MSE: 1762.079590 (Epoch 166)
# 🎯 New Best Valid MSE!
# Epoch 168/1000 - Train MSE: 1999.153442 | Valid MSE: 1761.675903 | Best Valid MSE: 1761.877563 (Epoch 167)
# 🎯 New Best Valid MSE!
# Epoch 169/1000 - Train MSE: 1998.929688 | Valid MSE: 1761.468994 | Best Valid MSE: 1761.675903 (Epoch 168)
# 🎯 New Best Valid MSE!
# Epoch 170/1000 - Train MSE: 1998.705566 | Valid MSE: 1761.263794 | Best Valid MSE: 1761.468994 (Epoch 169)
# 🎯 New Best Valid MSE!
# Epoch 171/1000 - Train MSE: 1998.476562 | Valid MSE: 1761.053833 | Best Valid MSE: 1761.263794 (Epoch 170)
# 🎯 New Best Valid MSE!
# Epoch 172/1000 - Train MSE: 1998.274414 | Valid MSE: 1760.844849 | Best Valid MSE: 1761.053833 (Epoch 171)
# 🎯 New Best Valid MSE!
# Epoch 173/1000 - Train MSE: 1998.060059 | Valid MSE: 1760.632202 | Best Valid MSE: 1760.844849 (Epoch 172)
# 🎯 New Best Valid MSE!
# Epoch 174/1000 - Train MSE: 1997.814575 | Valid MSE: 1760.419312 | Best Valid MSE: 1760.632202 (Epoch 173)
# 🎯 New Best Valid MSE!
# Epoch 175/1000 - Train MSE: 1997.579468 | Valid MSE: 1760.196899 | Best Valid MSE: 1760.419312 (Epoch 174)
# 🎯 New Best Valid MSE!
# Epoch 176/1000 - Train MSE: 1997.317261 | Valid MSE: 1759.964355 | Best Valid MSE: 1760.196899 (Epoch 175)
# 🎯 New Best Valid MSE!
# Epoch 177/1000 - Train MSE: 1997.093750 | Valid MSE: 1759.734619 | Best Valid MSE: 1759.964355 (Epoch 176)
# 🎯 New Best Valid MSE!
# Epoch 178/1000 - Train MSE: 1996.832031 | Valid MSE: 1759.505005 | Best Valid MSE: 1759.734619 (Epoch 177)
# 🎯 New Best Valid MSE!
# Epoch 179/1000 - Train MSE: 1996.586426 | Valid MSE: 1759.271851 | Best Valid MSE: 1759.505005 (Epoch 178)
# 🎯 New Best Valid MSE!
# Epoch 180/1000 - Train MSE: 1996.337524 | Valid MSE: 1759.040771 | Best Valid MSE: 1759.271851 (Epoch 179)
# 🎯 New Best Valid MSE!
# Epoch 181/1000 - Train MSE: 1996.092407 | Valid MSE: 1758.806274 | Best Valid MSE: 1759.040771 (Epoch 180)
# 🎯 New Best Valid MSE!
# Epoch 182/1000 - Train MSE: 1995.839966 | Valid MSE: 1758.569946 | Best Valid MSE: 1758.806274 (Epoch 181)
# 🎯 New Best Valid MSE!
# Epoch 183/1000 - Train MSE: 1995.580322 | Valid MSE: 1758.334961 | Best Valid MSE: 1758.569946 (Epoch 182)
# 🎯 New Best Valid MSE!
# Epoch 184/1000 - Train MSE: 1995.321777 | Valid MSE: 1758.097412 | Best Valid MSE: 1758.334961 (Epoch 183)
# 🎯 New Best Valid MSE!
# Epoch 185/1000 - Train MSE: 1995.076904 | Valid MSE: 1757.857788 | Best Valid MSE: 1758.097412 (Epoch 184)
# 🎯 New Best Valid MSE!
# Epoch 186/1000 - Train MSE: 1994.817993 | Valid MSE: 1757.617065 | Best Valid MSE: 1757.857788 (Epoch 185)
# 🎯 New Best Valid MSE!
# Epoch 187/1000 - Train MSE: 1994.544434 | Valid MSE: 1757.373657 | Best Valid MSE: 1757.617065 (Epoch 186)
# 🎯 New Best Valid MSE!
# Epoch 188/1000 - Train MSE: 1994.281250 | Valid MSE: 1757.130859 | Best Valid MSE: 1757.373657 (Epoch 187)
# 🎯 New Best Valid MSE!
# Epoch 189/1000 - Train MSE: 1994.017700 | Valid MSE: 1756.882690 | Best Valid MSE: 1757.130859 (Epoch 188)
# 🎯 New Best Valid MSE!
# Epoch 190/1000 - Train MSE: 1993.759277 | Valid MSE: 1756.636597 | Best Valid MSE: 1756.882690 (Epoch 189)
# 🎯 New Best Valid MSE!
# Epoch 191/1000 - Train MSE: 1993.497925 | Valid MSE: 1756.387695 | Best Valid MSE: 1756.636597 (Epoch 190)
# 🎯 New Best Valid MSE!
# Epoch 192/1000 - Train MSE: 1993.227539 | Valid MSE: 1756.140259 | Best Valid MSE: 1756.387695 (Epoch 191)
# 🎯 New Best Valid MSE!
# Epoch 193/1000 - Train MSE: 1992.969727 | Valid MSE: 1755.890259 | Best Valid MSE: 1756.140259 (Epoch 192)
# 🎯 New Best Valid MSE!
# Epoch 194/1000 - Train MSE: 1992.670410 | Valid MSE: 1755.635864 | Best Valid MSE: 1755.890259 (Epoch 193)
# 🎯 New Best Valid MSE!
# Epoch 195/1000 - Train MSE: 1992.409180 | Valid MSE: 1755.382324 | Best Valid MSE: 1755.635864 (Epoch 194)
# 🎯 New Best Valid MSE!
# Epoch 196/1000 - Train MSE: 1992.128784 | Valid MSE: 1755.125244 | Best Valid MSE: 1755.382324 (Epoch 195)
# 🎯 New Best Valid MSE!
# Epoch 197/1000 - Train MSE: 1991.856567 | Valid MSE: 1754.864502 | Best Valid MSE: 1755.125244 (Epoch 196)
# 🎯 New Best Valid MSE!
# Epoch 198/1000 - Train MSE: 1991.575317 | Valid MSE: 1754.608765 | Best Valid MSE: 1754.864502 (Epoch 197)
# 🎯 New Best Valid MSE!
# Epoch 199/1000 - Train MSE: 1991.317749 | Valid MSE: 1754.347412 | Best Valid MSE: 1754.608765 (Epoch 198)
# 🎯 New Best Valid MSE!
# Epoch 200/1000 - Train MSE: 1991.026855 | Valid MSE: 1754.084473 | Best Valid MSE: 1754.347412 (Epoch 199)
# 🎯 New Best Valid MSE!
# Epoch 201/1000 - Train MSE: 1990.725708 | Valid MSE: 1753.820557 | Best Valid MSE: 1754.084473 (Epoch 200)
# 🎯 New Best Valid MSE!
# Epoch 202/1000 - Train MSE: 1990.453857 | Valid MSE: 1753.554565 | Best Valid MSE: 1753.820557 (Epoch 201)
# 🎯 New Best Valid MSE!
# Epoch 203/1000 - Train MSE: 1990.156128 | Valid MSE: 1753.287354 | Best Valid MSE: 1753.554565 (Epoch 202)
# 🎯 New Best Valid MSE!
# Epoch 204/1000 - Train MSE: 1989.870728 | Valid MSE: 1753.020752 | Best Valid MSE: 1753.287354 (Epoch 203)
# 🎯 New Best Valid MSE!
# Epoch 205/1000 - Train MSE: 1989.591919 | Valid MSE: 1752.748535 | Best Valid MSE: 1753.020752 (Epoch 204)
# 🎯 New Best Valid MSE!
# Epoch 206/1000 - Train MSE: 1989.284668 | Valid MSE: 1752.478516 | Best Valid MSE: 1752.748535 (Epoch 205)
# 🎯 New Best Valid MSE!
# Epoch 207/1000 - Train MSE: 1989.004517 | Valid MSE: 1752.202515 | Best Valid MSE: 1752.478516 (Epoch 206)
# 🎯 New Best Valid MSE!
# Epoch 208/1000 - Train MSE: 1988.697998 | Valid MSE: 1751.928589 | Best Valid MSE: 1752.202515 (Epoch 207)
# 🎯 New Best Valid MSE!
# Epoch 209/1000 - Train MSE: 1988.405273 | Valid MSE: 1751.651978 | Best Valid MSE: 1751.928589 (Epoch 208)
# 🎯 New Best Valid MSE!
# Epoch 210/1000 - Train MSE: 1988.094727 | Valid MSE: 1751.372681 | Best Valid MSE: 1751.651978 (Epoch 209)
# 🎯 New Best Valid MSE!
# Epoch 211/1000 - Train MSE: 1987.803345 | Valid MSE: 1751.093018 | Best Valid MSE: 1751.372681 (Epoch 210)
# 🎯 New Best Valid MSE!
# Epoch 212/1000 - Train MSE: 1987.496582 | Valid MSE: 1750.813721 | Best Valid MSE: 1751.093018 (Epoch 211)
# 🎯 New Best Valid MSE!
# Epoch 213/1000 - Train MSE: 1987.178223 | Valid MSE: 1750.529175 | Best Valid MSE: 1750.813721 (Epoch 212)
# 🎯 New Best Valid MSE!
# Epoch 214/1000 - Train MSE: 1986.886841 | Valid MSE: 1750.244751 | Best Valid MSE: 1750.529175 (Epoch 213)
# 🎯 New Best Valid MSE!
# Epoch 215/1000 - Train MSE: 1986.592163 | Valid MSE: 1749.959595 | Best Valid MSE: 1750.244751 (Epoch 214)
# 🎯 New Best Valid MSE!
# Epoch 216/1000 - Train MSE: 1986.262573 | Valid MSE: 1749.669312 | Best Valid MSE: 1749.959595 (Epoch 215)
# 🎯 New Best Valid MSE!
# Epoch 217/1000 - Train MSE: 1985.949463 | Valid MSE: 1749.379028 | Best Valid MSE: 1749.669312 (Epoch 216)
# 🎯 New Best Valid MSE!
# Epoch 218/1000 - Train MSE: 1985.645874 | Valid MSE: 1749.087769 | Best Valid MSE: 1749.379028 (Epoch 217)
# 🎯 New Best Valid MSE!
# Epoch 219/1000 - Train MSE: 1985.319092 | Valid MSE: 1748.797363 | Best Valid MSE: 1749.087769 (Epoch 218)
# 🎯 New Best Valid MSE!
# Epoch 220/1000 - Train MSE: 1985.018433 | Valid MSE: 1748.501831 | Best Valid MSE: 1748.797363 (Epoch 219)
# 🎯 New Best Valid MSE!
# Epoch 221/1000 - Train MSE: 1984.677734 | Valid MSE: 1748.206787 | Best Valid MSE: 1748.501831 (Epoch 220)
# 🎯 New Best Valid MSE!
# Epoch 222/1000 - Train MSE: 1984.363647 | Valid MSE: 1747.906616 | Best Valid MSE: 1748.206787 (Epoch 221)
# 🎯 New Best Valid MSE!
# Epoch 223/1000 - Train MSE: 1984.033691 | Valid MSE: 1747.605591 | Best Valid MSE: 1747.906616 (Epoch 222)
# 🎯 New Best Valid MSE!
# Epoch 224/1000 - Train MSE: 1983.720581 | Valid MSE: 1747.305298 | Best Valid MSE: 1747.605591 (Epoch 223)
# 🎯 New Best Valid MSE!
# Epoch 225/1000 - Train MSE: 1983.388672 | Valid MSE: 1747.001831 | Best Valid MSE: 1747.305298 (Epoch 224)
# 🎯 New Best Valid MSE!
# Epoch 226/1000 - Train MSE: 1983.056030 | Valid MSE: 1746.697144 | Best Valid MSE: 1747.001831 (Epoch 225)
# 🎯 New Best Valid MSE!
# Epoch 227/1000 - Train MSE: 1982.717163 | Valid MSE: 1746.392700 | Best Valid MSE: 1746.697144 (Epoch 226)
# 🎯 New Best Valid MSE!
# Epoch 228/1000 - Train MSE: 1982.405518 | Valid MSE: 1746.079224 | Best Valid MSE: 1746.392700 (Epoch 227)
# 🎯 New Best Valid MSE!
# Epoch 229/1000 - Train MSE: 1982.070312 | Valid MSE: 1745.762207 | Best Valid MSE: 1746.079224 (Epoch 228)
# 🎯 New Best Valid MSE!
# Epoch 230/1000 - Train MSE: 1981.690063 | Valid MSE: 1745.439331 | Best Valid MSE: 1745.762207 (Epoch 229)
# 🎯 New Best Valid MSE!
# Epoch 231/1000 - Train MSE: 1981.362793 | Valid MSE: 1745.122314 | Best Valid MSE: 1745.439331 (Epoch 230)
# 🎯 New Best Valid MSE!
# Epoch 232/1000 - Train MSE: 1981.005737 | Valid MSE: 1744.800903 | Best Valid MSE: 1745.122314 (Epoch 231)
# 🎯 New Best Valid MSE!
# Epoch 233/1000 - Train MSE: 1980.655884 | Valid MSE: 1744.473511 | Best Valid MSE: 1744.800903 (Epoch 232)
# 🎯 New Best Valid MSE!
# Epoch 234/1000 - Train MSE: 1980.316528 | Valid MSE: 1744.154419 | Best Valid MSE: 1744.473511 (Epoch 233)
# 🎯 New Best Valid MSE!
# Epoch 235/1000 - Train MSE: 1979.953979 | Valid MSE: 1743.831055 | Best Valid MSE: 1744.154419 (Epoch 234)
# 🎯 New Best Valid MSE!
# Epoch 236/1000 - Train MSE: 1979.633789 | Valid MSE: 1743.500244 | Best Valid MSE: 1743.831055 (Epoch 235)
# 🎯 New Best Valid MSE!
# Epoch 237/1000 - Train MSE: 1979.266235 | Valid MSE: 1743.167358 | Best Valid MSE: 1743.500244 (Epoch 236)
# 🎯 New Best Valid MSE!
# Epoch 238/1000 - Train MSE: 1978.911255 | Valid MSE: 1742.830566 | Best Valid MSE: 1743.167358 (Epoch 237)
# 🎯 New Best Valid MSE!
# Epoch 239/1000 - Train MSE: 1978.550293 | Valid MSE: 1742.493164 | Best Valid MSE: 1742.830566 (Epoch 238)
# 🎯 New Best Valid MSE!
# Epoch 240/1000 - Train MSE: 1978.164795 | Valid MSE: 1742.154663 | Best Valid MSE: 1742.493164 (Epoch 239)
# 🎯 New Best Valid MSE!
# Epoch 241/1000 - Train MSE: 1977.784302 | Valid MSE: 1741.813232 | Best Valid MSE: 1742.154663 (Epoch 240)
# 🎯 New Best Valid MSE!
# Epoch 242/1000 - Train MSE: 1977.422119 | Valid MSE: 1741.472900 | Best Valid MSE: 1741.813232 (Epoch 241)
# 🎯 New Best Valid MSE!
# Epoch 243/1000 - Train MSE: 1977.055542 | Valid MSE: 1741.129883 | Best Valid MSE: 1741.472900 (Epoch 242)
# 🎯 New Best Valid MSE!
# Epoch 244/1000 - Train MSE: 1976.686401 | Valid MSE: 1740.786011 | Best Valid MSE: 1741.129883 (Epoch 243)
# 🎯 New Best Valid MSE!
# Epoch 245/1000 - Train MSE: 1976.299072 | Valid MSE: 1740.440186 | Best Valid MSE: 1740.786011 (Epoch 244)
# 🎯 New Best Valid MSE!
# Epoch 246/1000 - Train MSE: 1975.945801 | Valid MSE: 1740.090576 | Best Valid MSE: 1740.440186 (Epoch 245)
# 🎯 New Best Valid MSE!
# Epoch 247/1000 - Train MSE: 1975.561646 | Valid MSE: 1739.744019 | Best Valid MSE: 1740.090576 (Epoch 246)
# 🎯 New Best Valid MSE!
# Epoch 248/1000 - Train MSE: 1975.160400 | Valid MSE: 1739.392944 | Best Valid MSE: 1739.744019 (Epoch 247)
# 🎯 New Best Valid MSE!
# Epoch 249/1000 - Train MSE: 1974.785156 | Valid MSE: 1739.038574 | Best Valid MSE: 1739.392944 (Epoch 248)
# 🎯 New Best Valid MSE!
# Epoch 250/1000 - Train MSE: 1974.404907 | Valid MSE: 1738.686890 | Best Valid MSE: 1739.038574 (Epoch 249)
# 🎯 New Best Valid MSE!
# Epoch 251/1000 - Train MSE: 1974.026855 | Valid MSE: 1738.330322 | Best Valid MSE: 1738.686890 (Epoch 250)
# 🎯 New Best Valid MSE!
# Epoch 252/1000 - Train MSE: 1973.651855 | Valid MSE: 1737.969604 | Best Valid MSE: 1738.330322 (Epoch 251)
# 🎯 New Best Valid MSE!
# Epoch 253/1000 - Train MSE: 1973.256958 | Valid MSE: 1737.611694 | Best Valid MSE: 1737.969604 (Epoch 252)
# 🎯 New Best Valid MSE!
# Epoch 254/1000 - Train MSE: 1972.876831 | Valid MSE: 1737.247803 | Best Valid MSE: 1737.611694 (Epoch 253)
# 🎯 New Best Valid MSE!
# Epoch 255/1000 - Train MSE: 1972.472900 | Valid MSE: 1736.889038 | Best Valid MSE: 1737.247803 (Epoch 254)
# 🎯 New Best Valid MSE!
# Epoch 256/1000 - Train MSE: 1972.061646 | Valid MSE: 1736.526733 | Best Valid MSE: 1736.889038 (Epoch 255)
# 🎯 New Best Valid MSE!
# Epoch 257/1000 - Train MSE: 1971.671997 | Valid MSE: 1736.156982 | Best Valid MSE: 1736.526733 (Epoch 256)
# 🎯 New Best Valid MSE!
# Epoch 258/1000 - Train MSE: 1971.294434 | Valid MSE: 1735.789917 | Best Valid MSE: 1736.156982 (Epoch 257)
# 🎯 New Best Valid MSE!
# Epoch 259/1000 - Train MSE: 1970.891235 | Valid MSE: 1735.417358 | Best Valid MSE: 1735.789917 (Epoch 258)
# 🎯 New Best Valid MSE!
# Epoch 260/1000 - Train MSE: 1970.499146 | Valid MSE: 1735.047729 | Best Valid MSE: 1735.417358 (Epoch 259)
# 🎯 New Best Valid MSE!
# Epoch 261/1000 - Train MSE: 1970.084229 | Valid MSE: 1734.671265 | Best Valid MSE: 1735.047729 (Epoch 260)
# 🎯 New Best Valid MSE!
# Epoch 262/1000 - Train MSE: 1969.659790 | Valid MSE: 1734.290405 | Best Valid MSE: 1734.671265 (Epoch 261)
# 🎯 New Best Valid MSE!
# Epoch 263/1000 - Train MSE: 1969.266724 | Valid MSE: 1733.903320 | Best Valid MSE: 1734.290405 (Epoch 262)
# 🎯 New Best Valid MSE!
# Epoch 264/1000 - Train MSE: 1968.838013 | Valid MSE: 1733.512817 | Best Valid MSE: 1733.903320 (Epoch 263)
# 🎯 New Best Valid MSE!
# Epoch 265/1000 - Train MSE: 1968.429688 | Valid MSE: 1733.125488 | Best Valid MSE: 1733.512817 (Epoch 264)
# 🎯 New Best Valid MSE!
# Epoch 266/1000 - Train MSE: 1967.985718 | Valid MSE: 1732.732422 | Best Valid MSE: 1733.125488 (Epoch 265)
# 🎯 New Best Valid MSE!
# Epoch 267/1000 - Train MSE: 1967.565308 | Valid MSE: 1732.339966 | Best Valid MSE: 1732.732422 (Epoch 266)
# 🎯 New Best Valid MSE!
# Epoch 268/1000 - Train MSE: 1967.142456 | Valid MSE: 1731.944336 | Best Valid MSE: 1732.339966 (Epoch 267)
# 🎯 New Best Valid MSE!
# Epoch 269/1000 - Train MSE: 1966.723755 | Valid MSE: 1731.555298 | Best Valid MSE: 1731.944336 (Epoch 268)
# 🎯 New Best Valid MSE!
# Epoch 270/1000 - Train MSE: 1966.265381 | Valid MSE: 1731.157959 | Best Valid MSE: 1731.555298 (Epoch 269)
# 🎯 New Best Valid MSE!
# Epoch 271/1000 - Train MSE: 1965.866821 | Valid MSE: 1730.762207 | Best Valid MSE: 1731.157959 (Epoch 270)
# 🎯 New Best Valid MSE!
# Epoch 272/1000 - Train MSE: 1965.423950 | Valid MSE: 1730.365234 | Best Valid MSE: 1730.762207 (Epoch 271)
# 🎯 New Best Valid MSE!
# Epoch 273/1000 - Train MSE: 1964.971802 | Valid MSE: 1729.964722 | Best Valid MSE: 1730.365234 (Epoch 272)
# 🎯 New Best Valid MSE!
# Epoch 274/1000 - Train MSE: 1964.551636 | Valid MSE: 1729.561279 | Best Valid MSE: 1729.964722 (Epoch 273)
# 🎯 New Best Valid MSE!
# Epoch 275/1000 - Train MSE: 1964.114746 | Valid MSE: 1729.158813 | Best Valid MSE: 1729.561279 (Epoch 274)
# 🎯 New Best Valid MSE!
# Epoch 276/1000 - Train MSE: 1963.663208 | Valid MSE: 1728.755981 | Best Valid MSE: 1729.158813 (Epoch 275)
# 🎯 New Best Valid MSE!
# Epoch 277/1000 - Train MSE: 1963.249390 | Valid MSE: 1728.348389 | Best Valid MSE: 1728.755981 (Epoch 276)
# 🎯 New Best Valid MSE!
# Epoch 278/1000 - Train MSE: 1962.800171 | Valid MSE: 1727.939331 | Best Valid MSE: 1728.348389 (Epoch 277)
# 🎯 New Best Valid MSE!
# Epoch 279/1000 - Train MSE: 1962.349121 | Valid MSE: 1727.533813 | Best Valid MSE: 1727.939331 (Epoch 278)
# 🎯 New Best Valid MSE!
# Epoch 280/1000 - Train MSE: 1961.907837 | Valid MSE: 1727.121582 | Best Valid MSE: 1727.533813 (Epoch 279)
# 🎯 New Best Valid MSE!
# Epoch 281/1000 - Train MSE: 1961.468384 | Valid MSE: 1726.709961 | Best Valid MSE: 1727.121582 (Epoch 280)
# 🎯 New Best Valid MSE!
# Epoch 282/1000 - Train MSE: 1961.004150 | Valid MSE: 1726.298462 | Best Valid MSE: 1726.709961 (Epoch 281)
# 🎯 New Best Valid MSE!
# Epoch 283/1000 - Train MSE: 1960.581665 | Valid MSE: 1725.879028 | Best Valid MSE: 1726.298462 (Epoch 282)
# 🎯 New Best Valid MSE!
# Epoch 284/1000 - Train MSE: 1960.131104 | Valid MSE: 1725.463379 | Best Valid MSE: 1725.879028 (Epoch 283)
# 🎯 New Best Valid MSE!
# Epoch 285/1000 - Train MSE: 1959.682739 | Valid MSE: 1725.047485 | Best Valid MSE: 1725.463379 (Epoch 284)
# 🎯 New Best Valid MSE!
# Epoch 286/1000 - Train MSE: 1959.222290 | Valid MSE: 1724.626221 | Best Valid MSE: 1725.047485 (Epoch 285)
# 🎯 New Best Valid MSE!
# Epoch 287/1000 - Train MSE: 1958.702515 | Valid MSE: 1724.203003 | Best Valid MSE: 1724.626221 (Epoch 286)
# 🎯 New Best Valid MSE!
# Epoch 288/1000 - Train MSE: 1958.280396 | Valid MSE: 1723.781128 | Best Valid MSE: 1724.203003 (Epoch 287)
# 🎯 New Best Valid MSE!
# Epoch 289/1000 - Train MSE: 1957.839722 | Valid MSE: 1723.356323 | Best Valid MSE: 1723.781128 (Epoch 288)
# 🎯 New Best Valid MSE!
# Epoch 290/1000 - Train MSE: 1957.379883 | Valid MSE: 1722.929321 | Best Valid MSE: 1723.356323 (Epoch 289)
# 🎯 New Best Valid MSE!
# Epoch 291/1000 - Train MSE: 1956.912598 | Valid MSE: 1722.507080 | Best Valid MSE: 1722.929321 (Epoch 290)
# 🎯 New Best Valid MSE!
# Epoch 292/1000 - Train MSE: 1956.437012 | Valid MSE: 1722.076416 | Best Valid MSE: 1722.507080 (Epoch 291)
# 🎯 New Best Valid MSE!
# Epoch 293/1000 - Train MSE: 1955.992920 | Valid MSE: 1721.643433 | Best Valid MSE: 1722.076416 (Epoch 292)
# 🎯 New Best Valid MSE!
# Epoch 294/1000 - Train MSE: 1955.520752 | Valid MSE: 1721.209229 | Best Valid MSE: 1721.643433 (Epoch 293)
# 🎯 New Best Valid MSE!
# Epoch 295/1000 - Train MSE: 1955.050293 | Valid MSE: 1720.780396 | Best Valid MSE: 1721.209229 (Epoch 294)
# 🎯 New Best Valid MSE!
# Epoch 296/1000 - Train MSE: 1954.560059 | Valid MSE: 1720.342651 | Best Valid MSE: 1720.780396 (Epoch 295)
# 🎯 New Best Valid MSE!
# Epoch 297/1000 - Train MSE: 1954.082886 | Valid MSE: 1719.908447 | Best Valid MSE: 1720.342651 (Epoch 296)
# 🎯 New Best Valid MSE!
# Epoch 298/1000 - Train MSE: 1953.599854 | Valid MSE: 1719.465088 | Best Valid MSE: 1719.908447 (Epoch 297)
# 🎯 New Best Valid MSE!
# Epoch 299/1000 - Train MSE: 1953.144287 | Valid MSE: 1719.024170 | Best Valid MSE: 1719.465088 (Epoch 298)
# 🎯 New Best Valid MSE!
# Epoch 300/1000 - Train MSE: 1952.676880 | Valid MSE: 1718.583496 | Best Valid MSE: 1719.024170 (Epoch 299)
# 🎯 New Best Valid MSE!
# Epoch 301/1000 - Train MSE: 1952.184570 | Valid MSE: 1718.139771 | Best Valid MSE: 1718.583496 (Epoch 300)
# 🎯 New Best Valid MSE!
# Epoch 302/1000 - Train MSE: 1951.704102 | Valid MSE: 1717.692627 | Best Valid MSE: 1718.139771 (Epoch 301)
# 🎯 New Best Valid MSE!
# Epoch 303/1000 - Train MSE: 1951.203491 | Valid MSE: 1717.250977 | Best Valid MSE: 1717.692627 (Epoch 302)
# 🎯 New Best Valid MSE!
# Epoch 304/1000 - Train MSE: 1950.760864 | Valid MSE: 1716.796021 | Best Valid MSE: 1717.250977 (Epoch 303)
# 🎯 New Best Valid MSE!
# Epoch 305/1000 - Train MSE: 1950.252563 | Valid MSE: 1716.347656 | Best Valid MSE: 1716.796021 (Epoch 304)
# 🎯 New Best Valid MSE!
# Epoch 306/1000 - Train MSE: 1949.743774 | Valid MSE: 1715.894531 | Best Valid MSE: 1716.347656 (Epoch 305)
# 🎯 New Best Valid MSE!
# Epoch 307/1000 - Train MSE: 1949.231201 | Valid MSE: 1715.439331 | Best Valid MSE: 1715.894531 (Epoch 306)
# 🎯 New Best Valid MSE!
# Epoch 308/1000 - Train MSE: 1948.746948 | Valid MSE: 1714.982178 | Best Valid MSE: 1715.439331 (Epoch 307)
# 🎯 New Best Valid MSE!
# Epoch 309/1000 - Train MSE: 1948.283569 | Valid MSE: 1714.525635 | Best Valid MSE: 1714.982178 (Epoch 308)
# 🎯 New Best Valid MSE!
# Epoch 310/1000 - Train MSE: 1947.785156 | Valid MSE: 1714.067749 | Best Valid MSE: 1714.525635 (Epoch 309)
# 🎯 New Best Valid MSE!
# Epoch 311/1000 - Train MSE: 1947.283325 | Valid MSE: 1713.606323 | Best Valid MSE: 1714.067749 (Epoch 310)
# 🎯 New Best Valid MSE!
# Epoch 312/1000 - Train MSE: 1946.802002 | Valid MSE: 1713.146606 | Best Valid MSE: 1713.606323 (Epoch 311)
# 🎯 New Best Valid MSE!
# Epoch 313/1000 - Train MSE: 1946.284058 | Valid MSE: 1712.684326 | Best Valid MSE: 1713.146606 (Epoch 312)
# 🎯 New Best Valid MSE!
# Epoch 314/1000 - Train MSE: 1945.762451 | Valid MSE: 1712.213379 | Best Valid MSE: 1712.684326 (Epoch 313)
# 🎯 New Best Valid MSE!
# Epoch 315/1000 - Train MSE: 1945.249023 | Valid MSE: 1711.749634 | Best Valid MSE: 1712.213379 (Epoch 314)
# 🎯 New Best Valid MSE!
# Epoch 316/1000 - Train MSE: 1944.738281 | Valid MSE: 1711.280273 | Best Valid MSE: 1711.749634 (Epoch 315)
# 🎯 New Best Valid MSE!
# Epoch 317/1000 - Train MSE: 1944.213501 | Valid MSE: 1710.807861 | Best Valid MSE: 1711.280273 (Epoch 316)
# 🎯 New Best Valid MSE!
# Epoch 318/1000 - Train MSE: 1943.687134 | Valid MSE: 1710.335571 | Best Valid MSE: 1710.807861 (Epoch 317)
# 🎯 New Best Valid MSE!
# Epoch 319/1000 - Train MSE: 1943.214355 | Valid MSE: 1709.859741 | Best Valid MSE: 1710.335571 (Epoch 318)
# 🎯 New Best Valid MSE!
# Epoch 320/1000 - Train MSE: 1942.702759 | Valid MSE: 1709.388306 | Best Valid MSE: 1709.859741 (Epoch 319)
# 🎯 New Best Valid MSE!
# Epoch 321/1000 - Train MSE: 1942.203491 | Valid MSE: 1708.910889 | Best Valid MSE: 1709.388306 (Epoch 320)
# 🎯 New Best Valid MSE!
# Epoch 322/1000 - Train MSE: 1941.637451 | Valid MSE: 1708.432129 | Best Valid MSE: 1708.910889 (Epoch 321)
# 🎯 New Best Valid MSE!
# Epoch 323/1000 - Train MSE: 1941.101074 | Valid MSE: 1707.952881 | Best Valid MSE: 1708.432129 (Epoch 322)
# 🎯 New Best Valid MSE!
# Epoch 324/1000 - Train MSE: 1940.589478 | Valid MSE: 1707.473145 | Best Valid MSE: 1707.952881 (Epoch 323)
# 🎯 New Best Valid MSE!
# Epoch 325/1000 - Train MSE: 1940.093750 | Valid MSE: 1706.986694 | Best Valid MSE: 1707.473145 (Epoch 324)
# 🎯 New Best Valid MSE!
# Epoch 326/1000 - Train MSE: 1939.570312 | Valid MSE: 1706.502075 | Best Valid MSE: 1706.986694 (Epoch 325)
# 🎯 New Best Valid MSE!
# Epoch 327/1000 - Train MSE: 1939.030518 | Valid MSE: 1706.016357 | Best Valid MSE: 1706.502075 (Epoch 326)
# 🎯 New Best Valid MSE!
# Epoch 328/1000 - Train MSE: 1938.510254 | Valid MSE: 1705.528198 | Best Valid MSE: 1706.016357 (Epoch 327)
# 🎯 New Best Valid MSE!
# Epoch 329/1000 - Train MSE: 1937.992432 | Valid MSE: 1705.039673 | Best Valid MSE: 1705.528198 (Epoch 328)
# 🎯 New Best Valid MSE!
# Epoch 330/1000 - Train MSE: 1937.451294 | Valid MSE: 1704.547852 | Best Valid MSE: 1705.039673 (Epoch 329)
# 🎯 New Best Valid MSE!
# Epoch 331/1000 - Train MSE: 1936.913330 | Valid MSE: 1704.058228 | Best Valid MSE: 1704.547852 (Epoch 330)
# 🎯 New Best Valid MSE!
# Epoch 332/1000 - Train MSE: 1936.402344 | Valid MSE: 1703.562134 | Best Valid MSE: 1704.058228 (Epoch 331)
# 🎯 New Best Valid MSE!
# Epoch 333/1000 - Train MSE: 1935.824707 | Valid MSE: 1703.066040 | Best Valid MSE: 1703.562134 (Epoch 332)
# 🎯 New Best Valid MSE!
# Epoch 334/1000 - Train MSE: 1935.301270 | Valid MSE: 1702.566406 | Best Valid MSE: 1703.066040 (Epoch 333)
# 🎯 New Best Valid MSE!
# Epoch 335/1000 - Train MSE: 1934.772827 | Valid MSE: 1702.072388 | Best Valid MSE: 1702.566406 (Epoch 334)
# 🎯 New Best Valid MSE!
# Epoch 336/1000 - Train MSE: 1934.229004 | Valid MSE: 1701.571411 | Best Valid MSE: 1702.072388 (Epoch 335)
# 🎯 New Best Valid MSE!
# Epoch 337/1000 - Train MSE: 1933.706909 | Valid MSE: 1701.071289 | Best Valid MSE: 1701.571411 (Epoch 336)
# 🎯 New Best Valid MSE!
# Epoch 338/1000 - Train MSE: 1933.122925 | Valid MSE: 1700.564941 | Best Valid MSE: 1701.071289 (Epoch 337)
# 🎯 New Best Valid MSE!
# Epoch 339/1000 - Train MSE: 1932.577148 | Valid MSE: 1700.055664 | Best Valid MSE: 1700.564941 (Epoch 338)
# 🎯 New Best Valid MSE!
# Epoch 340/1000 - Train MSE: 1932.009155 | Valid MSE: 1699.552368 | Best Valid MSE: 1700.055664 (Epoch 339)
# 🎯 New Best Valid MSE!
# Epoch 341/1000 - Train MSE: 1931.479980 | Valid MSE: 1699.045288 | Best Valid MSE: 1699.552368 (Epoch 340)
# 🎯 New Best Valid MSE!
# Epoch 342/1000 - Train MSE: 1930.928955 | Valid MSE: 1698.528076 | Best Valid MSE: 1699.045288 (Epoch 341)
# 🎯 New Best Valid MSE!
# Epoch 343/1000 - Train MSE: 1930.374634 | Valid MSE: 1698.012573 | Best Valid MSE: 1698.528076 (Epoch 342)
# 🎯 New Best Valid MSE!
# Epoch 344/1000 - Train MSE: 1929.830933 | Valid MSE: 1697.502808 | Best Valid MSE: 1698.012573 (Epoch 343)
# 🎯 New Best Valid MSE!
# Epoch 345/1000 - Train MSE: 1929.240356 | Valid MSE: 1696.983154 | Best Valid MSE: 1697.502808 (Epoch 344)
# 🎯 New Best Valid MSE!
# Epoch 346/1000 - Train MSE: 1928.698730 | Valid MSE: 1696.469604 | Best Valid MSE: 1696.983154 (Epoch 345)
# 🎯 New Best Valid MSE!
# Epoch 347/1000 - Train MSE: 1928.131104 | Valid MSE: 1695.944092 | Best Valid MSE: 1696.469604 (Epoch 346)
# 🎯 New Best Valid MSE!
# Epoch 348/1000 - Train MSE: 1927.583496 | Valid MSE: 1695.423218 | Best Valid MSE: 1695.944092 (Epoch 347)
# 🎯 New Best Valid MSE!
# Epoch 349/1000 - Train MSE: 1926.987305 | Valid MSE: 1694.898315 | Best Valid MSE: 1695.423218 (Epoch 348)
# 🎯 New Best Valid MSE!
# Epoch 350/1000 - Train MSE: 1926.444946 | Valid MSE: 1694.373047 | Best Valid MSE: 1694.898315 (Epoch 349)
# 🎯 New Best Valid MSE!
# Epoch 351/1000 - Train MSE: 1925.852539 | Valid MSE: 1693.849121 | Best Valid MSE: 1694.373047 (Epoch 350)
# 🎯 New Best Valid MSE!
# Epoch 352/1000 - Train MSE: 1925.293091 | Valid MSE: 1693.315918 | Best Valid MSE: 1693.849121 (Epoch 351)
# 🎯 New Best Valid MSE!
# Epoch 353/1000 - Train MSE: 1924.680420 | Valid MSE: 1692.788818 | Best Valid MSE: 1693.315918 (Epoch 352)
# 🎯 New Best Valid MSE!
# Epoch 354/1000 - Train MSE: 1924.117432 | Valid MSE: 1692.254639 | Best Valid MSE: 1692.788818 (Epoch 353)
# 🎯 New Best Valid MSE!
# Epoch 355/1000 - Train MSE: 1923.536377 | Valid MSE: 1691.717651 | Best Valid MSE: 1692.254639 (Epoch 354)
# 🎯 New Best Valid MSE!
# Epoch 356/1000 - Train MSE: 1922.933594 | Valid MSE: 1691.167725 | Best Valid MSE: 1691.717651 (Epoch 355)
# 🎯 New Best Valid MSE!
# Epoch 357/1000 - Train MSE: 1922.347290 | Valid MSE: 1690.591919 | Best Valid MSE: 1691.167725 (Epoch 356)
# 🎯 New Best Valid MSE!
# Epoch 358/1000 - Train MSE: 1921.734131 | Valid MSE: 1690.020264 | Best Valid MSE: 1690.591919 (Epoch 357)
# 🎯 New Best Valid MSE!
# Epoch 359/1000 - Train MSE: 1921.081055 | Valid MSE: 1689.450317 | Best Valid MSE: 1690.020264 (Epoch 358)
# 🎯 New Best Valid MSE!
# Epoch 360/1000 - Train MSE: 1920.468384 | Valid MSE: 1688.882690 | Best Valid MSE: 1689.450317 (Epoch 359)
# 🎯 New Best Valid MSE!
# Epoch 361/1000 - Train MSE: 1919.865234 | Valid MSE: 1688.324585 | Best Valid MSE: 1688.882690 (Epoch 360)
# 🎯 New Best Valid MSE!
# Epoch 362/1000 - Train MSE: 1919.263062 | Valid MSE: 1687.755981 | Best Valid MSE: 1688.324585 (Epoch 361)
# 🎯 New Best Valid MSE!
# Epoch 363/1000 - Train MSE: 1918.604248 | Valid MSE: 1687.186890 | Best Valid MSE: 1687.755981 (Epoch 362)
# 🎯 New Best Valid MSE!
# Epoch 364/1000 - Train MSE: 1918.051880 | Valid MSE: 1686.617310 | Best Valid MSE: 1687.186890 (Epoch 363)
# 🎯 New Best Valid MSE!
# Epoch 365/1000 - Train MSE: 1917.413330 | Valid MSE: 1686.045898 | Best Valid MSE: 1686.617310 (Epoch 364)
# 🎯 New Best Valid MSE!
# Epoch 366/1000 - Train MSE: 1916.788330 | Valid MSE: 1685.477173 | Best Valid MSE: 1686.045898 (Epoch 365)
# 🎯 New Best Valid MSE!
# Epoch 367/1000 - Train MSE: 1916.172729 | Valid MSE: 1684.914429 | Best Valid MSE: 1685.477173 (Epoch 366)
# 🎯 New Best Valid MSE!
# Epoch 368/1000 - Train MSE: 1915.570801 | Valid MSE: 1684.335205 | Best Valid MSE: 1684.914429 (Epoch 367)
# 🎯 New Best Valid MSE!
# Epoch 369/1000 - Train MSE: 1914.919189 | Valid MSE: 1683.759888 | Best Valid MSE: 1684.335205 (Epoch 368)
# 🎯 New Best Valid MSE!
# Epoch 370/1000 - Train MSE: 1914.306763 | Valid MSE: 1683.181152 | Best Valid MSE: 1683.759888 (Epoch 369)
# 🎯 New Best Valid MSE!
# Epoch 371/1000 - Train MSE: 1913.644531 | Valid MSE: 1682.605957 | Best Valid MSE: 1683.181152 (Epoch 370)
# 🎯 New Best Valid MSE!
# Epoch 372/1000 - Train MSE: 1913.064575 | Valid MSE: 1682.028198 | Best Valid MSE: 1682.605957 (Epoch 371)
# 🎯 New Best Valid MSE!
# Epoch 373/1000 - Train MSE: 1912.424927 | Valid MSE: 1681.451050 | Best Valid MSE: 1682.028198 (Epoch 372)
# 🎯 New Best Valid MSE!
# Epoch 374/1000 - Train MSE: 1911.734131 | Valid MSE: 1680.867065 | Best Valid MSE: 1681.451050 (Epoch 373)
# ...
# 🎯 New Best Valid MSE!
# Epoch 877/1000 - Train MSE: 1263.523438 | Valid MSE: 1086.241821 | Best Valid MSE: 1088.003418 (Epoch 876)
# 🎯 New Best Valid MSE!
# Epoch 878/1000 - Train MSE: 1261.687134 | Valid MSE: 1084.474243 | Best Valid MSE: 1086.241821 (Epoch 877)
# 🎯 New Best Valid MSE!
# Epoch 879/1000 - Train MSE: 1259.707520 | Valid MSE: 1082.737427 | Best Valid MSE: 1084.474243 (Epoch 878)
# 🎯 New Best Valid MSE!
# Epoch 880/1000 - Train MSE: 1257.606079 | Valid MSE: 1081.001953 | Best Valid MSE: 1082.737427 (Epoch 879)
# 🎯 New Best Valid MSE!
# Epoch 881/1000 - Train MSE: 1255.777222 | Valid MSE: 1079.249634 | Best Valid MSE: 1081.001953 (Epoch 880)
# 🎯 New Best Valid MSE!
# Epoch 882/1000 - Train MSE: 1253.894653 | Valid MSE: 1077.501587 | Best Valid MSE: 1079.249634 (Epoch 881)
# 🎯 New Best Valid MSE!
# Epoch 883/1000 - Train MSE: 1251.924438 | Valid MSE: 1075.740479 | Best Valid MSE: 1077.501587 (Epoch 882)
# 🎯 New Best Valid MSE!
# Epoch 884/1000 - Train MSE: 1249.999756 | Valid MSE: 1073.979126 | Best Valid MSE: 1075.740479 (Epoch 883)
# 🎯 New Best Valid MSE!
# Epoch 885/1000 - Train MSE: 1247.994507 | Valid MSE: 1072.243652 | Best Valid MSE: 1073.979126 (Epoch 884)
# 🎯 New Best Valid MSE!
# Epoch 886/1000 - Train MSE: 1246.171265 | Valid MSE: 1070.497192 | Best Valid MSE: 1072.243652 (Epoch 885)
# 🎯 New Best Valid MSE!
# Epoch 887/1000 - Train MSE: 1244.305176 | Valid MSE: 1068.710083 | Best Valid MSE: 1070.497192 (Epoch 886)
# 🎯 New Best Valid MSE!
# Epoch 888/1000 - Train MSE: 1242.287231 | Valid MSE: 1066.963257 | Best Valid MSE: 1068.710083 (Epoch 887)
# 🎯 New Best Valid MSE!
# Epoch 889/1000 - Train MSE: 1240.314697 | Valid MSE: 1065.198730 | Best Valid MSE: 1066.963257 (Epoch 888)
# 🎯 New Best Valid MSE!
# Epoch 890/1000 - Train MSE: 1238.213623 | Valid MSE: 1063.444458 | Best Valid MSE: 1065.198730 (Epoch 889)
# 🎯 New Best Valid MSE!
# Epoch 891/1000 - Train MSE: 1236.424438 | Valid MSE: 1061.693359 | Best Valid MSE: 1063.444458 (Epoch 890)
# 🎯 New Best Valid MSE!
# Epoch 892/1000 - Train MSE: 1234.424805 | Valid MSE: 1059.917725 | Best Valid MSE: 1061.693359 (Epoch 891)
# 🎯 New Best Valid MSE!
# Epoch 893/1000 - Train MSE: 1232.357788 | Valid MSE: 1058.170898 | Best Valid MSE: 1059.917725 (Epoch 892)
# 🎯 New Best Valid MSE!
# Epoch 894/1000 - Train MSE: 1230.507080 | Valid MSE: 1056.397705 | Best Valid MSE: 1058.170898 (Epoch 893)
# 🎯 New Best Valid MSE!
# Epoch 895/1000 - Train MSE: 1228.659546 | Valid MSE: 1054.641357 | Best Valid MSE: 1056.397705 (Epoch 894)
# 🎯 New Best Valid MSE!
# Epoch 896/1000 - Train MSE: 1226.664795 | Valid MSE: 1052.861450 | Best Valid MSE: 1054.641357 (Epoch 895)
# 🎯 New Best Valid MSE!
# Epoch 897/1000 - Train MSE: 1224.745972 | Valid MSE: 1051.107544 | Best Valid MSE: 1052.861450 (Epoch 896)
# 🎯 New Best Valid MSE!
# Epoch 898/1000 - Train MSE: 1222.704346 | Valid MSE: 1049.310669 | Best Valid MSE: 1051.107544 (Epoch 897)
# 🎯 New Best Valid MSE!
# Epoch 899/1000 - Train MSE: 1220.856812 | Valid MSE: 1047.568115 | Best Valid MSE: 1049.310669 (Epoch 898)
# 🎯 New Best Valid MSE!
# Epoch 900/1000 - Train MSE: 1218.954712 | Valid MSE: 1045.800903 | Best Valid MSE: 1047.568115 (Epoch 899)
# 🎯 New Best Valid MSE!
# Epoch 901/1000 - Train MSE: 1216.877075 | Valid MSE: 1044.035645 | Best Valid MSE: 1045.800903 (Epoch 900)
# 🎯 New Best Valid MSE!
# Epoch 902/1000 - Train MSE: 1214.790283 | Valid MSE: 1042.291016 | Best Valid MSE: 1044.035645 (Epoch 901)
# 🎯 New Best Valid MSE!
# Epoch 903/1000 - Train MSE: 1213.036133 | Valid MSE: 1040.469360 | Best Valid MSE: 1042.291016 (Epoch 902)
# 🎯 New Best Valid MSE!
# Epoch 904/1000 - Train MSE: 1211.024170 | Valid MSE: 1038.733887 | Best Valid MSE: 1040.469360 (Epoch 903)
# 🎯 New Best Valid MSE!
# Epoch 905/1000 - Train MSE: 1209.093506 | Valid MSE: 1036.955688 | Best Valid MSE: 1038.733887 (Epoch 904)
# 🎯 New Best Valid MSE!
# Epoch 906/1000 - Train MSE: 1207.104004 | Valid MSE: 1035.194336 | Best Valid MSE: 1036.955688 (Epoch 905)
# 🎯 New Best Valid MSE!
# Epoch 907/1000 - Train MSE: 1205.237915 | Valid MSE: 1033.403320 | Best Valid MSE: 1035.194336 (Epoch 906)
# 🎯 New Best Valid MSE!
# Epoch 908/1000 - Train MSE: 1203.251953 | Valid MSE: 1031.645874 | Best Valid MSE: 1033.403320 (Epoch 907)
# 🎯 New Best Valid MSE!
# Epoch 909/1000 - Train MSE: 1201.157471 | Valid MSE: 1029.855347 | Best Valid MSE: 1031.645874 (Epoch 908)
# 🎯 New Best Valid MSE!
# Epoch 910/1000 - Train MSE: 1199.422119 | Valid MSE: 1028.083008 | Best Valid MSE: 1029.855347 (Epoch 909)
# 🎯 New Best Valid MSE!
# Epoch 911/1000 - Train MSE: 1197.363403 | Valid MSE: 1026.314087 | Best Valid MSE: 1028.083008 (Epoch 910)
# 🎯 New Best Valid MSE!
# Epoch 912/1000 - Train MSE: 1195.339844 | Valid MSE: 1024.552490 | Best Valid MSE: 1026.314087 (Epoch 911)
# 🎯 New Best Valid MSE!
# Epoch 913/1000 - Train MSE: 1193.283325 | Valid MSE: 1022.774231 | Best Valid MSE: 1024.552490 (Epoch 912)
# 🎯 New Best Valid MSE!
# Epoch 914/1000 - Train MSE: 1191.286133 | Valid MSE: 1020.977356 | Best Valid MSE: 1022.774231 (Epoch 913)
# 🎯 New Best Valid MSE!
# Epoch 915/1000 - Train MSE: 1189.382080 | Valid MSE: 1019.228271 | Best Valid MSE: 1020.977356 (Epoch 914)
# 🎯 New Best Valid MSE!
# Epoch 916/1000 - Train MSE: 1187.457153 | Valid MSE: 1017.417664 | Best Valid MSE: 1019.228271 (Epoch 915)
# 🎯 New Best Valid MSE!
# Epoch 917/1000 - Train MSE: 1185.572510 | Valid MSE: 1015.652405 | Best Valid MSE: 1017.417664 (Epoch 916)
# 🎯 New Best Valid MSE!
# Epoch 918/1000 - Train MSE: 1183.515869 | Valid MSE: 1013.896423 | Best Valid MSE: 1015.652405 (Epoch 917)
# 🎯 New Best Valid MSE!
# Epoch 919/1000 - Train MSE: 1181.562622 | Valid MSE: 1012.113708 | Best Valid MSE: 1013.896423 (Epoch 918)
# 🎯 New Best Valid MSE!
# Epoch 920/1000 - Train MSE: 1179.484619 | Valid MSE: 1010.337219 | Best Valid MSE: 1012.113708 (Epoch 919)
# 🎯 New Best Valid MSE!
# Epoch 921/1000 - Train MSE: 1177.605713 | Valid MSE: 1008.550415 | Best Valid MSE: 1010.337219 (Epoch 920)
# 🎯 New Best Valid MSE!
# Epoch 922/1000 - Train MSE: 1175.818115 | Valid MSE: 1006.757874 | Best Valid MSE: 1008.550415 (Epoch 921)
# 🎯 New Best Valid MSE!
# Epoch 923/1000 - Train MSE: 1173.621704 | Valid MSE: 1005.000366 | Best Valid MSE: 1006.757874 (Epoch 922)
# 🎯 New Best Valid MSE!
# Epoch 924/1000 - Train MSE: 1171.794678 | Valid MSE: 1003.212891 | Best Valid MSE: 1005.000366 (Epoch 923)
# 🎯 New Best Valid MSE!
# Epoch 925/1000 - Train MSE: 1169.690674 | Valid MSE: 1001.443848 | Best Valid MSE: 1003.212891 (Epoch 924)
# 🎯 New Best Valid MSE!
# Epoch 926/1000 - Train MSE: 1167.740356 | Valid MSE: 999.660461 | Best Valid MSE: 1001.443848 (Epoch 925)
# 🎯 New Best Valid MSE!
# Epoch 927/1000 - Train MSE: 1165.699463 | Valid MSE: 997.889587 | Best Valid MSE: 999.660461 (Epoch 926)
# 🎯 New Best Valid MSE!
# Epoch 928/1000 - Train MSE: 1163.816772 | Valid MSE: 996.090759 | Best Valid MSE: 997.889587 (Epoch 927)
# 🎯 New Best Valid MSE!
# Epoch 929/1000 - Train MSE: 1161.795166 | Valid MSE: 994.339478 | Best Valid MSE: 996.090759 (Epoch 928)
# 🎯 New Best Valid MSE!
# Epoch 930/1000 - Train MSE: 1159.901489 | Valid MSE: 992.556335 | Best Valid MSE: 994.339478 (Epoch 929)
# 🎯 New Best Valid MSE!
# Epoch 931/1000 - Train MSE: 1157.972412 | Valid MSE: 990.777100 | Best Valid MSE: 992.556335 (Epoch 930)
# 🎯 New Best Valid MSE!
# Epoch 932/1000 - Train MSE: 1155.859741 | Valid MSE: 989.012451 | Best Valid MSE: 990.777100 (Epoch 931)
# 🎯 New Best Valid MSE!
# Epoch 933/1000 - Train MSE: 1154.107910 | Valid MSE: 987.247009 | Best Valid MSE: 989.012451 (Epoch 932)
# 🎯 New Best Valid MSE!
# Epoch 934/1000 - Train MSE: 1152.002563 | Valid MSE: 985.462341 | Best Valid MSE: 987.247009 (Epoch 933)
# 🎯 New Best Valid MSE!
# Epoch 935/1000 - Train MSE: 1149.923706 | Valid MSE: 983.669067 | Best Valid MSE: 985.462341 (Epoch 934)
# 🎯 New Best Valid MSE!
# Epoch 936/1000 - Train MSE: 1147.954712 | Valid MSE: 981.906860 | Best Valid MSE: 983.669067 (Epoch 935)
# 🎯 New Best Valid MSE!
# Epoch 937/1000 - Train MSE: 1146.039673 | Valid MSE: 980.106323 | Best Valid MSE: 981.906860 (Epoch 936)
# 🎯 New Best Valid MSE!
# Epoch 938/1000 - Train MSE: 1144.045898 | Valid MSE: 978.333069 | Best Valid MSE: 980.106323 (Epoch 937)
# 🎯 New Best Valid MSE!
# Epoch 939/1000 - Train MSE: 1142.082153 | Valid MSE: 976.546204 | Best Valid MSE: 978.333069 (Epoch 938)
# 🎯 New Best Valid MSE!
# Epoch 940/1000 - Train MSE: 1140.172363 | Valid MSE: 974.776428 | Best Valid MSE: 976.546204 (Epoch 939)
# 🎯 New Best Valid MSE!
# Epoch 941/1000 - Train MSE: 1138.168457 | Valid MSE: 973.004089 | Best Valid MSE: 974.776428 (Epoch 940)
# 🎯 New Best Valid MSE!
# Epoch 942/1000 - Train MSE: 1136.203979 | Valid MSE: 971.224548 | Best Valid MSE: 973.004089 (Epoch 941)
# 🎯 New Best Valid MSE!
# Epoch 943/1000 - Train MSE: 1134.157471 | Valid MSE: 969.433472 | Best Valid MSE: 971.224548 (Epoch 942)
# 🎯 New Best Valid MSE!
# Epoch 944/1000 - Train MSE: 1132.238525 | Valid MSE: 967.658508 | Best Valid MSE: 969.433472 (Epoch 943)
# 🎯 New Best Valid MSE!
# Epoch 945/1000 - Train MSE: 1130.194946 | Valid MSE: 965.896729 | Best Valid MSE: 967.658508 (Epoch 944)
# 🎯 New Best Valid MSE!
# Epoch 946/1000 - Train MSE: 1128.173828 | Valid MSE: 964.118408 | Best Valid MSE: 965.896729 (Epoch 945)
# 🎯 New Best Valid MSE!
# Epoch 947/1000 - Train MSE: 1126.146484 | Valid MSE: 962.322937 | Best Valid MSE: 964.118408 (Epoch 946)
# 🎯 New Best Valid MSE!
# Epoch 948/1000 - Train MSE: 1124.237183 | Valid MSE: 960.557556 | Best Valid MSE: 962.322937 (Epoch 947)
# 🎯 New Best Valid MSE!
# Epoch 949/1000 - Train MSE: 1122.318604 | Valid MSE: 958.780823 | Best Valid MSE: 960.557556 (Epoch 948)
# 🎯 New Best Valid MSE!
# Epoch 950/1000 - Train MSE: 1120.218018 | Valid MSE: 957.024780 | Best Valid MSE: 958.780823 (Epoch 949)
# 🎯 New Best Valid MSE!
# Epoch 951/1000 - Train MSE: 1118.240723 | Valid MSE: 955.206665 | Best Valid MSE: 957.024780 (Epoch 950)
# 🎯 New Best Valid MSE!
# Epoch 952/1000 - Train MSE: 1116.355469 | Valid MSE: 953.437744 | Best Valid MSE: 955.206665 (Epoch 951)
# 🎯 New Best Valid MSE!
# Epoch 953/1000 - Train MSE: 1114.407593 | Valid MSE: 951.670593 | Best Valid MSE: 953.437744 (Epoch 952)
# 🎯 New Best Valid MSE!
# Epoch 954/1000 - Train MSE: 1112.438232 | Valid MSE: 949.905518 | Best Valid MSE: 951.670593 (Epoch 953)
# 🎯 New Best Valid MSE!
# Epoch 955/1000 - Train MSE: 1110.324097 | Valid MSE: 948.111633 | Best Valid MSE: 949.905518 (Epoch 954)
# 🎯 New Best Valid MSE!
# Epoch 956/1000 - Train MSE: 1108.450195 | Valid MSE: 946.330627 | Best Valid MSE: 948.111633 (Epoch 955)
# 🎯 New Best Valid MSE!
# Epoch 957/1000 - Train MSE: 1106.492676 | Valid MSE: 944.537781 | Best Valid MSE: 946.330627 (Epoch 956)
# 🎯 New Best Valid MSE!
# Epoch 958/1000 - Train MSE: 1104.415161 | Valid MSE: 942.782654 | Best Valid MSE: 944.537781 (Epoch 957)
# 🎯 New Best Valid MSE!
# Epoch 959/1000 - Train MSE: 1102.377075 | Valid MSE: 941.005371 | Best Valid MSE: 942.782654 (Epoch 958)
# 🎯 New Best Valid MSE!
# Epoch 960/1000 - Train MSE: 1100.430542 | Valid MSE: 939.215759 | Best Valid MSE: 941.005371 (Epoch 959)
# 🎯 New Best Valid MSE!
# Epoch 961/1000 - Train MSE: 1098.512085 | Valid MSE: 937.463928 | Best Valid MSE: 939.215759 (Epoch 960)
# 🎯 New Best Valid MSE!
# Epoch 962/1000 - Train MSE: 1096.447632 | Valid MSE: 935.681152 | Best Valid MSE: 937.463928 (Epoch 961)
# 🎯 New Best Valid MSE!
# Epoch 963/1000 - Train MSE: 1094.433350 | Valid MSE: 933.896423 | Best Valid MSE: 935.681152 (Epoch 962)
# 🎯 New Best Valid MSE!
# Epoch 964/1000 - Train MSE: 1092.368408 | Valid MSE: 932.110962 | Best Valid MSE: 933.896423 (Epoch 963)
# 🎯 New Best Valid MSE!
# Epoch 965/1000 - Train MSE: 1090.401001 | Valid MSE: 930.322632 | Best Valid MSE: 932.110962 (Epoch 964)
# 🎯 New Best Valid MSE!
# Epoch 966/1000 - Train MSE: 1088.501221 | Valid MSE: 928.556335 | Best Valid MSE: 930.322632 (Epoch 965)
# 🎯 New Best Valid MSE!
# Epoch 967/1000 - Train MSE: 1086.740967 | Valid MSE: 926.785278 | Best Valid MSE: 928.556335 (Epoch 966)
# 🎯 New Best Valid MSE!
# Epoch 968/1000 - Train MSE: 1084.573242 | Valid MSE: 925.004761 | Best Valid MSE: 926.785278 (Epoch 967)
# 🎯 New Best Valid MSE!
# Epoch 969/1000 - Train MSE: 1082.551636 | Valid MSE: 923.239807 | Best Valid MSE: 925.004761 (Epoch 968)
# 🎯 New Best Valid MSE!
# Epoch 970/1000 - Train MSE: 1080.721680 | Valid MSE: 921.467041 | Best Valid MSE: 923.239807 (Epoch 969)
# 🎯 New Best Valid MSE!
# Epoch 971/1000 - Train MSE: 1078.631348 | Valid MSE: 919.691101 | Best Valid MSE: 921.467041 (Epoch 970)
# 🎯 New Best Valid MSE!
# Epoch 972/1000 - Train MSE: 1076.535278 | Valid MSE: 917.919983 | Best Valid MSE: 919.691101 (Epoch 971)
# 🎯 New Best Valid MSE!
# Epoch 973/1000 - Train MSE: 1074.597412 | Valid MSE: 916.132690 | Best Valid MSE: 917.919983 (Epoch 972)
# 🎯 New Best Valid MSE!
# Epoch 974/1000 - Train MSE: 1072.769897 | Valid MSE: 914.397949 | Best Valid MSE: 916.132690 (Epoch 973)
# 🎯 New Best Valid MSE!
# Epoch 975/1000 - Train MSE: 1070.758545 | Valid MSE: 912.608826 | Best Valid MSE: 914.397949 (Epoch 974)
# 🎯 New Best Valid MSE!
# Epoch 976/1000 - Train MSE: 1068.605835 | Valid MSE: 910.838745 | Best Valid MSE: 912.608826 (Epoch 975)
# 🎯 New Best Valid MSE!
# Epoch 977/1000 - Train MSE: 1066.569458 | Valid MSE: 909.051575 | Best Valid MSE: 910.838745 (Epoch 976)
# 🎯 New Best Valid MSE!
# Epoch 978/1000 - Train MSE: 1064.892334 | Valid MSE: 907.302551 | Best Valid MSE: 909.051575 (Epoch 977)
# 🎯 New Best Valid MSE!
# Epoch 979/1000 - Train MSE: 1062.767456 | Valid MSE: 905.525269 | Best Valid MSE: 907.302551 (Epoch 978)
# 🎯 New Best Valid MSE!
# Epoch 980/1000 - Train MSE: 1060.992554 | Valid MSE: 903.782410 | Best Valid MSE: 905.525269 (Epoch 979)
# 🎯 New Best Valid MSE!
# Epoch 981/1000 - Train MSE: 1058.892578 | Valid MSE: 902.013550 | Best Valid MSE: 903.782410 (Epoch 980)
# 🎯 New Best Valid MSE!
# Epoch 982/1000 - Train MSE: 1056.941284 | Valid MSE: 900.232178 | Best Valid MSE: 902.013550 (Epoch 981)
# 🎯 New Best Valid MSE!
# Epoch 983/1000 - Train MSE: 1054.933594 | Valid MSE: 898.481262 | Best Valid MSE: 900.232178 (Epoch 982)
# 🎯 New Best Valid MSE!
# Epoch 984/1000 - Train MSE: 1052.840454 | Valid MSE: 896.697083 | Best Valid MSE: 898.481262 (Epoch 983)
# 🎯 New Best Valid MSE!
# Epoch 985/1000 - Train MSE: 1050.841797 | Valid MSE: 894.934143 | Best Valid MSE: 896.697083 (Epoch 984)
# 🎯 New Best Valid MSE!
# Epoch 986/1000 - Train MSE: 1048.850708 | Valid MSE: 893.190796 | Best Valid MSE: 894.934143 (Epoch 985)
# 🎯 New Best Valid MSE!
# Epoch 987/1000 - Train MSE: 1047.089966 | Valid MSE: 891.395691 | Best Valid MSE: 893.190796 (Epoch 986)
# 🎯 New Best Valid MSE!
# Epoch 988/1000 - Train MSE: 1045.118774 | Valid MSE: 889.648315 | Best Valid MSE: 891.395691 (Epoch 987)
# 🎯 New Best Valid MSE!
# Epoch 989/1000 - Train MSE: 1043.136353 | Valid MSE: 887.876038 | Best Valid MSE: 889.648315 (Epoch 988)
# 🎯 New Best Valid MSE!
# Epoch 990/1000 - Train MSE: 1040.949707 | Valid MSE: 886.111328 | Best Valid MSE: 887.876038 (Epoch 989)
# 🎯 New Best Valid MSE!
# Epoch 991/1000 - Train MSE: 1039.057983 | Valid MSE: 884.362488 | Best Valid MSE: 886.111328 (Epoch 990)
# 🎯 New Best Valid MSE!
# Epoch 992/1000 - Train MSE: 1037.016357 | Valid MSE: 882.604187 | Best Valid MSE: 884.362488 (Epoch 991)
# 🎯 New Best Valid MSE!
# Epoch 993/1000 - Train MSE: 1034.960327 | Valid MSE: 880.843811 | Best Valid MSE: 882.604187 (Epoch 992)
# 🎯 New Best Valid MSE!
# Epoch 994/1000 - Train MSE: 1033.146606 | Valid MSE: 879.091858 | Best Valid MSE: 880.843811 (Epoch 993)
# 🎯 New Best Valid MSE!
# Epoch 995/1000 - Train MSE: 1031.065918 | Valid MSE: 877.334167 | Best Valid MSE: 879.091858 (Epoch 994)
# 🎯 New Best Valid MSE!
# Epoch 996/1000 - Train MSE: 1029.059326 | Valid MSE: 875.571167 | Best Valid MSE: 877.334167 (Epoch 995)
# 🎯 New Best Valid MSE!
# Epoch 997/1000 - Train MSE: 1027.167114 | Valid MSE: 873.819519 | Best Valid MSE: 875.571167 (Epoch 996)
# 🎯 New Best Valid MSE!
# Epoch 998/1000 - Train MSE: 1025.222290 | Valid MSE: 872.073608 | Best Valid MSE: 873.819519 (Epoch 997)
# 🎯 New Best Valid MSE!
# Epoch 999/1000 - Train MSE: 1023.223694 | Valid MSE: 870.326294 | Best Valid MSE: 872.073608 (Epoch 998)
# 🎯 New Best Valid MSE!
# Epoch 1000/1000 - Train MSE: 1021.405090 | Valid MSE: 868.552429 | Best Valid MSE: 870.326294 (Epoch 999)
# 🎯 New Best Valid MSE!
# ✅ Finished. Best Valid MSE: 868.552429 at Epoch 1000

# %%
test_metrics, test_preds, test_targets = evaluate_on_test_set_direct(
    model=model,
    test_loader=test_loader,
    device=None,       # 모델이 올라간 디바이스 자동 사용
    show_samples=10
)

# 🔍 내가 만든 함수로 예측 결과 보기
show_delta_predictions(test_preds, test_targets, n=10)
# Out:
# 🎯 Test Set Evaluation (direct)
# MSE: 61.472775
#
# 🔍 Sample Predictions vs Targets:
# [0] pred: [-9.862471],  true: [-14.]
# [1] pred: [-9.195986],  true: [-14.]
# [2] pred: [-9.46167],  true: [-17.]
# [3] pred: [-10.108566],  true: [-16.]
# [4] pred: [-9.849886],  true: [-15.]
# [5] pred: [-9.647968],  true: [-10.]
# [6] pred: [-9.058969],  true: [-13.]
# [7] pred: [-9.277093],  true: [-12.]
# [8] pred: [-9.482059],  true: [-7.]
# [9] pred: [-9.226643],  true: [-7.]
#    D_lon_pred  D_lon_true
# 0     -9.8625       -14.0
# 1     -9.1960       -14.0
# 2     -9.4617       -17.0
# 3    -10.1086       -16.0
# 4     -9.8499       -15.0
# 5     -9.6480       -10.0
# 6     -9.0590       -13.0
# 7     -9.2771       -12.0
# 8     -9.4821        -7.0
# 9     -9.2266        -7.0

# %%
# # ==== Valid / Test 예측값을 뽑아 CSV로 저장 ====
# import pandas as pd
# import torch
# import os

# def collect_preds(model, loader, device=None):
#     """loader 전체에 대해 예측값과 실제값을 numpy로 반환"""
#     if device is None:
#         device = next(model.parameters()).device
#     model.eval()
#     preds, trues = [], []
#     with torch.no_grad():
#         for Xb, yb in loader:
#             Xb = Xb.to(device)
#             out = model(Xb).cpu()
#             preds.append(out)
#             trues.append(yb.cpu())
#     preds = torch.cat(preds, dim=0).numpy()
#     trues = torch.cat(trues, dim=0).numpy()
#     return preds, trues

# # 1) Validation 결과 저장
# val_preds, val_trues = collect_preds(model, valid_loader)
# df_valid = pd.DataFrame({
#     "D_lat_pred": val_preds[:, 0],
#     "D_lat_true": val_trues[:, 0],
#     "D_lon_pred": val_preds[:, 1],
#     "D_lon_true": val_trues[:, 1],
# })
# # Colab 로컬(세션) 저장
# df_valid.to_csv("/content/valid_results.csv", index=False)
# # 구글 드라이브에도 저장 (마운트되어 있음)
# df_valid.to_csv("/content/drive/MyDrive/valid_results.csv", index=False)
# print("✅ Saved: /content/valid_results.csv & /content/drive/MyDrive/valid_results.csv")

# # 2) Test 결과 저장
# test_preds_np, test_trues_np = test_preds.numpy(), test_targets.numpy()
# df_test = pd.DataFrame({
#     "D_lat_pred": test_preds_np[:, 0],
#     "D_lat_true": test_trues_np[:, 0],
#     "D_lon_pred": test_preds_np[:, 1],
#     "D_lon_true": test_trues_np[:, 1],
# })
# df_test.to_csv("/content/test_results.csv", index=False)
# df_test.to_csv("/content/drive/MyDrive/test_results.csv", index=False)
# print("✅ Saved: /content/test_results.csv & /content/drive/MyDrive/test_results.csv")

# %%
# ================================
# 📊 Test Summary Statistics (D_lon only)
# ================================
import numpy as np
import pandas as pd

# evaluate_on_test_set_direct 에서 나온 텐서(이미 CPU로 모임)
test_preds_np  = test_preds.numpy().reshape(-1)    # (N,1) 혹은 (N,) → (N,)
test_trues_np  = test_targets.numpy().reshape(-1)  # (N,1) 혹은 (N,) → (N,)

# 1) true/pred/error
df_test_stats = pd.DataFrame({
    "true_D_lon": test_trues_np,
    "pred_D_lon": test_preds_np,
})
df_test_stats["error_D_lon"] = df_test_stats["pred_D_lon"] - df_test_stats["true_D_lon"]
df_test_stats["squared_error"] = df_test_stats["error_D_lon"]**2
df_test_stats["abs_error"] = df_test_stats["error_D_lon"].abs()

print("\n==============================")
print("📋 D_lon Summary (true, pred, error)")
print(df_test_stats[["true_D_lon","pred_D_lon","error_D_lon"]].describe().round(6))

# 2) 단일 타깃이므로 전체 RMSE = sqrt(MSE)
overall_mse  = df_test_stats["squared_error"].mean()
overall_rmse = np.sqrt(overall_mse)
overall_mae  = df_test_stats["abs_error"].mean()

print(f"\n🎯 Overall MSE (from rows): {overall_mse:.6f}")
print(f"🎯 Overall RMSE: {overall_rmse:.6f}")
print(f"🎯 Overall MAE: {overall_mae:.6f}")
print(f"🎯 Overall MSE (from evaluate function): {test_metrics['MSE']:.6f}")

# (선택) 앞 10개 빠르게 확인
print("\n🔎 First 10 rows (true/pred/errors)")
print(df_test_stats[["true_D_lon","pred_D_lon","error_D_lon"]].head(10).round(6))
# Out:
# ==============================
# 📋 D_lon Summary (true, pred, error)
#         true_D_lon   pred_D_lon  error_D_lon
# count  2100.000000  2100.000000  2100.000000
# mean      0.914286    -0.742877    -1.657163
# std      22.791069    16.936562     7.665153
# min     -51.000000   -28.469290   -28.086908
# 25%      -5.000000    -5.570493    -5.366323
# 50%       0.000000    -0.187538    -0.359935
# 75%       9.000000     9.657660     2.507242
# max      46.000000    22.357862    24.880772
#
# 🎯 Overall MSE (from rows): 61.472775
# 🎯 Overall RMSE: 7.840457
# 🎯 Overall MAE: 5.633548
# 🎯 Overall MSE (from evaluate function): 61.472775
#
# 🔎 First 10 rows (true/pred/errors)
#    true_D_lon  pred_D_lon  error_D_lon
# 0       -14.0   -9.862471     4.137529
# 1       -14.0   -9.195986     4.804014
# 2       -17.0   -9.461670     7.538330
# 3       -16.0  -10.108566     5.891434
# 4       -15.0   -9.849886     5.150114
# 5       -10.0   -9.647968     0.352032
# 6       -13.0   -9.058969     3.941032
# 7       -12.0   -9.277093     2.722907
# 8        -7.0   -9.482059    -2.482058
# 9        -7.0   -9.226643    -2.226642
